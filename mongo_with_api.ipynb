# %% [markdown]
# # Project2

# %%
# Dependencies
import pandas as pd
import numpy as np
import pymongo
import json

# %% [markdown]
# ## Collect the data ##

# %%
# load the data
data_csv=pd.read_csv("data.csv")
data_csv.head()
# Out:
#                                                 name                   group  \
# 0  Beverage, instant breakfast powder, chocolate,...  Dairy and Egg Products
# 1  Beverage, instant breakfast powder, chocolate,...  Dairy and Egg Products
# 2        Beverage, milkshake mix, dry, not chocolate  Dairy and Egg Products
# 3                              Butter oil, anhydrous  Dairy and Egg Products
# 4                                     Butter, salted  Dairy and Egg Products
#
#    protein (g)  calcium (g)  sodium (g)  fiber (g)  vitaminc (g)  \
# 0        19.90        0.285       0.385        0.4        0.0769
# 1        35.80        0.500       0.717        2.0        0.1380
# 2        23.50        0.880       0.780        1.6        0.0012
# 3         0.28        0.004       0.002        NaN        0.0000
# 4         0.85        0.024       0.714        NaN        0.0000
#
#    potassium (g)  carbohydrate (g)  sugars (g)  fat (g)  water (g)  calories  \
# 0          0.947             66.20       65.80     1.40       7.40     357.0
# 1          1.705             41.00       39.00     5.10       7.40     358.0
# 2          2.200             52.90       51.30     2.60      12.80     329.0
# 3          0.005               NaN         NaN    99.48       0.24     876.0
# 4          0.024              0.06        0.06    81.11      15.87     717.0
#
#    saturated (g)  monounsat (g)  polyunsat (g)     id
# 0          0.560          0.314          0.278  27481
# 1          2.162          1.189          1.027  27482
# 2          2.059          0.332          0.060  27483
# 3         61.924         28.732          3.694  27484
# 4         51.368         21.021          3.043  27485

# %% [markdown]
# ## Clean the data

# %%
# Clean the data
data_csv.columns=['name','group','protein','calcium','sodium','fiber','vitaminc','potassium','carbohydrate','sugars','fat','water','calories','saturated','monounsat','polyunsat','id']
data_csv
# Out:
#                                                    name  \
# 0     Beverage, instant breakfast powder, chocolate,...
# 1     Beverage, instant breakfast powder, chocolate,...
# 2           Beverage, milkshake mix, dry, not chocolate
# 3                                 Butter oil, anhydrous
# 4                                        Butter, salted
# 5                            Butter, whipped, with salt
# 6                                  Butter, without salt
# 7                                         Cheese fondue
# 8                      Cheese food, cold pack, american
# 9                                Cheese food, imitation
# 10    Cheese food, pasteurized process, american, wi...
# 11    Cheese food, pasteurized process, american, wi...
# 12              Cheese food, pasteurized process, swiss
# 13    Cheese product, pasteurized process, american,...
# 14    Cheese product, pasteurized process, cheddar o...
# 15                   Cheese sauce, prepared from recipe
# 16                     Cheese spread, cream cheese base
# 17    Cheese spread, pasteurized process, american, ...
# 18    Cheese spread, pasteurized process, american, ...
# 19                        Cheese substitute, mozzarella
# 20                  Cheese, Mexican, blend, reduced fat
# 21                  Cheese, american cheddar, imitation
# 22                                         Cheese, blue
# 23                                        Cheese, brick
# 24                                         Cheese, brie
# 25                                    Cheese, camembert
# 26                                      Cheese, caraway
# 27                                      Cheese, cheddar
# 28                                     Cheese, cheshire
# 29                                        Cheese, colby
# ...                                                 ...
# 7607         Restaurant, Chinese, general tso's chicken
# 7608              Restaurant, Chinese, kung pao chicken
# 7609                 Restaurant, Chinese, lemon chicken
# 7610  Restaurant, Latino, Arroz con frijoles negros ...
# 7611  Restaurant, Latino, Arroz con grandules (rice ...
# 7612  Restaurant, Latino, Arroz con habichuelas colo...
# 7613  Restaurant, Latino, arepa (unleavened cornmeal...
# 7614  Restaurant, Latino, arroz con leche (rice pudd...
# 7615                Restaurant, Latino, black bean soup
# 7616   Restaurant, Latino, bunuelos (fried yeast bread)
# 7617  Restaurant, Latino, chicken and rice, entree, ...
# 7618      Restaurant, Latino, empanadas, beef, prepared
# 7619  Restaurant, Latino, pupusas con frijoles (pupu...
# 7620  Restaurant, Latino, pupusas con queso (pupusas...
# 7621  Restaurant, Latino, pupusas del cerdo (pupusas...
# 7622                   Restaurant, Latino, tamale, corn
# 7623                   Restaurant, Latino, tamale, pork
# 7624                     Restaurant, Latino, tripe soup
# 7625             Restaurant, family style, French fries
# 7626  Restaurant, family style, chicken fingers, fro...
# 7627  Restaurant, family style, fried mozzarella sticks
# 7628  Restaurant, family style, macaroni & cheese, f...
# 7629  Restaurant, family style, shrimp, breaded and ...
# 7630            Restaurant, family style, sirloin steak
# 7631          T.G.I. FRIDAY'S, FRIDAY'S Shrimp, breaded
# 7632                      T.G.I. FRIDAY'S, French fries
# 7633     T.G.I. FRIDAY'S, Mac & Cheese, from kid's menu
# 7634  T.G.I. FRIDAY'S, chicken fingers, from kids' menu
# 7635             T.G.I. FRIDAY'S, classic sirloin steak
# 7636                  T.G.I. FRIDAY'S, fried mozzarella
#
#                        group  protein  calcium  sodium  fiber  vitaminc  \
# 0     Dairy and Egg Products    19.90    0.285   0.385    0.4    0.0769
# 1     Dairy and Egg Products    35.80    0.500   0.717    2.0    0.1380
# 2     Dairy and Egg Products    23.50    0.880   0.780    1.6    0.0012
# 3     Dairy and Egg Products     0.28    0.004   0.002    NaN    0.0000
# 4     Dairy and Egg Products     0.85    0.024   0.714    NaN    0.0000
# 5     Dairy and Egg Products     0.85    0.024   0.827    NaN    0.0000
# 6     Dairy and Egg Products     0.85    0.024   0.011    NaN    0.0000
# 7     Dairy and Egg Products    14.23    0.476   0.132    NaN    0.0000
# 8     Dairy and Egg Products    19.66    0.497   0.966    NaN    0.0000
# 9     Dairy and Egg Products    22.40    0.552   1.239    NaN    0.0000
# 10    Dairy and Egg Products    19.61    0.574   1.596    NaN    0.0000
# 11    Dairy and Egg Products    18.40    0.570   1.265    NaN    0.0000
# 12    Dairy and Egg Products    21.92    0.723   1.552    NaN    0.0000
# 13    Dairy and Egg Products    17.60    0.529   1.587    NaN    0.0000
# 14    Dairy and Egg Products    17.60    0.529   1.587    NaN    0.0000
# 15    Dairy and Egg Products    10.33    0.311   0.493    0.1    0.0006
# 16    Dairy and Egg Products     7.10    0.071   0.673    NaN    0.0000
# 17    Dairy and Egg Products    16.41    0.562   1.625    NaN    0.0000
# 18    Dairy and Egg Products    16.41    0.562   1.345    NaN    0.0000
# 19    Dairy and Egg Products    11.47    0.610   0.685    NaN    0.0001
# 20    Dairy and Egg Products    24.69    1.146   0.776    NaN    0.0000
# 21    Dairy and Egg Products    16.70    0.562   1.345    NaN    0.0000
# 22    Dairy and Egg Products    21.40    0.528   1.395    NaN    0.0000
# 23    Dairy and Egg Products    23.24    0.674   0.560    NaN    0.0000
# 24    Dairy and Egg Products    20.75    0.184   0.629    NaN    0.0000
# 25    Dairy and Egg Products    19.80    0.388   0.842    NaN    0.0000
# 26    Dairy and Egg Products    25.18    0.673   0.690    NaN    0.0000
# 27    Dairy and Egg Products    24.90    0.721   0.621    NaN    0.0000
# 28    Dairy and Egg Products    23.37    0.643   0.700    NaN    0.0000
# 29    Dairy and Egg Products    23.76    0.685   0.604    NaN    0.0000
# ...                      ...      ...      ...     ...    ...       ...
# 7607        Restaurant Foods    12.90    0.012   0.435    0.9    0.0016
# 7608        Restaurant Foods     9.76    0.020   0.402    1.5    0.0071
# 7609        Restaurant Foods    10.77    0.039   0.243    1.1    0.0025
# 7610        Restaurant Foods     4.64    0.037   0.420    3.4    0.0000
# 7611        Restaurant Foods     3.50    0.008   0.583    1.4    0.0000
# 7612        Restaurant Foods     3.96    0.015   0.370    2.6    0.0000
# 7613        Restaurant Foods     5.48    0.089   0.270    2.6    0.0000
# 7614        Restaurant Foods     3.20    0.090   0.106    0.5    0.0000
# 7615        Restaurant Foods     5.10    0.042   0.311    4.9    0.0000
# 7616        Restaurant Foods     8.02    0.215   0.418    1.5    0.0000
# 7617        Restaurant Foods    12.02    0.018   0.518    1.2    0.0000
# 7618        Restaurant Foods    11.31    0.020   0.440    2.0    0.0000
# 7619        Restaurant Foods     5.59    0.051   0.305    5.8    0.0000
# 7620        Restaurant Foods    11.72    0.325   0.400    2.9    0.0000
# 7621        Restaurant Foods    11.51    0.049   0.426    2.6    0.0000
# 7622        Restaurant Foods     3.48    0.024   0.277    3.2    0.0000
# 7623        Restaurant Foods     7.35    0.075   0.473    2.4    0.0000
# 7624        Restaurant Foods     8.61    0.022   0.411    NaN    0.0000
# 7625        Restaurant Foods     3.65    0.019   0.314    3.5    0.0000
# 7626        Restaurant Foods    19.93    0.021   0.588    1.0    0.0000
# 7627        Restaurant Foods    14.89    0.348   0.794    1.8    0.0000
# 7628        Restaurant Foods     6.47    0.116   0.368    1.2    0.0000
# 7629        Restaurant Foods    12.85    0.063   0.853    1.0    0.0000
# 7630        Restaurant Foods    28.78    0.009   0.307    NaN    0.0000
# 7631        Restaurant Foods    13.75    0.058   0.685    0.8    0.0000
# 7632        Restaurant Foods     4.08    0.018   0.374    3.6    0.0000
# 7633        Restaurant Foods     5.84    0.114   0.417    1.0    0.0000
# 7634        Restaurant Foods    21.52    0.038   0.524    0.9    0.0000
# 7635        Restaurant Foods    30.61    0.007   0.194    NaN    0.0000
# 7636        Restaurant Foods    15.73    0.362   0.656    1.9    0.0000
#
#       potassium  carbohydrate  sugars    fat  water  calories  saturated  \
# 0         0.947         66.20   65.80   1.40   7.40     357.0      0.560
# 1         1.705         41.00   39.00   5.10   7.40     358.0      2.162
# 2         2.200         52.90   51.30   2.60  12.80     329.0      2.059
# 3         0.005           NaN     NaN  99.48   0.24     876.0     61.924
# 4         0.024          0.06    0.06  81.11  15.87     717.0     51.368
# 5         0.026          0.06    0.06  81.11  15.87     717.0     50.489
# 6         0.024          0.06    0.06  81.11  17.94     717.0     51.368
# 7         0.105          3.77     NaN  13.47  61.61     229.0      8.721
# 8         0.363          8.32     NaN  24.46  43.12     331.0     15.355
# 9         0.336          8.80    8.21   1.30  63.80     137.0      0.810
# 10        0.279          7.29    7.43  24.60  43.15     328.0     15.443
# 11        0.291          7.83    7.43  25.18  43.21     330.0     14.895
# 12        0.284          4.50     NaN  24.14  43.67     323.0     15.487
# 13        0.330         10.60    8.02  14.10  51.80     240.0      8.850
# 14        0.330         10.60    8.02  14.10  51.80     240.0      8.850
# 15        0.142          5.48    0.19  14.92  66.86     197.0      8.034
# 16        0.112          3.50    3.50  28.60  58.50     295.0     18.020
# 17        0.242          8.73     NaN  21.23  47.65     290.0     13.327
# 18        0.242          8.73    7.32  21.23  47.65     290.0     13.327
# 19        0.455         23.67   23.67  12.22  47.36     248.0      3.711
# 20        0.093          3.41    0.56  19.40  48.20     282.0     11.580
# 21        0.242         11.60    7.74  14.00  53.10     239.0      8.790
# 22        0.256          2.34    0.50  28.74  42.41     353.0     18.669
# 23        0.136          2.79    0.51  29.68  41.11     371.0     18.764
# 24        0.152          0.45    0.45  27.68  48.42     334.0     17.410
# 25        0.187          0.46    0.46  24.26  51.80     300.0     15.259
# 26        0.093          3.06     NaN  29.20  39.28     376.0     18.584
# 27        0.098          1.28    0.52  33.14  36.75     403.0     21.092
# 28        0.095          4.78     NaN  30.60  37.65     387.0     19.475
# 29        0.127          2.57    0.52  32.11  38.20     394.0     20.218
# ...         ...           ...     ...    ...    ...       ...        ...
# 7607      0.201         23.99   11.60  16.36  45.15     295.0      2.760
# 7608      0.218          6.87    3.03   6.98  74.78     129.0      1.352
# 7609      0.155         19.15    8.67  11.76  57.08     226.0      1.912
# 7610      0.224         24.40    0.86   3.85  65.47     151.0      0.729
# 7611      0.084         30.75     NaN   4.98  58.87     182.0      0.763
# 7612      0.194         23.74    0.15   3.46  67.27     142.0      0.502
# 7613      0.088         37.14    0.87   5.38  50.80     219.0      2.902
# 7614      0.142         24.92   15.26   3.69  67.39     146.0      1.899
# 7615      0.340         14.79    0.89   2.57  75.91     103.0      0.535
# 7616      0.104         48.57   12.24  26.24  15.30     462.0      6.834
# 7617      0.184         20.03    0.55   5.06  61.12     174.0      1.101
# 7618      0.190         31.19    1.84  18.37  37.50     335.0      5.156
# 7619      0.305         31.49    1.30   9.01  52.16     229.0      2.188
# 7620      0.120         22.39    1.20  13.25  50.36     256.0      6.479
# 7621      0.255         23.02    1.45  10.43  53.12     232.0      3.166
# 7622      0.186         26.68    7.42   7.21  61.32     186.0      2.629
# 7623      0.152         15.75    0.46   9.04  66.03     174.0      2.692
# 7624      0.081          4.07     NaN   2.58  83.41      74.0      1.045
# 7625      0.610         36.60    0.28  14.53  43.05     292.0      2.666
# 7626      0.325         15.20    0.41  14.34  48.01     270.0      2.641
# 7627      0.115         24.89    2.22  18.92  37.95     329.0      6.983
# 7628      0.144         18.12    2.87   6.10  67.72     153.0      2.210
# 7629      0.096         20.01    0.74  18.10  46.31     294.0      3.325
# 7630      0.363          0.07     NaN   7.88  61.60     186.0      2.952
# 7631      0.066         12.43    0.47  15.12  56.45     241.0      2.833
# 7632      0.669         37.34    0.32  15.06  41.09     301.0      2.824
# 7633      0.135         16.42    2.74   4.47  71.48     129.0      1.579
# 7634      0.335         12.08    0.29  13.91  49.88     260.0      2.656
# 7635      0.382           NaN     NaN   6.95  61.04     185.0      2.839
# 7636      0.110         24.55    1.66  19.63  37.05     338.0      7.204
#
#       monounsat  polyunsat     id
# 0         0.314      0.278  27481
# 1         1.189      1.027  27482
# 2         0.332      0.060  27483
# 3        28.732      3.694  27484
# 4        21.021      3.043  27485
# 5        23.426      3.012  27486
# 6        21.021      3.043  27487
# 7         3.563      0.484  27488
# 8         7.165      0.719  27489
# 9         0.380      0.048  27490
# 10        7.206      0.723  27491
# 11        7.214      1.108  27492
# 12        6.801      0.600  27493
# 13        4.130      0.410  27494
# 14        4.130      0.410  27495
# 15        4.735      1.397  27496
# 16        8.071      1.033  27497
# 17        6.219      0.624  27498
# 18        6.219      0.624  27499
# 19        6.243      1.738  27500
# 20        5.020      0.750  27501
# 21        4.102      0.409  27502
# 22        7.778      0.800  27503
# 23        8.598      0.784  27504
# 24        8.013      0.826  27505
# 25        7.023      0.724  27506
# 26        8.275      0.830  27507
# 27        9.391      0.942  27508
# 28        8.671      0.870  27509
# 29        9.280      0.953  27510
# ...         ...        ...    ...
# 7607      3.879      7.501  35088
# 7608      2.173      3.020  35089
# 7609      2.567      5.768  35090
# 7610      0.889      1.557  35091
# 7611      1.005      2.320  35092
# 7612      0.691      1.579  35093
# 7613      1.514      0.989  35094
# 7614      1.018      0.443  35095
# 7615      1.035      0.787  35096
# 7616      9.415      7.090  35097
# 7617      1.799      1.564  35098
# 7618      7.121      4.268  35099
# 7619      2.986      2.907  35100
# 7620      3.411      1.555  35101
# 7621      3.964      2.205  35102
# 7622      2.437      1.548  35103
# 7623      3.244      2.052  35104
# 7624      1.124      0.310  35105
# 7625      3.892      7.006  35106
# 7626      3.498      6.985  35107
# 7627      4.709      5.176  35108
# 7628      2.225      1.382  35109
# 7629      4.344      9.033  35110
# 7630      3.265      0.610  35111
# 7631      3.612      7.546  35112
# 7632      4.118      7.502  35113
# 7633      1.014      1.323  35114
# 7634      3.448      6.874  35115
# 7635      2.945      0.551  35116
# 7636      5.031      5.328  35117
#
# [7637 rows x 17 columns]

# %% [markdown]
# ## Tranfer the data to json type

# %%
# Change the data to Json type
import json

data_json=json.loads(data_csv.T.to_json()).values()
len(data_json)
data_json
# Out:
# dict_values([{'name': 'Beverage, instant breakfast powder, chocolate, not reconstituted', 'group': 'Dairy and Egg Products', 'protein': 19.9, 'calcium': 0.285, 'sodium': 0.385, 'fiber': 0.4, 'vitaminc': 0.0769, 'potassium': 0.947, 'carbohydrate': 66.2, 'sugars': 65.8, 'fat': 1.4, 'water': 7.4, 'calories': 357.0, 'saturated': 0.56, 'monounsat': 0.314, 'polyunsat': 0.278, 'id': 27481}, {'name': 'Beverage, instant breakfast powder, chocolate, sugar-free, not reconstituted', 'group': 'Dairy and Egg Products', 'protein': 35.8, 'calcium': 0.5, 'sodium': 0.717, 'fiber': 2.0, 'vitaminc': 0.138, 'potassium': 1.705, 'carbohydrate': 41.0, 'sugars': 39.0, 'fat': 5.1, 'water': 7.4, 'calories': 358.0, 'saturated': 2.162, 'monounsat': 1.189, 'polyunsat': 1.027, 'id': 27482}, {'name': 'Beverage, milkshake mix, dry, not chocolate', 'group': 'Dairy and Egg Products', 'protein': 23.5, 'calcium': 0.88, 'sodium': 0.78, 'fiber': 1.6, 'vitaminc': 0.0012, 'potassium': 2.2, 'carbohydrate': 52.9, 'sugars': 51.3, 'fat': 2.6, 'water': 12.8, 'calories': 329.0, 'saturated': 2.059, 'monounsat': 0.332, 'polyunsat': 0.06, 'id': 27483}, {'name': 'Butter oil, anhydrous', 'group': 'Dairy and Egg Products', 'protein': 0.28, 'calcium': 0.004, 'sodium': 0.002, 'fiber': None, 'vitaminc': 0.0, 'potassium': 0.005, 'carbohydrate': None, 'sugars': None, 'fat': 99.48, 'water': 0.24, 'calories': 876.0, 'saturated': 61.924, 'monounsat': 28.732, 'polyunsat': 3.694, 'id': 27484}, {'name': 'Butter, salted', 'group': 'Dairy and Egg Products', 'protein': 0.85, 'calcium': 0.024, 'sodium': 0.714, 'fiber': None, 'vitaminc': 0.0, 'potassium': 0.024, 'carbohydrate': 0.06, 'sugars': 0.06, 'fat': 81.11, 'water': 15.87, 'calories': 717.0, 'saturated': 51.368, 'monounsat': 21.021, 'polyunsat': 3.043, 'id': 27485}, {'name': 'Butter, whipped, with salt', 'group': 'Dairy and Egg Products', 'protein': 0.85, 'calcium': 0.024, 'sodium': 0.827, 'fiber': None, 'vitaminc': 0.0, 'potassium': 0.026, 'carbohydrate': 0.06, 'sugars': 0.06, 'fat': 81.11, 'water': 15.87, 'calories': 717.0, 'saturated': 50.489, 'monounsat': 23.426, 'polyunsat': 3.012, 'id': 27486}, {'name': 'Butter, without salt', 'group': 'Dairy and Egg Products', 'protein': 0.85, 'calcium': 0.024, 'sodium': 0.011, 'fiber': None, 'vitaminc': 0.0, 'potassium': 0.024, 'carbohydrate': 0.06, 'sugars': 0.06, 'fat': 81.11, 'water': 17.94, 'calories': 717.0, 'saturated': 51.368, 'monounsat': 21.021, 'polyunsat': 3.043, 'id': 27487}, {'name': 'Cheese fondue', 'group': 'Dairy and Egg Products', 'protein': 14.23, 'calcium': 0.476, 'sodium': 0.132, 'fiber': None, 'vitaminc': 0.0, 'potassium': 0.105, 'carbohydrate': 3.77, 'sugars': None, 'fat': 13.47, 'water': 61.61, 'calories': 229.0, 'saturated': 8.721, 'monounsat': 3.563, 'polyunsat': 0.484, 'id': 27488}, {'name': 'Cheese food, cold pack, american', 'group': 'Dairy and Egg Products', 'protein': 19.66, 'calcium': 0.497, 'sodium': 0.966, 'fiber': None, 'vitaminc': 0.0, 'potassium': 0.363, 'carbohydrate': 8.32, 'sugars': None, 'fat': 24.46, 'water': 43.12, 'calories': 331.0, 'saturated': 15.355, 'monounsat': 7.165, 'polyunsat': 0.719, 'id': 27489}, {'name': 'Cheese food, imitation', 'group': 'Dairy and Egg Products', 'protein': 22.4, 'calcium': 0.552, 'sodium': 1.239, 'fiber': None, 'vitaminc': 0.0, 'potassium': 0.336, 'carbohydrate': 8.8, 'sugars': 8.21, 'fat': 1.3, 'water': 63.8, 'calories': 137.0, 'saturated': 0.81, 'monounsat': 0.38, 'polyunsat': 0.048, 'id': 27490}, {'name': 'Cheese food, pasteurized process, american, with di sodium phosphate', 'group': 'Dairy and Egg Products', 'protein': 19.61, 'calcium': 0.574, 'sodium': 1.596, 'fiber': None, 'vitaminc': 0.0, 'potassium': 0.279, 'carbohydrate': 7.29, 'sugars': 7.43, 'fat': 24.6, 'water': 43.15, 'calories': 328.0, 'saturated': 15.443, 'monounsat': 7.206, 'polyunsat': 0.723, 'id': 27491}, {'name': 'Cheese food, pasteurized process, american, without di sodium phosphate', 'group': 'Dairy and Egg Products', 'protein': 18.4, 'calcium': 0.57, ' ...

# %% [markdown]
# ## Load the CSV data into mongo database

# %%
# Import our pymongo library, which lets us connect our Flask app to our Mongo database.
import pymongo

# Create connection variable
conn = 'mongodb://localhost:27017'

# Pass connection to the pymongo instance.
client = pymongo.MongoClient(conn)
db = client.project_two

# %%
# Connect to a database and input the data
db.data_csv.insert_many(data_json)

# %% [markdown]
# # Inquiry data from mongo

# %%
x=list(db.data_csv.find({'id': 27481}))[0]
x['sugars']
# Out:
# 65.8

# %%
y=list(db.data_csv.find({"protein":{"$gte":10}}))
# name=[]
name= [i["name"] for i in y]
name
# Out:
# ['Beverage, instant breakfast powder, chocolate, not reconstituted',
#  'Beverage, instant breakfast powder, chocolate, sugar-free, not reconstituted',
#  'Beverage, milkshake mix, dry, not chocolate',
#  'Cheese fondue',
#  'Cheese food, cold pack, american',
#  'Cheese food, imitation',
#  'Cheese food, pasteurized process, american, with di sodium phosphate',
#  'Cheese food, pasteurized process, american, without di sodium phosphate',
#  'Cheese food, pasteurized process, swiss',
#  'Cheese product, pasteurized process, american, reduced fat, fortified with vitamin D',
#  'Cheese product, pasteurized process, cheddar or american, reduced fat',
#  'Cheese sauce, prepared from recipe',
#  'Cheese spread, pasteurized process, american, with di sodium phosphate',
#  'Cheese spread, pasteurized process, american, without di sodium phosphate',
#  'Cheese substitute, mozzarella',
#  'Cheese, Mexican, blend, reduced fat',
#  'Cheese, american cheddar, imitation',
#  'Cheese, blue',
#  'Cheese, brick',
#  'Cheese, brie',
#  'Cheese, camembert',
#  'Cheese, caraway',
#  'Cheese, cheddar',
#  'Cheese, cheshire',
#  'Cheese, colby',
#  'Cheese, cottage, creamed, large or small curd',
#  'Cheese, cottage, creamed, with fruit',
#  'Cheese, cottage, lowfat, 1% milkfat',
#  'Cheese, cottage, lowfat, 1% milkfat, lactose reduced',
#  'Cheese, cottage, lowfat, 1% milkfat, no sodium added',
#  'Cheese, cottage, lowfat, 1% milkfat, with vegetables',
#  'Cheese, cottage, lowfat, 2% milkfat',
#  'Cheese, cottage, nonfat, uncreamed, dry, large or small curd',
#  'Cheese, cottage, with vegetables',
#  'Cheese, cream, fat free',
#  'Cheese, dry white, queso seco',
#  'Cheese, edam',
#  'Cheese, feta',
#  'Cheese, fontina',
#  'Cheese, fresh, queso fresco',
#  'Cheese, goat, hard type',
#  'Cheese, goat, semisoft type',
#  'Cheese, goat, soft type',
#  'Cheese, gouda',
#  'Cheese, gruyere',
#  'Cheese, limburger',
#  'Cheese, low fat, cheddar or colby',
#  'Cheese, low-sodium, cheddar or colby',
#  'Cheese, mexican, queso anejo',
#  'Cheese, mexican, queso asadero',
#  'Cheese, mexican, queso chihuahua',
#  'Cheese, monterey',
#  'Cheese, monterey, low fat',
#  'Cheese, mozzarella, low sodium',
#  'Cheese, mozzarella, nonfat',
#  'Cheese, mozzarella, part skim milk',
#  'Cheese, mozzarella, part skim milk, low moisture',
#  'Cheese, mozzarella, whole milk',
#  'Cheese, mozzarella, whole milk, low moisture',
#  'Cheese, muenster',
#  'Cheese, muenster, low fat',
#  'Cheese, parmesan, dry grated, reduced fat',
#  'Cheese, parmesan, grated',
#  'Cheese, parmesan, hard',
#  'Cheese, parmesan, low sodium',
#  'Cheese, parmesan, shredded',
#  'Cheese, pasteurized process, american, low fat',
#  'Cheese, pasteurized process, american, with di sodium phosphate',
#  'Cheese, pasteurized process, american, without di sodium phosphate',
#  'Cheese, pasteurized process, cheddar or american, fat-free',
#  'Cheese, pasteurized process, cheddar or american, low sodium',
#  'Cheese, pasteurized process, pimento',
#  'Cheese, pasteurized process, swiss, low fat',
#  'Cheese, pasteurized process, swiss, with di sodium phosphate',
#  'Cheese, pasteurized process, swiss, without di sodium phosphate',
#  'Cheese, port de salut',
#  'Cheese, provolone',
#  'Cheese, provolone, reduced fat',
#  'Cheese, ricotta, part skim milk',
#  'Cheese, ricotta, whole milk',
#  'Cheese, romano',
#  'Cheese, roquefort',
#  'Cheese, swiss',
#  'Cheese, swiss, low fat',
#  'Cheese, swiss, low sodium',
#  'Cheese, tilsit',
#  'Cheese, white, queso blanco',
#  'Egg Mix, USDA Commodity',
#  'Egg substitute, liquid or frozen, fat free',
#  'Egg substitute, powder',
#  'Egg, duck, whole, fresh, raw',
#  'Egg, goose, whole, fresh, raw',
#  'Egg, quail, whole, fresh, raw',
#  'Egg, turkey, whole, fresh, raw',
#  'Egg, white, dried',
#  'Egg, white, dried, flakes, glucose reduced',
#  'Egg, white, dried, powder, glucose reduced',
#  'Egg, white, raw, fresh',
#  'Egg, whole, cooked, fried',
#  'Egg, whole, cooked, hard-boiled',
#  'Egg, whole, cooked, omelet',
#  'Egg, whole, cooked, poached',
#  'Egg, whole, dried',
#  'Egg, whole, dried, stabilized, glucose reduced',
#  'Egg, whole, raw, fresh',
#  'Egg, whole, raw, frozen',
#  'Egg, yolk, dried',
#  'Egg, yolk, raw, fresh',
#  'Egg, yolk, raw, frozen',
#  'Egg, yolk, raw, frozen, salted',
#  'Egg, yolk, raw, frozen, sugared',
#  'Eggs, scrambled, frozen mixture',
#  'Imitation cheese, american or cheddar, low cholesterol',
#  'KRAFT CHEEZ WHIZ LIGHT Pasteurized Process Cheese Product',
#  'KRAFT CHEEZ WHIZ Pasteurized Process Cheese Sauce',
#  'KRAFT FREE Singles American Nonfat Pasteurized Process Cheese Product',
#  'KRAFT VELVEETA LIGHT Reduced Fat Pasteurized Process Cheese Product',
#  'KRAFT VELVEETA Pasteurized Process Cheese Spread',
#  'Milk, buttermilk, dried',
#  'Milk, dry, nonfat, calcium reduced',
#  'Milk, dry, nonfat, instant, with added vitamin A and vitamin D',
#  'Milk, dry, nonfat, instant, without added vitamin A and vitamin D',
#  'Milk, dry, nonfat, regular, with added vitamin A and vitamin D',
#  'Milk, dry, nonfat, regular, without added vitamin A and vitamin D',
#  'Milk, dry, whole, with added vitamin D',
#  'Milk, dry, whole, without added vitamin D',
#  'Parmesan cheese topping, fat free',
#  'Protein supplement, milk based, Muscle Milk Light, powder',
#  'Protein supplement, milk based, Muscle Milk, powder',
#  'USDA Commodity, cheese, cheddar, reduced fat',
#  'Whey, acid, dried',
#  'Whey, sweet, dried',
#  'Spearmint, dried',
#  'Spices, anise seed',
#  'Spices, basil, dried',
#  'Spices, caraway seed',
#  'Spices, cardamom',
#  'Spices, celery seed',
#  'Spices, chervil, dried',
#  'Spices, chili powder',
#  'Spices, coriander leaf, dried',
#  'Spices, coriander seed',
#  'Spices, cumin seed',
#  'Spices, curry powder',
#  'Spices, dill seed',
#  'Spices, dill weed, dried',
#  'Spices, fennel seed',
#  'Spices, fenugreek seed',
#  'Spices, garlic powder',
#  'Spices, marjoram, dried',
#  'Spices, mustard seed, ground',
#  'Spices, onion powder',
#  'Spices, paprika',
#  'Spices, parsley, dried',
#  'Spices, pepper, black',
#  'Spices, pepper, red or cayenne',
#  'Spices, pepper, white',
#  'Spices, poppy seed',
#  'Spices, saffron',
#  'Spices, sage, ground',
#  'Spices, tarragon, dried',
#  'Babyfood, cereal, barley, dry',
#  'Babyfood, cereal, high protein, with apple and orange, dry',
#  'Babyfood, cereal, mixed, dry',
#  'Babyfood, cereal, mixed, with bananas, dry',
#  'Babyfood, cereal, oatmeal, dry',
#  'Babyfood, cereal, oatmeal, with bananas, dry',
#  'Babyfood, cereal, oatmeal, with honey, dry',
#  'Babyfood, cereal, whole wheat, with apples, dry',
#  'Babyfood, cookies',
#  'Babyfood, meat, beef, junior',
#  'Babyfood, meat, beef, strained',
#  'Babyfood, meat, chicken sticks, junior',
#  'Babyfood, meat, chicken, junior',
#  'Babyfood, meat, chicken, strained',
#  'Babyfood, meat, ham, junior',
#  'Babyfood, meat, ham, strained',
#  'Babyfood, meat, lamb, junior',
#  'Babyfood, meat, lamb, strained',
#  'Babyfood, meat, meat sticks, junior',
#  'Babyfood, meat, pork, strained',
#  'Babyfood, meat, turkey sticks, junior',
#  'Babyfood, meat, turkey, junior',
#  'Babyfood, meat, turkey, strained',
#  'Babyfood, meat, veal, strained',
#  'Babyfood, oatmeal cereal with fruit, dry, instant, toddler',
#  'Babyfood, pretzels',
#  'Babyfood, teething biscuits',
#  'Child formula, MEAD JOHNSON, PORTAGEN, with iron, powder, not reconstituted',
#  'Infant formula, ABBOTT NUTRITION, ALIMENTUM ADVANCE, with iron, powder, not reconstituted, with DHA and ARA (formerly ROSS)',
#  'Infant formula, ABBOTT NUTRITION, SIMILAC, ADVANCE, with iron, powder, not reconstituted (formerly ROSS)',
#  'Infant formula, ABBOTT NUTRITION, SIMILAC, ISOMIL, ADVANCE with iron, powder, not reconstituted (formerly ROSS)',
#  'Infant formula, ABBOTT NUTRITION, SIMILAC, ISOMIL, with iron, powder, not reconstituted (formerly ROSS)',
#  'Infant formula, ABBOTT NUTRITION, SIMILAC, NEOSURE, powder, with ARA and DHA (formerly ROSS)',
#  'Infant formula, ABBOTT NUTRITION, SIMILAC, PM 60/40, powder not reconstituted (formerly ROSS)',
#  'Infant formula, ABBOTT NUTRITION, SIMILAC, SENSITIVE, (LACTOSE FREE), powder, with ARA and DHA (formerly ROSS)',
#  'Infant formula, ABBOTT NUTRITION, SIMILAC, low iron, powder, not reconstituted (formerly ROSS)',
#  'Infant formula, ABBOTT NUTRITION, SIMILAC, with iron, powder, not reconstituted (formerly ROSS)',
#  'Infant formula, MEAD JOHNSON, ENFAMIL, AR LIPIL, powder, with ARA and DHA',
#  'Infant formula, MEAD JOHNSON, ENFAMIL, ENFACARE LIPIL, powder, with ARA and DHA',
#  'Infant formula, MEAD JOHNSON, ENFAMIL, LACTOFREE LIPIL, with iron, powder, with ARA and DHA',
#  'Infant formula, MEAD JOHNSON, ENFAMIL, LACTOFREE, with iron, powder, not reconstituted',
#  'Infant formula, MEAD JOHNSON, ENFAMIL, LIPIL, low iron, powder, with ARA and DHA',
#  'Infant formula, MEAD JOHNSON, ENFAMIL, LIPIL, with iron, powder, with ARA and DHA',
#  'Infant formula, MEAD JOHNSON, ENFAMIL, NUTRAMIGEN LIPIL, with iron, powder, not reconstituted, with ARA and DHA',
#  'Infant formula, MEAD JOHNSON, ENFAMIL, NUTRAMIGEN, with iron, powder, not reconstituted',
#  'Infant formula, MEAD JOHNSON, ENFAMIL, PROSOBEE LIPIL, with iron, powder, not reconstituted, with ARA and DHA',
#  'Infant formula, MEAD JOHNSON, ENFAMIL, PROSOBEE, with iron, powder, not reconstituted',
#  'Infant formula, MEAD JOHNSON, ENFAMIL, low iron, powder, not reconstituted',
#  'Infant formula, MEAD JOHNSON, ENFAMIL, with iron, powder',
#  'Infant formula, MEAD JOHNSON, NEXT STEP PROSOBEE, powder, not reconstituted',
#  'Infant formula, MEAD JOHNSON, NEXT STEP, PROSOBEE LIPIL, powder, with ARA and DHA',
#  'Infant formula, MEAD JOHNSON, PREGESTIMIL, with iron, powder, not reconstituted',
#  'Infant formula, NESTLE, GOOD START 2 ESSENTIALS, with iron, powder',
#  'Infant formula, NESTLE, GOOD START ESSENTIALS SOY, with iron, powder',
#  'Infant formula, NESTLE, GOOD START SOY, with ARA and DHA, powder',
#  'Infant formula, NESTLE, GOOD START SUPREME, with iron, powder',
#  'Infant formula, PBM PRODUCTS, ULTRA BRIGHT BEGINNINGS, powder (formerly WYETH-AYERST)',
#  'Infant formula, PBM PRODUCTS, ULTRA BRIGHT BEGINNINGS, soy, powder (formerly WYETH-AYERST)',
#  'Infant formula, PBM PRODUCTS, store brand, powder (formerly WYETH-AYERST)',
#  'Infant formula, PBM PRODUCTS, store brand, soy, powder (formerly WYETH-AYERST)',
#  'Zwieback',
#  'Chicken breast tenders, cooked, conventional oven',
#  'Chicken breast tenders, cooked, microwaved',
#  'Chicken breast tenders, uncooked',
#  'Chicken nuggets, frozen, cooked',
#  'Chicken nuggets, frozen, uncooked',
#  'Chicken patty, frozen, cooked',
#  'Chicken patty, frozen, uncooked',
#  'Chicken, broilers or fryers, back, meat and skin, cooked, fried, batter',
#  'Chicken, broilers or fryers, back, meat and skin, cooked, fried, flour',
#  'Chicken, broilers or fryers, back, meat and skin, cooked, roasted',
#  'Chicken, broilers or fryers, back, meat and skin, cooked, rotisserie, original seasoning',
#  'Chicken, broilers or fryers, back, meat and skin, cooked, stewed',
#  'Chicken, broilers or fryers, back, meat and skin, raw',
#  'Chicken, broilers or fryers, back, meat only, cooked, fried',
#  'Chicken, broilers or fryers, back, meat only, cooked, roasted',
#  'Chicken, broilers or fryers, back, meat only, cooked, rotisserie, original seasoning',
#  'Chicken, broilers or fryers, back, meat only, cooked, stewed',
#  'Chicken, broilers or fryers, back, meat only, raw',
#  'Chicken, broilers or fryers, breast, meat and skin, cooked, fried, batter',
#  'Chicken, broilers or fryers, breast, meat and skin, cooked, fried, flour',
#  'Chicken, broilers or fryers, breast, meat and skin, cooked, roasted',
#  'Chicken, broilers or fryers, breast, meat and skin, cooked, rotisserie, original seasoning',
#  'Chicken, broilers or fryers, breast, meat and skin, cooked, stewed',
#  'Chicken, broilers or fryers, breast, meat and skin, raw',
#  'Chicken, broilers or fryers, breast, meat only, cooked, fried',
#  'Chicken, broilers or fryers, breast, meat only, cooked, roasted',
#  'Chicken, broilers or fryers, breast, meat only, cooked, rotisserie, original seasoning',
#  'Chicken, broilers or fryers, breast, meat only, cooked, stewed',
#  'Chicken, broilers or fryers, breast, meat only, raw',
#  'Chicken, broilers or fryers, breast, meat only, raw, enhanced',
#  'Chicken, broilers or fryers, dark meat, meat and skin, cooked, fried, batter',
#  'Chicken, broilers or fryers, dark meat, meat and skin, cooked, fried, flour',
#  'Chicken, broilers or fryers, dark meat, meat and skin, cooked, roasted',
#  'Chicken, broilers or fryers, dark meat, meat and skin, cooked, stewed',
#  'Chicken, broilers or fryers, dark meat, meat and skin, raw',
#  'Chicken, broilers or fryers, dark meat, meat only, cooked, fried',
#  'Chicken, broilers or fryers, dark meat, meat only, cooked, roasted',
#  'Chicken, broilers or fryers, dark meat, meat only, cooked, stewed',
#  'Chicken, broilers or fryers, dark meat, meat only, raw',
#  'Chicken, broilers or fryers, drumstick, meat and skin, cooked, fried, batter',
#  'Chicken, broilers or fryers, drumstick, meat and skin, cooked, fried, flour',
#  'Chicken, broilers or fryers, drumstick, meat and skin, cooked, roasted',
#  'Chicken, broilers or fryers, drumstick, meat and skin, cooked, rotisserie, original seasoning',
#  'Chicken, broilers or fryers, drumstick, meat and skin, cooked, stewed',
#  'Chicken, broilers or fryers, drumstick, meat and skin, raw',
#  'Chicken, broilers or fryers, drumstick, meat only, cooked, fried',
#  'Chicken, broilers or fryers, drumstick, meat only, cooked, roasted',
#  'Chicken, broilers or fryers, drumstick, meat only, cooked, rotisserie, original seasoning',
#  'Chicken, broilers or fryers, drumstick, meat only, cooked, stewed',
#  'Chicken, broilers or fryers, drumstick, meat only, raw',
#  'Chicken, broilers or fryers, giblets, cooked, fried',
#  'Chicken, broilers or fryers, giblets, cooked, simmered',
#  'Chicken, broilers or fryers, giblets, raw',
#  'Chicken, broilers or fryers, leg, meat and skin, cooked, fried, batter',
#  'Chicken, broilers or fryers, leg, meat and skin, cooked, fried, flour',
#  'Chicken, broilers or fryers, leg, meat and skin, cooked, roasted',
#  'Chicken, broilers or fryers, leg, meat and skin, cooked, stewed',
#  'Chicken, broilers or fryers, leg, meat and skin, raw',
#  'Chicken, broilers or fryers, leg, meat only, cooked, fried',
#  'Chicken, broilers or fryers, leg, meat only, cooked, roasted',
#  'Chicken, broilers or fryers, leg, meat only, cooked, stewed',
#  'Chicken, broilers or fryers, leg, meat only, raw',
#  'Chicken, broilers or fryers, light meat, meat and skin, cooked, fried, batter',
#  'Chicken, broilers or fryers, light meat, meat and skin, cooked, fried, flour',
#  'Chicken, broilers or fryers, light meat, meat and skin, cooked, roasted',
#  'Chicken, broilers or fryers, light meat, meat and skin, cooked, stewed',
#  'Chicken, broilers or fryers, light meat, meat and skin, raw',
#  'Chicken, broilers or fryers, light meat, meat only, cooked, fried',
#  'Chicken, broilers or fryers, light meat, meat only, cooked, roasted',
#  'Chicken, broilers or fryers, light meat, meat only, cooked, stewed',
#  'Chicken, broilers or fryers, light meat, meat only, raw',
#  'Chicken, broilers or fryers, meat and skin and giblets and neck, cooked, fried, batter',
#  'Chicken, broilers or fryers, meat and skin and giblets and neck, cooked, fried, flour',
#  'Chicken, broilers or fryers, meat and skin and giblets and neck, raw',
#  'Chicken, broilers or fryers, meat and skin and giblets and neck, roasted',
#  'Chicken, broilers or fryers, meat and skin and giblets and neck, stewed',
#  'Chicken, broilers or fryers, meat and skin, cooked, fried, batter',
#  'Chicken, broilers or fryers, meat and skin, cooked, fried, flour',
#  'Chicken, broilers or fryers, meat and skin, cooked, roasted',
#  'Chicken, broilers or fryers, meat and skin, cooked, stewed',
#  'Chicken, broilers or fryers, meat and skin, raw',
#  'Chicken, broilers or fryers, meat only, cooked, fried',
#  'Chicken, broilers or fryers, meat only, raw',
#  'Chicken, broilers or fryers, meat only, roasted',
#  'Chicken, broilers or fryers, meat only, stewed',
#  'Chicken, broilers or fryers, neck, meat and skin, cooked simmered',
#  'Chicken, broilers or fryers, neck, meat and skin, cooked, fried, batter',
#  'Chicken, broilers or fryers, neck, meat and skin, cooked, fried, flour',
#  'Chicken, broilers or fryers, neck, meat and skin, raw',
#  'Chicken, broilers or fryers, neck, meat only, cooked, fried',
#  'Chicken, broilers or fryers, neck, meat only, cooked, simmered',
#  'Chicken, broilers or fryers, neck, meat only, raw',
#  'Chicken, broilers or fryers, skin only, cooked, fried, batter',
#  'Chicken, broilers or fryers, skin only, cooked, fried, flour',
#  'Chicken, broilers or fryers, skin only, cooked, roasted',
#  'Chicken, broilers or fryers, skin only, cooked, rotisserie, original seasoning',
#  'Chicken, broilers or fryers, skin only, cooked, stewed',
#  'Chicken, broilers or fryers, skin only, raw',
#  'Chicken, broilers or fryers, thigh, meat and skin, cooked, fried, batter',
#  'Chicken, broilers or fryers, thigh, meat and skin, cooked, fried, flour',
#  'Chicken, broilers or fryers, thigh, meat and skin, cooked, roasted',
#  'Chicken, broilers or fryers, thigh, meat and skin, cooked, rotisserie, original seasoning',
#  'Chicken, broilers or fryers, thigh, meat and skin, cooked, stewed',
#  'Chicken, broilers or fryers, thigh, meat and skin, raw',
#  'Chicken, broilers or fryers, thigh, meat only, cooked, fried',
#  'Chicken, broilers or fryers, thigh, meat only, cooked, roasted',
#  'Chicken, broilers or fryers, thigh, meat only, cooked, rotisserie, original seasoning',
#  'Chicken, broilers or fryers, thigh, meat only, cooked, stewed',
#  'Chicken, broilers or fryers, thigh, meat only, raw',
#  'Chicken, broilers or fryers, wing, meat and skin, cooked, fried, batter',
#  'Chicken, broilers or fryers, wing, meat and skin, cooked, fried, flour',
#  'Chicken, broilers or fryers, wing, meat and skin, cooked, roasted',
#  'Chicken, broilers or fryers, wing, meat and skin, cooked, rotisserie, original seasoning',
#  'Chicken, broilers or fryers, wing, meat and skin, cooked, stewed',
#  'Chicken, broilers or fryers, wing, meat and skin, raw',
#  'Chicken, broilers or fryers, wing, meat only, cooked, fried',
#  'Chicken, broilers or fryers, wing, meat only, cooked, roasted',
#  'Chicken, broilers or fryers, wing, meat only, cooked, rotisserie, original seasoning',
#  'Chicken, broilers or fryers, wing, meat only, cooked, stewed',
#  'Chicken, broilers or fryers, wing, meat only, raw',
#  'Chicken, canned, meat only, with broth',
#  'Chicken, canned, no broth',
#  'Chicken, capons, giblets, cooked, simmered',
#  'Chicken, capons, giblets, raw',
#  'Chicken, capons, meat and skin and giblets and neck, cooked, roasted',
#  'Chicken, capons, meat and skin and giblets and neck, raw',
#  'Chicken, capons, meat and skin, cooked, roasted',
#  'Chicken, capons, meat and skin, raw',
#  'Chicken, cornish game hens, meat and skin, cooked, roasted',
#  'Chicken, cornish game hens, meat and skin, raw',
#  'Chicken, cornish game hens, meat only, cooked, roasted',
#  'Chicken, cornish game hens, meat only, raw',
#  'Chicken, feet, boiled',
#  'Chicken, gizzard, all classes, cooked, simmered',
#  'Chicken, gizzard, all classes, raw',
#  'Chicken, ground, crumbles, cooked, pan-browned',
#  'Chicken, ground, raw',
#  'Chicken, heart, all classes, cooked, simmered',
#  'Chicken, heart, all classes, raw',
#  'Chicken, liver, all classes, cooked, pan-fried',
#  'Chicken, liver, all classes, cooked, simmered',
#  'Chicken, liver, all classes, raw',
#  'Chicken, roasting, dark meat, meat only, cooked, roasted',
#  'Chicken, roasting, dark meat, meat only, raw',
#  'Chicken, roasting, giblets, cooked, simmered',
#  'Chicken, roasting, giblets, raw',
#  'Chicken, roasting, light meat, meat only, cooked, roasted',
#  'Chicken, roasting, light meat, meat only, raw',
#  'Chicken, roasting, meat and skin and giblets and neck, cooked, roasted',
#  'Chicken, roasting, meat and skin and giblets and neck, raw',
#  'Chicken, roasting, meat and skin, cooked, roasted',
#  'Chicken, roasting, meat and skin, raw',
#  'Chicken, roasting, meat only, cooked, roasted',
#  'Chicken, roasting, meat only, raw',
#  'Chicken, stewing, dark meat, meat only, cooked, stewed',
#  'Chicken, stewing, dark meat, meat only, raw',
#  'Chicken, stewing, giblets, cooked, simmered',
#  'Chicken, stewing, giblets, raw',
#  'Chicken, stewing, light meat, meat only, cooked, stewed',
#  'Chicken, stewing, light meat, meat only, raw',
#  'Chicken, stewing, meat and skin, and giblets and neck, cooked, stewed',
#  'Chicken, stewing, meat and skin, and giblets and neck, raw',
#  'Chicken, stewing, meat and skin, cooked, stewed',
#  'Chicken, stewing, meat and skin, raw',
#  'Chicken, stewing, meat only, cooked, stewed',
#  'Chicken, stewing, meat only, raw',
#  'Chicken, wing, frozen, glazed, barbecue flavored',
#  'Chicken, wing, frozen, glazed, barbecue flavored, heated (conventional oven)',
#  'Chicken, wing, frozen, glazed, barbecue flavored, heated (microwave)',
#  'Dove, cooked (includes squab)',
#  'Duck, domesticated, liver, raw',
#  'Duck, domesticated, meat and skin, cooked, roasted',
#  'Duck, domesticated, meat and skin, raw',
#  'Duck, domesticated, meat only, cooked, roasted',
#  'Duck, domesticated, meat only, raw',
#  'Duck, wild, breast, meat only, raw',
#  'Duck, wild, meat and skin, raw',
#  'Duck, young duckling, domesticated, White Pekin, breast, meat and skin, boneless, cooked, roasted',
#  'Duck, young duckling, domesticated, White Pekin, breast, meat only, boneless, cooked without skin, broiled',
#  'Duck, young duckling, domesticated, White Pekin, leg, meat and skin, bone in, cooked, roasted',
#  'Duck, young duckling, domesticated, White Pekin, leg, meat only, bone in, cooked without skin, braised',
#  'Emu, fan fillet, cooked, broiled',
#  'Emu, fan fillet, raw',
#  'Emu, flat fillet, raw',
#  'Emu, full rump, cooked, broiled',
#  'Emu, full rump, raw',
#  'Emu, ground, cooked, pan-broiled',
#  'Emu, ground, raw',
#  'Emu, inside drum, raw',
#  'Emu, inside drums, cooked, broiled',
#  'Emu, outside drum, raw',
#  'Emu, oyster, raw',
#  'Emu, top loin, cooked, broiled',
#  'Goose, domesticated, meat and skin, cooked, roasted',
#  'Goose, domesticated, meat and skin, raw',
#  'Goose, domesticated, meat only, cooked, roasted',
#  'Goose, domesticated, meat only, raw',
#  'Goose, liver, raw',
#  'Ground Turkey, fat free, raw',
#  'Ground turkey, 85% lean, 15% fat, pan-broiled crumbles',
#  'Ground turkey, 85% lean, 15% fat, patties, broiled',
#  'Ground turkey, 85% lean, 15% fat, raw',
#  'Ground turkey, 93% lean, 7% fat, pan-broiled crumbles',
#  'Ground turkey, 93% lean, 7% fat, patties, broiled',
#  'Ground turkey, 93% lean, 7% fat, raw',
#  'Ground turkey, fat free, pan-broiled crumbles',
#  'Ground turkey, fat free, patties, broiled',
#  'Guinea hen, meat and skin, raw',
#  'Guinea hen, meat only, raw',
#  'Ostrich, fan, raw',
#  'Ostrich, ground, cooked, pan-broiled',
#  'Ostrich, ground, raw',
#  'Ostrich, inside leg, cooked',
#  'Ostrich, inside leg, raw',
#  'Ostrich, inside strip, cooked',
#  'Ostrich, inside strip, raw',
#  'Ostrich, outside leg, raw',
#  'Ostrich, outside strip, cooked',
#  'Ostrich, outside strip, raw',
#  'Ostrich, oyster, cooked',
#  'Ostrich, oyster, raw',
#  'Ostrich, round, raw',
#  'Ostrich, tenderloin, raw',
#  'Ostrich, tip trimmed, cooked',
#  'Ostrich, tip trimmed, raw',
#  'Ostrich, top loin, cooked',
#  'Ostrich, top loin, raw',
#  'Pate de foie gras, canned (goose liver pate), smoked',
#  'Pheasant, breast, meat only, raw',
#  'Pheasant, cooked, total edible',
#  'Pheasant, leg, meat only, raw',
#  'Pheasant, raw, meat and skin',
#  'Pheasant, raw, meat only',
#  'Poultry food products, ground turkey, cooked',
#  'Poultry food products, ground turkey, raw',
#  'Poultry, mechanically deboned, from backs and necks with skin, raw',
#  'Poultry, mechanically deboned, from backs and necks without skin, raw',
#  'Poultry, mechanically deboned, from mature hens, raw',
#  'Quail, breast, meat only, raw',
#  'Quail, cooked, total edible',
#  'Quail, meat and skin, raw',
#  'Quail, meat only, raw',
#  'Squab, (pigeon), light meat without skin, raw',
#  'Squab, (pigeon), meat and skin, raw',
#  'Squab, (pigeon), meat only, raw',
#  'Turkey bacon, cooked',
#  'Turkey breast, pre-basted, meat and skin, cooked, roasted',
#  'Turkey patties, breaded, battered, fried',
#  'Turkey roast, boneless, frozen, seasoned, light and dark meat, raw',
#  'Turkey roast, boneless, frozen, seasoned, light and dark meat, roasted',
#  'Turkey sticks, breaded, battered, fried',
#  'Turkey thigh, pre-basted, meat and skin, cooked, roasted',
#  'Turkey, all classes, back, meat and skin, cooked, roasted',
#  'Turkey, all classes, back, meat and skin, raw',
#  'Turkey, all classes, breast, meat and skin, cooked, roasted',
#  'Turkey, all classes, breast, meat and skin, raw',
#  'Turkey, all classes, dark meat, cooked, roasted',
#  'Turkey, all classes, dark meat, meat and skin, cooked, roasted',
#  'Turkey, all classes, dark meat, meat and skin, raw',
#  'Turkey, all classes, dark meat, raw',
#  'Turkey, all classes, giblets, cooked, simmered, some giblet fat',
#  'Turkey, all classes, giblets, raw',
#  'Turkey, all classes, leg, meat and skin, cooked, roasted',
#  'Turkey, all classes, leg, meat and skin, raw',
#  'Turkey, all classes, light meat, cooked, roasted',
#  'Turkey, all classes, light meat, meat and skin, cooked, roasted',
#  'Turkey, all classes, light meat, meat and skin, raw',
#  'Turkey, all classes, light meat, raw',
#  'Turkey, all classes, meat and skin and giblets and neck, cooked, roasted',
#  'Turkey, all classes, meat and skin and giblets and neck, raw',
#  'Turkey, all classes, meat and skin, cooked, roasted',
#  'Turkey, all classes, meat and skin, raw',
#  'Turkey, all classes, meat only, cooked, roasted',
#  'Turkey, all classes, meat only, raw',
#  'Turkey, all classes, neck, meat only, cooked, simmered',
#  'Turkey, all classes, neck, meat only, raw',
#  'Turkey, all classes, skin only, cooked, roasted',
#  'Turkey, all classes, skin only, raw',
#  'Turkey, all classes, wing, meat and skin, cooked, roasted',
#  'Turkey, all classes, wing, meat and skin, raw',
#  'Turkey, canned, meat only, with broth',
#  'Turkey, diced, light and dark meat, seasoned',
#  'Turkey, drumstick, smoked, cooked, with skin, bone removed',
#  'Turkey, fryer-roasters, back, meat and skin, cooked, roasted',
#  'Turkey, fryer-roasters, back, meat and skin, raw',
#  'Turkey, fryer-roasters, back, meat only, cooked, roasted',
#  'Turkey, fryer-roasters, back, meat only, raw',
#  'Turkey, fryer-roasters, breast, meat and skin, cooked, roasted',
#  'Turkey, fryer-roasters, breast, meat and skin, raw',
#  'Turkey, fryer-roasters, breast, meat only, cooked, roasted',
#  'Turkey, fryer-roasters, breast, meat only, raw',
#  'Turkey, fryer-roasters, dark meat, meat and skin, cooked, roasted',
#  'Turkey, fryer-roasters, dark meat, meat and skin, raw',
#  'Turkey, fryer-roasters, dark meat, meat only, cooked, roasted',
#  'Turkey, fryer-roasters, dark meat, meat only, raw',
#  'Turkey, fryer-roasters, leg, meat and skin, cooked, roasted',
#  'Turkey, fryer-roasters, leg, meat and skin, raw',
#  'Turkey, fryer-roasters, leg, meat only, cooked, roasted',
#  'Turkey, fryer-roasters, leg, meat only, raw',
#  'Turkey, fryer-roasters, light meat, meat and skin, cooked, roasted',
#  'Turkey, fryer-roasters, light meat, meat and skin, raw',
#  'Turkey, fryer-roasters, light meat, meat only, cooked, roasted',
#  'Turkey, fryer-roasters, light meat, meat only, raw',
#  'Turkey, fryer-roasters, meat and skin and giblets and neck, cooked, roasted',
#  'Turkey, fryer-roasters, meat and skin and giblets and neck, raw',
#  'Turkey, fryer-roasters, meat and skin, cooked, roasted',
#  'Turkey, fryer-roasters, meat and skin, raw',
#  'Turkey, fryer-roasters, meat only, cooked, roasted',
#  'Turkey, fryer-roasters, meat only, raw',
#  'Turkey, fryer-roasters, skin only, cooked, roasted',
#  'Turkey, fryer-roasters, skin only, raw',
#  'Turkey, fryer-roasters, wing, meat and skin, cooked, roasted',
#  'Turkey, fryer-roasters, wing, meat and skin, raw',
#  'Turkey, fryer-roasters, wing, meat only, cooked, roasted',
#  'Turkey, fryer-roasters, wing, meat only, raw',
#  'Turkey, gizzard, all classes, cooked, simmered',
#  'Turkey, gizzard, all classes, raw',
#  'Turkey, heart, all classes, cooked, simmered',
#  'Turkey, heart, all classes, raw',
#  'Turkey, light or dark meat, smoked, cooked, skin and bone removed',
#  'Turkey, light or dark meat, smoked, cooked, with skin, bone removed',
#  'Turkey, liver, all classes, cooked, simmered',
#  'Turkey, liver, all classes, raw',
#  'Turkey, mechanically deboned, from turkey frames, raw',
#  'Turkey, wing, smoked, cooked, with skin, bone removed',
#  'Turkey, young hen, back, meat and skin, cooked, roasted',
#  'Turkey, young hen, back, meat and skin, raw',
#  'Turkey, young hen, breast, meat and skin, cooked, roasted',
#  'Turkey, young hen, breast, meat and skin, raw',
#  'Turkey, young hen, dark meat, meat and skin, cooked, roasted',
#  'Turkey, young hen, dark meat, meat and skin, raw',
#  'Turkey, young hen, dark meat, meat only, cooked, roasted',
#  'Turkey, young hen, dark meat, meat only, raw',
#  'Turkey, young hen, leg, meat and skin, cooked, roasted',
#  'Turkey, young hen, leg, meat and skin, raw',
#  'Turkey, young hen, light meat, meat and skin, cooked, roasted',
#  'Turkey, young hen, light meat, meat and skin, raw',
#  'Turkey, young hen, light meat, meat only, cooked, roasted',
#  'Turkey, young hen, light meat, meat only, raw',
#  'Turkey, young hen, meat and skin and giblets and neck, cooked, roasted',
#  'Turkey, young hen, meat and skin and giblets and neck, raw',
#  'Turkey, young hen, meat and skin, cooked, roasted',
#  'Turkey, young hen, meat and skin, raw',
#  'Turkey, young hen, meat only, cooked, roasted',
#  'Turkey, young hen, meat only, raw',
#  'Turkey, young hen, skin only, cooked, roasted',
#  'Turkey, young hen, skin only, raw',
#  'Turkey, young hen, wing, meat and skin, cooked, roasted',
#  'Turkey, young hen, wing, meat and skin, raw',
#  'Turkey, young tom, back, meat and skin, cooked, roasted',
#  'Turkey, young tom, back, meat and skin, raw',
#  'Turkey, young tom, breast, meat and skin, cooked, roasted',
#  'Turkey, young tom, breast, meat and skin, raw',
#  'Turkey, young tom, dark meat, meat and skin, cooked, roasted',
#  'Turkey, young tom, dark meat, meat and skin, raw',
#  'Turkey, young tom, dark meat, meat only, cooked, roasted',
#  'Turkey, young tom, dark meat, meat only, raw',
#  'Turkey, young tom, leg, meat and skin, cooked, roasted',
#  'Turkey, young tom, leg, meat and skin, raw',
#  'Turkey, young tom, light meat, meat and skin, cooked, roasted',
#  'Turkey, young tom, light meat, meat and skin, raw',
#  'Turkey, young tom, light meat, meat only, cooked, roasted',
#  'Turkey, young tom, light meat, meat only, raw',
#  'Turkey, young tom, meat and skin and giblets and neck, cooked, roasted',
#  'Turkey, young tom, meat and skin and giblets and neck, raw',
#  'Turkey, young tom, meat and skin, cooked, roasted',
#  'Turkey, young tom, meat and skin, raw',
#  'Turkey, young tom, meat only, cooked, roasted',
#  'Turkey, young tom, meat only, raw',
#  'Turkey, young tom, skin only, cooked, roasted',
#  'Turkey, young tom, skin only, raw',
#  'Turkey, young tom, wing, meat and skin, cooked, roasted',
#  'Turkey, young tom, wing, meat and skin, raw',
#  'USDA Commodity Chicken, canned, meat only, drained',
#  'USDA Commodity, Chicken, canned, meat only, with broth',
#  'USDA Commodity, Chicken, canned, meat only, with water',
#  'USDA Commodity, chicken fajita strips, frozen',
#  'USDA Commodity, turkey ham, dark meat, smoked, frozen',
#  'USDA Commodity, turkey taco meat, frozen, cooked',
#  'Gravy, brown, dry',
#  'Gravy, chicken, dry',
#  'Gravy, instant turkey, dry',
#  'Gravy, mushroom, dry, powder',
#  'Gravy, turkey, dry',
#  'Gravy, unspecified type, dry',
#  'Sauce, alfredo mix, dry',
#  'Sauce, cheese, dry, powder',
#  'Sauce, sofrito, prepared from recipe',
#  'Soup, beef broth or bouillon, powder, dry',
#  'Soup, beef broth, cubed, dry',
#  'Soup, beef noodle, dry, mix',
#  'Soup, bouillon cubes and granules, low sodium, dry',
#  'Soup, chicken broth cubes, dry',
#  'Soup, chicken broth or bouillon, dry',
#  'Soup, chicken noodle, dry, mix',
#  'Soup, ramen noodle, any flavor, dry',
#  'Soup, ramen noodle, beef flavor, dry',
#  'Soup, ramen noodle, chicken flavor, dry',
#  'Soup, ramen noodle, dry, any flavor, reduced fat, reduced sodium',
#  'Soup, tomato vegetable, dry, mix',
#  'BUTCHER BOY MEATS, INC., Turkey Franks',
#  'Bacon and beef sticks',
#  'Barbecue loaf, pork, beef',
#  'Beef sausage, fresh, cooked',
#  'Beef sausage, pre-cooked',
#  'Beef, bologna, reduced sodium',
#  'Beef, cured, corned beef, canned',
#  'Beef, cured, dried',
#  'Beef, cured, luncheon meat, jellied',
#  'Beef, cured, pastrami',
#  'Beef, cured, sausage, cooked, smoked',
#  'Beef, cured, smoked, chopped beef',
#  'Beef, cured, thin-sliced beef',
#  'Beerwurst, beer salami, pork',
#  'Beerwurst, beer salami, pork and beef',
#  'Beerwurst, pork and beef',
#  'Blood sausage',
#  'Bockwurst, pork, veal, raw',
#  'Bologna, beef',
#  'Bologna, beef and pork',
#  'Bologna, beef and pork, low fat',
#  'Bologna, beef, low fat',
#  'Bologna, chicken, pork',
#  'Bologna, chicken, pork, beef',
#  'Bologna, pork',
#  'Bologna, pork and turkey, lite',
#  'Bologna, pork, turkey and beef',
#  'Bologna, turkey',
#  'Bratwurst, beef and pork, smoked',
#  'Bratwurst, chicken, cooked',
#  'Bratwurst, pork, beef and turkey, lite, smoked',
#  'Bratwurst, pork, cooked',
#  'Bratwurst, veal, cooked',
#  'Braunschweiger (a liver sausage), pork',
#  'Brotwurst, pork, beef, link',
#  'CARL BUDDIG, Cooked Corned Beef, Chopped, Pressed',
#  'CARL BUDDIG, Smoked Sliced Beef',
#  'CARL BUDDIG, Smoked Sliced Chicken, light and dark meat',
#  'CARL BUDDIG, Smoked Sliced Ham',
#  'CARL BUDDIG, Smoked Sliced Turkey, light and dark meat',
#  'CARL BUDDIG. Cooked Smoked Beef Pastrami, Chopped, Pressed',
#  'Cheesefurter, cheese smokie, pork, beef',
#  'Chicken breast, fat-free, mesquite flavor, sliced',
#  'Chicken breast, oven-roasted, fat-free, sliced',
#  'Chicken roll, light meat',
#  'Chicken spread',
#  'Chorizo, pork and beef',
#  'Corned beef loaf, jellied',
#  'Dutch brand loaf, chicken, pork and beef',
#  'Frankfurter, beef',
#  'Frankfurter, beef and pork',
#  'Frankfurter, beef and pork, low fat',
#  'Frankfurter, beef, heated',
#  'Frankfurter, beef, low fat',
#  'Frankfurter, beef, pork, and turkey, fat free',
#  'Frankfurter, chicken',
#  'Frankfurter, low sodium',
#  'Frankfurter, meat',
#  'Frankfurter, meat and poultry, low fat',
#  'Frankfurter, pork',
#  'Frankfurter, turkey',
#  'HORMEL Pillow Pak Sliced Turkey Pepperoni',
#  'HORMEL SPAM, Lite Luncheon Meat, Pork and chicken, minced, canned, ascorbic acid added',
#  'HORMEL SPAM, Luncheon Meat, pork with ham, minced, canned',
#  'HORMEL WRANGLER Beef Franks',
#  'Ham and cheese loaf or roll',
#  'Ham and cheese spread',
#  'Ham, chopped, canned',
#  'Ham, chopped, not canned',
#  'Ham, honey, smoked, cooked',
#  'Ham, minced',
#  'Ham, sliced, extra lean',
#  'Ham, sliced, regular (approximately 11% fat)',
#  'Headcheese, pork',
#  'Honey loaf, pork, beef',
#  'Honey roll sausage, beef',
#  'Kielbasa, Polish, turkey and beef, smoked',
#  'Kielbasa, kolbassy, pork, beef, nonfat dry milk added',
#  'Knackwurst, knockwurst, pork, beef',
#  'LOUIS RICH, Chicken (white, oven roasted)',
#  'LOUIS RICH, Chicken Breast (oven roasted deluxe)',
#  'LOUIS RICH, Chicken Breast Classic Baked /Grill (carving board)',
#  'LOUIS RICH, Franks (turkey and chicken cheese)',
#  'LOUIS RICH, Franks (turkey and chicken)',
#  'LOUIS RICH, Turkey (honey roasted, fat free)',
#  'LOUIS RICH, Turkey Bacon',
#  'LOUIS RICH, Turkey Bologna',
#  'LOUIS RICH, Turkey Breast (Smoked, Carving Board)',
#  'LOUIS RICH, Turkey Breast (oven roasted, fat free)',
#  'LOUIS RICH, Turkey Breast (oven roasted, portion fat free)',
#  'LOUIS RICH, Turkey Breast (smoked, portion fat free)',
#  'LOUIS RICH, Turkey Breast and White Turkey (oven roasted)',
#  'LOUIS RICH, Turkey Breast and White Turkey (smoked sliced)',
#  'LOUIS RICH, Turkey Ham (10% water added)',
#  'LOUIS RICH, Turkey Nuggets/Sticks (breaded)',
#  'LOUIS RICH, Turkey Salami',
#  'LOUIS RICH, Turkey Salami Cotto',
#  'LOUIS RICH, Turkey Smoked Sausage',
#  'Lebanon bologna, beef',
#  'Liver cheese, pork',
#  'Liver sausage, liverwurst, pork',
#  'Liverwurst spread',
#  'Luncheon meat, beef, loaved',
#  'Luncheon meat, beef, thin sliced',
#  'Luncheon meat, pork and chicken, minced, canned, includes SPAM Lite',
#  'Luncheon meat, pork with ham, minced, canned, includes SPAM (Hormel)',
#  'Luncheon meat, pork, beef',
#  'Luncheon meat, pork, canned',
#  'Luncheon meat, pork, ham, and chicken, minced, canned, reduced sodium, added ascorbic acid, includes SPAM, 25% less sodium',
#  'Luncheon sausage, pork and beef',
#  'Luxury loaf, pork',
#  'Macaroni and cheese loaf, chicken, pork and beef',
#  'Mortadella, beef, pork',
#  "Mother's loaf, pork",
#  'New england brand sausage, pork, beef',
#  'OSCAR MAYER, Bologna (beef light)',
#  'OSCAR MAYER, Bologna (beef)',
#  'OSCAR MAYER, Bologna (chicken, pork, beef)',
#  'OSCAR MAYER, Bologna (fat free)',
#  'OSCAR MAYER, Bologna Light (pork, chicken, beef)',
#  'OSCAR MAYER, Braunschweiger Liver Sausage (saren tube)',
#  'OSCAR MAYER, Braunschweiger Liver Sausage (sliced)',
#  'OSCAR MAYER, Chicken Breast (honey glazed)',
#  'OSCAR MAYER, Chicken Breast (oven roasted, fat free)',
#  'OSCAR MAYER, Ham (40% ham/water product, smoked, fat free)',
#  'OSCAR MAYER, Ham (chopped with natural juice)',
#  'OSCAR MAYER, Ham (water added, baked cooked 96% fat free)',
#  'OSCAR MAYER, Ham (water added, boiled)',
#  'OSCAR MAYER, Ham (water added, honey)',
#  'OSCAR MAYER, Ham (water added, smoked, cooked)',
#  'OSCAR MAYER, Ham and Cheese Loaf',
#  'OSCAR MAYER, Head Cheese',
#  'OSCAR MAYER, Liver Cheese, pork fat wrapped',
#  'OSCAR MAYER, Luncheon Loaf (spiced)',
#  'OSCAR MAYER, Old Fashioned Loaf',
#  'OSCAR MAYER, Pork Sausage Links (cooked)',
#  'OSCAR MAYER, Salami (Genoa)',
#  'OSCAR MAYER, Salami (for beer)',
#  'OSCAR MAYER, Salami (hard)',
#  'OSCAR MAYER, Salami Beef Cotto',
#  'OSCAR MAYER, Salami Cotto (beef, pork, chicken)',
#  'OSCAR MAYER, Smokie Links Sausage',
#  'OSCAR MAYER, Smokies (beef)',
#  'OSCAR MAYER, Smokies (cheese)',
#  'OSCAR MAYER, Smokies Sausage Little (pork, turkey)',
#  'OSCAR MAYER, Smokies Sausage Little Cheese (pork, turkey)',
#  'OSCAR MAYER, Summer Sausage Beef Thuringer Cervelat',
#  'OSCAR MAYER, Summer Sausage Thuringer Cervalat',
#  'OSCAR MAYER, Turkey Breast (smoked, fat free)',
#  'OSCAR MAYER, Wieners (beef franks)',
#  'OSCAR MAYER, Wieners (beef franks, bun length)',
#  'OSCAR MAYER, Wieners (beef franks, fat free)',
#  'OSCAR MAYER, Wieners (beef franks, light)',
#  'OSCAR MAYER, Wieners (cheese hot dogs with turkey)',
#  'OSCAR MAYER, Wieners (fat free hot dogs)',
#  'OSCAR MAYER, Wieners (light pork, turkey, beef)',
#  'OSCAR MAYER, Wieners (pork, turkey)',
#  'OSCAR MAYER, Wieners Little (pork, turkey)',
#  'OSCAR MAYER. Bologna (Wisconsin made ring)',
#  'Olive loaf, pork',
#  'Oven-roasted chicken breast roll',
#  'Pastrami, beef, 98% fat-free',
#  'Pastrami, turkey',
#  'Pate, chicken liver, canned',
#  'Pate, goose liver, smoked, canned',
#  'Pate, liver, not specified, canned',
#  'Pate, truffle flavor',
#  'Peppered loaf, pork, beef',
#  'Pepperoni, pork, beef',
#  'Pickle and pimiento loaf, pork',
#  'Picnic loaf, pork, beef',
#  'Polish sausage, pork',
#  'Pork and beef sausage, fresh, cooked',
#  'Pork and turkey sausage, pre-cooked',
#  'Pork sausage rice links, brown and serve, cooked',
#  'Pork sausage, fresh, cooked',
#  'Pork sausage, fresh, raw',
#  'Pork sausage, pre-cooked',
#  'Poultry salad sandwich spread',
#  'Roast beef spread',
#  'Salami, Italian, pork',
#  'Salami, Italian, pork and beef, dry, sliced, 50% less sodium',
#  'Salami, cooked, beef',
#  'Salami, cooked, beef and pork',
#  'Salami, cooked, turkey',
#  'Salami, dry or hard, pork',
#  'Salami, dry or hard, pork, beef',
#  'Salami, pork, beef, less sodium',
#  'Sausage, Berliner, pork, beef',
#  'Sausage, Italian, pork, cooked',
#  'Sausage, Italian, pork, raw',
#  'Sausage, Italian, sweet, links',
#  'Sausage, Italian, turkey, smoked',
#  'Sausage, Polish, beef with chicken, hot',
#  'Sausage, Polish, pork and beef, smoked',
#  'Sausage, Vienna, canned, chicken, beef, pork',
#  'Sausage, chicken and beef, smoked',
#  'Sausage, chicken, beef, pork, skinless, smoked',
#  'Sausage, pork and beef, with cheddar cheese, smoked',
#  'Sausage, smoked link sausage, pork and beef',
#  'Sausage, summer, pork and beef, sticks, with cheddar cheese',
#  'Sausage, turkey, breakfast links, mild',
#  'Sausage, turkey, hot, smoked',
#  'Smoked link sausage, pork',
#  'Smoked link sausage, pork and beef, flour and nonfat dry milk added',
#  'Smoked link sausage, pork and beef, nonfat dry milk added',
#  'Swisswurst, pork and beef, with swiss cheese, smoked',
#  'Thuringer, cervelat, summer sausage, beef, pork',
#  'Turkey and pork sausage, fresh, bulk, patty or link, cooked',
#  'Turkey breast meat',
#  'Turkey breast, low salt, prepackaged or deli, luncheon meat',
#  'Turkey ham, cured turkey thigh meat',
#  'Turkey ham, sliced, extra lean, prepackaged or deli-sliced',
#  'Turkey roll, light and dark meat',
#  'Turkey roll, light meat',
#  'Turkey sausage, fresh, cooked',
#  'Turkey sausage, fresh, raw',
#  'Turkey sausage, reduced fat, brown and serve, cooked (include BUTTERBALL breakfast links turkey sausage)',
#  'Turkey, breast, smoked, lemon pepper flavor, 97% fat-free',
#  'Turkey, pork, and beef sausage, reduced fat, smoked',
#  'Turkey, white, rotisserie, deli cut',
#  'USDA Commodity, luncheon meat, canned',
#  'USDA Commodity, pork sausage, bulk/links/patties, frozen, raw',
#  'USDA Commodity, pork, sausage, bulk/links/patties, frozen, cooked',
#  'Yachtwurst, with pistachio nuts, cooked',
#  'AMARANTH FLAKES',
#  'Cereals ready-to-eat, GENERAL MILLS, CHEERIOS',
#  'Cereals ready-to-eat, GENERAL MILLS, GENERAL MILLS Berry Burst CHEERIOS, all flavors',
#  'Cereals ready-to-eat, GENERAL MILLS, HARMONY',
#  'Cereals ready-to-eat, GENERAL MILLS, HONEY NUT CHEERIOS',
#  'Cereals ready-to-eat, GENERAL MILLS, Wheat CHEX',
#  'Cereals ready-to-eat, HEALTH VALLEY, FIBER 7 Flakes',
#  'Cereals ready-to-eat, KASHI 7 Whole Grain Flakes',
#  'Cereals ready-to-eat, KASHI 7 Whole Grain Honey Puffs',
#  'Cereals ready-to-eat, KASHI 7 Whole Grain Nuggets',
#  'Cereals ready-to-eat, KASHI GO LEAN CRUNCH!, Honey Almond Flax',
#  'Cereals ready-to-eat, KASHI GOLEAN',
#  'Cereals ready-to-eat, KASHI GOLEAN CRUNCH!',
#  'Cereals ready-to-eat, KASHI GRANOLA, COCOA BEACH Cereal',
#  'Cereals ready-to-eat, KASHI GRANOLA, Mountain Medley Cereal',
#  'Cereals ready-to-eat, KASHI GRANOLA, ORCHARD SPICE CEREAL',
#  'Cereals ready-to-eat, KASHI GRANOLA, Summer Berry Cereal',
#  'Cereals ready-to-eat, KASHI HEART TO HEART, Honey Toasted Oat',
#  'Cereals ready-to-eat, KASHI Heart to Heart Warm Cinnamon',
#  'Cereals ready-to-eat, KASHI MIGHTY BITES, Honey Crunch Cereal',
#  'Cereals ready-to-eat, KASHI ORGANIC PROMISE Island Vanilla Biscuit',
#  'Cereals ready-to-eat, KASHI, HEART TO HEART, Wild Blueberry',
#  'Cereals ready-to-eat, KASHI, Kashi U',
#  "Cereals ready-to-eat, KELLOGG'S, SPECIAL K Low Carb Lifestyle Protein Plus",
#  'Cereals ready-to-eat, KELLOGG, All-Bran Strawberry Medley',
#  "Cereals ready-to-eat, KELLOGG, KELLOGG'S ALL-BRAN Original",
#  "Cereals ready-to-eat, KELLOGG, KELLOGG'S ALL-BRAN WITH EXTRA FIBER",
#  "Cereals ready-to-eat, KELLOGG, KELLOGG'S ALL-BRAN Yogurt Bites",
#  "Cereals ready-to-eat, KELLOGG, KELLOGG'S COMPLETE Wheat Flakes",
#  "Cereals ready-to-eat, KELLOGG, KELLOGG'S Complete Oat Bran Flakes",
#  "Cereals ready-to-eat, KELLOGG, KELLOGG'S FROSTED MINI-WHEATS, bite size",
#  "Cereals ready-to-eat, KELLOGG, KELLOGG'S Puffed Wheat",
#  "Cereals ready-to-eat, KELLOGG, KELLOGG'S SPECIAL K",
#  "Cereals ready-to-eat, KELLOGG, KELLOGG'S Shredded Wheat Miniatures",
#  "Cereals ready-to-eat, KELLOGG, KELLOGG'S Special K low fat granola",
#  'Cereals ready-to-eat, KELLOGG, SMART START Strong Heart, Maple Brown Sugar',
#  'Cereals ready-to-eat, KELLOGG, Smart Start Strong Heart, Original',
#  'Cereals ready-to-eat, MALT-O-MEAL, Puffed Wheat Cereal',
#  "Cereals ready-to-eat, MALT-O-MEAL, TOASTY O'S",
#  "Cereals ready-to-eat, NATURE'S PATH, OPTIMUM",
#  "Cereals ready-to-eat, NATURE'S PATH, OPTIMUM SLIM",
#  'Cereals ready-to-eat, OAT BRAN FLAKES, HEALTH VALLEY',
#  'Cereals ready-to-eat, POST, 100% Bran Cereal',
#  'Cereals ready-to-eat, POST, GRAPE-NUTS Cereal',
#  'Cereals ready-to-eat, POST, GRAPE-NUTS Flakes',
#  "Cereals ready-to-eat, POST, Shredded Wheat n' Bran, spoon-size",
#  'Cereals ready-to-eat, POST, Shredded Wheat, spoon-size',
#  'Cereals ready-to-eat, Puffed KASHI',
#  'Cereals ready-to-eat, QUAKER, 100% Natural Granola Oats and Honey',
#  'Cereals ready-to-eat, QUAKER, KRETSCHMER Honey Crunch Wheat Germ',
#  'Cereals ready-to-eat, QUAKER, KRETSCHMER Toasted Wheat Bran',
#  'Cereals ready-to-eat, QUAKER, KRETSCHMER Wheat Germ, Regular',
#  "Cereals ready-to-eat, QUAKER, MOTHER'S CINNAMON OAT CRUNCH",
#  "Cereals ready-to-eat, QUAKER, MOTHER'S TOASTED OAT BRAN CEREAL, Brown Sugar Flavor",
#  'Cereals ready-to-eat, QUAKER, QUAKER CINNAMON OATMEAL SQUARES',
#  'Cereals ready-to-eat, QUAKER, QUAKER OATMEAL SQUARES',
#  'Cereals ready-to-eat, QUAKER, QUAKER Oat Bran Cereal',
#  'Cereals ready-to-eat, QUAKER, QUAKER Puffed Wheat',
#  'Cereals ready-to-eat, QUAKER, SUN COUNTRY Granola with Almonds',
#  'Cereals ready-to-eat, QUAKER, Shredded Wheat, bagged cereal',
#  'Cereals ready-to-eat, Ralston Enriched Bran flakes',
#  'Cereals ready-to-eat, Ralston TASTEEOS',
#  'Cereals ready-to-eat, UNCLE SAM CEREAL',
#  'Cereals ready-to-eat, WEETABIX WHOLE WHEAT CEREAL',
#  'Cereals ready-to-eat, granola, homemade',
#  'Cereals ready-to-eat, wheat and malt barley flakes',
#  'Cereals ready-to-eat, wheat germ, toasted, plain',
#  'Cereals ready-to-eat, wheat, puffed, fortified',
#  'Cereals ready-to-eat, wheat, shredded, plain, sugar and salt free',
#  'Cereals, CREAM OF WHEAT, 1 minute cook time, dry',
#  'Cereals, CREAM OF WHEAT, instant, dry',
#  'Cereals, CREAM OF WHEAT, regular, 10 minute cooking, dry',
#  'Cereals, Cream of Wheat, 2 1/2 minute cook time, dry',
#  'Cereals, KASHI GO LEAN Hot Cereal, Hearty Honey & Cinnamon, dry',
#  'Cereals, KASHI HEART TO HEART, Instant Oatmeal, Apple Cinnamon, dry',
#  'Cereals, KASHI HEART TO HEART, Instant Oatmeal, maple, dry',
#  'Cereals, KASHI, KASHI GO LEAN Hot Cereal, Truly Vanilla, dry',
#  'Cereals, MALT-O-MEAL, Farina Hot Wheat Cereal, dry',
#  'Cereals, MALT-O-MEAL, chocolate, dry',
#  'Cereals, MALT-O-MEAL, plain, dry',
#  'Cereals, MALTEX, dry',
#  'Cereals, MAYPO, dry',
#  'Cereals, QUAKER, Instant Grits Product with Imitation Bacon Bits and Cheddar Flavor, Dry',
#  "Cereals, QUAKER, Instant Grits Product--Ham 'n' Cheese",
#  'Cereals, QUAKER, Instant Oatmeal, low sodium, dry',
#  "Cereals, QUAKER, Mother's Instant Oatmeal (Non-Fortified), Dry",
#  "Cereals, QUAKER, Oat Bran, QUAKER/MOTHER'S Oat Bran, dry",
#  'Cereals, QUAKER, QUAKER MultiGrain Oatmeal, dry',
#  'Cereals, QUAKER, Quick Oats, Dry',
#  'Cereals, QUAKER, Scotch Barley, regular and quick, dry',
#  'Cereals, QUAKER, farina, Creamy Wheat, enriched, dry',
#  'Cereals, QUAKER, farina, enriched cinnamon flavor, dry',
#  'Cereals, RALSTON, dry',
#  'Cereals, ROMAN MEAL, plain, dry',
#  'Cereals, WHEATENA, dry',
#  'Cereals, farina, enriched, assorted brands including CREAM OF WHEAT, quick (1-3 minutes), dry',
#  'Cereals, farina, unenriched, dry',
#  'Cereals, oats, instant, fortified, plain, dry',
#  'Cereals, oats, regular and quick and instant, not fortified, dry',
#  'Cereals, ready-to-eat, ALPEN',
#  'Cereals, whole wheat hot natural cereal, dry',
#  'Incaparina, dry mix (corn and soy flours), unprepared',
#  'KASHI GOLEAN Crisp Toasted Berry Crumble',
#  'Millet, puffed',
#  'HORMEL ALWAYS TENDER, Boneless Pork Loin, Fresh Pork',
#  'HORMEL ALWAYS TENDER, Center Cut Chops, Fresh Pork',
#  'HORMEL ALWAYS TENDER, Pork Loin Filets, Lemon Garlic-Flavored',
#  'HORMEL ALWAYS TENDER, Pork Tenderloin, Peppercorn-Flavored',
#  'HORMEL ALWAYS TENDER, Pork Tenderloin, Teriyaki-Flavored',
#  'HORMEL Canadian Style Bacon',
#  'HORMEL, Cure 81 Ham',
#  'Pork, Leg Cap Steak, boneless, separable lean and fat, raw',
#  'Pork, Leg sirloin tip roast, boneless, separable lean and fat, cooked, braised',
#  'Pork, Leg sirloin tip roast, boneless, separable lean and fat, raw',
#  'Pork, Shoulder breast, boneless, separable lean and fat, cooked, broiled',
#  'Pork, Shoulder breast, boneless, separable lean and fat, raw',
#  'Pork, Shoulder petite tender, boneless, separable lean and fat, raw',
#  'Pork, cured, bacon, cooked, baked',
#  'Pork, cured, bacon, cooked, broiled, pan-fried or roasted',
#  'Pork, cured, bacon, cooked, broiled, pan-fried or roasted, reduced sodium',
#  'Pork, cured, bacon, cooked, microwaved',
#  'Pork, cured, bacon, cooked, pan-fried',
#  'Pork, cured, bacon, raw',
#  'Pork, cured, breakfast strips, cooked',
#  'Pork, cured, breakfast strips, raw or unheated',
#  'Pork, cured, canadian-style bacon, grilled',
#  'Pork, cured, canadian-style bacon, unheated',
#  'Pork, cured, feet, pickled',
#  'Pork, cured, ham -- water added, rump, bone-in, separable lean and fat, heated, roasted',
#  'Pork, cured, ham -- water added, rump, bone-in, separable lean and fat, unheated',
#  'Pork, cured, ham -- water added, rump, bone-in, separable lean only, heated, roasted',
#  'Pork, cured, ham -- water added, rump, bone-in, separable lean only, unheated',
#  'Pork, cured, ham -- water added, shank, bone-in, separable lean and fat, heated, roasted',
#  'Pork, cured, ham -- water added, shank, bone-in, separable lean and fat, unheated',
#  'Pork, cured, ham -- water added, shank, bone-in, separable lean only, heated, roasted',
#  'Pork, cured, ham -- water added, shank, bone-in, separable lean only, unheated',
#  'Pork, cured, ham -- water added, slice, bone-in, separable lean and fat, heated, pan-broil',
#  'Pork, cured, ham -- water added, slice, bone-in, separable lean and fat, unheated',
#  'Pork, cured, ham -- water added, slice, bone-in, separable lean only, heated, pan-broil',
#  'Pork, cured, ham -- water added, slice, bone-in, separable lean only, unheated',
#  'Pork, cured, ham -- water added, slice, boneless, separable lean and fat, heated, pan-broil',
#  'Pork, cured, ham -- water added, slice, boneless, separable lean only, heated, pan-broil',
#  'Pork, cured, ham -- water added, whole, boneless, separable lean and fat, heated, roasted',
#  'Pork, cured, ham -- water added, whole, boneless, separable lean and fat, unheated',
#  'Pork, cured, ham -- water added, whole, boneless, separable lean only, heated, roasted',
#  'Pork, cured, ham -- water added, whole, boneless, separable lean only, unheated',
#  'Pork, cured, ham and water product, rump, bone-in, separable lean and fat, heated, roasted',
#  'Pork, cured, ham and water product, rump, bone-in, separable lean and fat, unheated',
#  'Pork, cured, ham and water product, rump, bone-in, separable lean only, heated, roasted',
#  'Pork, cured, ham and water product, rump, bone-in, separable lean only, unheated',
#  'Pork, cured, ham and water product, shank, bone-in, separable lean and fat, heated, roasted',
#  'Pork, cured, ham and water product, shank, bone-in, separable lean and fat, unheated',
#  'Pork, cured, ham and water product, shank, bone-in, separable lean only, heated, roasted',
#  ...]

# %% [markdown]
# # API Call

# %%
import requests
import pandas as pd
from config import API_KEY
from pprint import pprint

# %%
vegetables1 = "ndbno=11011&ndbno=11080&ndbno=11090&ndbno=11109&ndbno=11124&ndbno=11135&ndbno=11143&\
            ndbno=11167&ndbno=11205&ndbno=11210"
vegetables2 = "&ndbno=11238&ndbno=11248&ndbno=11253&ndbno=11294&ndbno=11304&ndbno=11333&ndbno=11357&ndbno=11484&ndbno=11695&\
            ndbno=11959&ndbno=11932&ndbno=11705&ndbno=11215&ndbno=11233&ndbno=11007"
grains = "ndbno=28319&ndbno=20062&ndbno=20014&ndbno=20016&ndbno=20044&ndbno=20135&ndbno=20649&ndbno=20091&ndbno=20657&ndbno=20120&ndbno=12147&ndbno=12586&ndbno=12104&ndbno=12155&ndbno=12063&ndbno=20648&ndbno=18017&ndbno=18260&ndbno=18351&ndbno=21611&ndbno=42265&ndbno=42261&ndbno=28326&ndbno=20036"
dairy = "ndbno=01004&ndbno=01040&ndbno=01132&ndbno=01001&ndbno=01009&ndbno=01053&ndbno=01082&ndbno=01117&ndbno=01287&ndbno=01323&ndbno=01229&ndbno=01145&ndbno=01159&ndbno=01057&ndbno=01077&ndbno=01032&ndbno=01012&ndbno=01015&ndbno=01017&ndbno=01019&ndbno=01026&ndbno=01056&ndbno=01107&ndbno=01252&ndbno=01293"
meats = "ndbno=13346&ndbno=22908&ndbno=07073&ndbno=19002&ndbno=07007&ndbno=23090&ndbno=13330&ndbno=13317&ndbno=07068&ndbno=07921&ndbno=13926&ndbno=23136&ndbno=13148&ndbno=07033&ndbno=10153&ndbno=10870&ndbno=15085&ndbno=15084&ndbno=15266&ndbno=15128&ndbno=35157&ndbno=15005&ndbno=15009&ndbno=15017&ndbno=15040"
fruit="ndbno=09003&ndbno=09252&ndbno=09236&ndbno=09226&ndbno=09050&ndbno=09316&ndbno=09040&ndbno=09148&ndbno=09200&ndbno=09037&ndbno=09111&ndbno=09131&ndbno=09070&ndbno=09150&ndbno=09176&ndbno=09159&ndbno=09279&ndbno=09326&ndbno=09302"

# %%
veg_query_url = f"https://api.nal.usda.gov/ndb/V2/reports?{vegetables1}{vegetables2}&type=b&format=json&api_key={API_KEY}"
grain_query_url = f"https://api.nal.usda.gov/ndb/V2/reports?{grains}&type=b&format=json&api_key={API_KEY}"
dairy_query_url = f"https://api.nal.usda.gov/ndb/V2/reports?{dairy}&type=b&format=json&api_key={API_KEY}"
meats_query_url = f"https://api.nal.usda.gov/ndb/V2/reports?{meats}&type=b&format=json&api_key={API_KEY}"
fruit_query_url = f"https://api.nal.usda.gov/ndb/V2/reports?{fruit}&type=b&format=json&api_key={API_KEY}"

# %%
query_url=[veg_query_url,grain_query_url,dairy_query_url,meats_query_url,fruit_query_url]
category=['vegetables','grains','dairy','meats','fruit']
food_items = []
response = requests.get(query_url[4])
response_json = response.json()
foods = response_json['foods']
foods
# Out:
# [{'food': {'sr': '1',
#    'type': 'b',
#    'desc': {'ndbno': '09003',
#     'name': "Apples, raw, with skin (Includes foods for USDA's Food Distribution Program)",
#     'ds': 'Standard Reference',
#     'manu': '',
#     'ru': 'g'},
#    'nutrients': [{'nutrient_id': '255',
#      'name': 'Water',
#      'derivation': 'NONE',
#      'group': 'Proximates',
#      'unit': 'g',
#      'value': '85.56',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '106.95'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '93.26'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '190.80'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '155.72'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '127.48'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '86.42'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '207.06'}]},
#     {'nutrient_id': '208',
#      'name': 'Energy',
#      'derivation': 'NC',
#      'group': 'Proximates',
#      'unit': 'kcal',
#      'value': '52',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '65'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '57'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '116'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '95'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '77'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '53'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '126'}]},
#     {'nutrient_id': '203',
#      'name': 'Protein',
#      'derivation': 'NONE',
#      'group': 'Proximates',
#      'unit': 'g',
#      'value': '0.26',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.33'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.28'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.58'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.47'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.39'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.26'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.63'}]},
#     {'nutrient_id': '204',
#      'name': 'Total lipid (fat)',
#      'derivation': 'NONE',
#      'group': 'Proximates',
#      'unit': 'g',
#      'value': '0.17',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.21'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.19'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.38'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.31'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.25'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.17'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.41'}]},
#     {'nutrient_id': '205',
#      'name': 'Carbohydrate, by difference',
#      'derivation': 'NC',
#      'group': 'Proximates',
#      'unit': 'g',
#      'value': '13.81',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '17.26'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '15.05'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '30.80'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '25.13'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '20.58'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '13.95'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '33.42'}]},
#     {'nutrient_id': '291',
#      'name': 'Fiber, total dietary',
#      'derivation': 'NONE',
#      'group': 'Proximates',
#      'unit': 'g',
#      'value': '2.4',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '3.0'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '2.6'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '5.4'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '4.4'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '3.6'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '2.4'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '5.8'}]},
#     {'nutrient_id': '269',
#      'name': 'Sugars, total',
#      'derivation': 'NONE',
#      'group': 'Proximates',
#      'unit': 'g',
#      'value': '10.39',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '12.99'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '11.33'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '23.17'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '18.91'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '15.48'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '10.49'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '25.14'}]},
#     {'nutrient_id': '301',
#      'name': 'Calcium, Ca',
#      'derivation': 'NONE',
#      'group': 'Minerals',
#      'unit': 'mg',
#      'value': '6',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '8'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '7'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '13'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '11'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '9'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '6'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '15'}]},
#     {'nutrient_id': '303',
#      'name': 'Iron, Fe',
#      'derivation': 'NONE',
#      'group': 'Minerals',
#      'unit': 'mg',
#      'value': '0.12',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.15'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.13'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.27'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.22'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.18'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.12'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.29'}]},
#     {'nutrient_id': '304',
#      'name': 'Magnesium, Mg',
#      'derivation': 'NONE',
#      'group': 'Minerals',
#      'unit': 'mg',
#      'value': '5',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '6'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '5'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '11'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '9'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '7'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '5'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '12'}]},
#     {'nutrient_id': '305',
#      'name': 'Phosphorus, P',
#      'derivation': 'NONE',
#      'group': 'Minerals',
#      'unit': 'mg',
#      'value': '11',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '14'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '12'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '25'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '20'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '16'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '11'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '27'}]},
#     {'nutrient_id': '306',
#      'name': 'Potassium, K',
#      'derivation': 'NONE',
#      'group': 'Minerals',
#      'unit': 'mg',
#      'value': '107',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '134'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '117'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '239'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '195'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '159'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '108'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '259'}]},
#     {'nutrient_id': '307',
#      'name': 'Sodium, Na',
#      'derivation': 'NONE',
#      'group': 'Minerals',
#      'unit': 'mg',
#      'value': '1',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '1'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '1'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '2'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '2'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '1'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '1'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '2'}]},
#     {'nutrient_id': '309',
#      'name': 'Zinc, Zn',
#      'derivation': 'NONE',
#      'group': 'Minerals',
#      'unit': 'mg',
#      'value': '0.04',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.05'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.04'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.09'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.07'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.06'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.04'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.10'}]},
#     {'nutrient_id': '401',
#      'name': 'Vitamin C, total ascorbic acid',
#      'derivation': 'NONE',
#      'group': 'Vitamins',
#      'unit': 'mg',
#      'value': '4.6',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '5.8'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '5.0'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '10.3'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '8.4'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '6.9'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '4.6'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '11.1'}]},
#     {'nutrient_id': '404',
#      'name': 'Thiamin',
#      'derivation': 'NONE',
#      'group': 'Vitamins',
#      'unit': 'mg',
#      'value': '0.017',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.021'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.019'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.038'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.031'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.025'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.017'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.041'}]},
#     {'nutrient_id': '405',
#      'name': 'Riboflavin',
#      'derivation': 'NONE',
#      'group': 'Vitamins',
#      'unit': 'mg',
#      'value': '0.026',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.033'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.028'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.058'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.047'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.039'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.026'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.063'}]},
#     {'nutrient_id': '406',
#      'name': 'Niacin',
#      'derivation': 'NONE',
#      'group': 'Vitamins',
#      'unit': 'mg',
#      'value': '0.091',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.114'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.099'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.203'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.166'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.136'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.092'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.220'}]},
#     {'nutrient_id': '415',
#      'name': 'Vitamin B-6',
#      'derivation': 'NONE',
#      'group': 'Vitamins',
#      'unit': 'mg',
#      'value': '0.041',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.051'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.045'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.091'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.075'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.061'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.041'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.099'}]},
#     {'nutrient_id': '435',
#      'name': 'Folate, DFE',
#      'derivation': 'NC',
#      'group': 'Vitamins',
#      'unit': 'µg',
#      'value': '3',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '4'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '3'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '7'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '5'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '4'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '3'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '7'}]},
#     {'nutrient_id': '418',
#      'name': 'Vitamin B-12',
#      'derivation': 'NONE',
#      'group': 'Vitamins',
#      'unit': 'µg',
#      'value': '0.00',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.00'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.00'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.00'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.00'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.00'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.00'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.00'}]},
#     {'nutrient_id': '320',
#      'name': 'Vitamin A, RAE',
#      'derivation': 'AS',
#      'group': 'Vitamins',
#      'unit': 'µg',
#      'value': '3',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '4'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '3'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '7'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '5'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '4'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '3'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '7'}]},
#     {'nutrient_id': '318',
#      'name': 'Vitamin A, IU',
#      'derivation': 'AS',
#      'group': 'Vitamins',
#      'unit': 'IU',
#      'value': '54',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '68'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '59'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '120'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '98'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '80'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '55'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '131'}]},
#     {'nutrient_id': '323',
#      'name': 'Vitamin E (alpha-tocopherol)',
#      'derivation': 'NONE',
#      'group': 'Vitamins',
#      'unit': 'mg',
#      'value': '0.18',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.23'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.20'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.40'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.33'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.27'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.18'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.44'}]},
#     {'nutrient_id': '328',
#      'name': 'Vitamin D (D2 + D3)',
#      'derivation': 'NONE',
#      'group': 'Vitamins',
#      'unit': 'µg',
#      'value': '0.0',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.0'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.0'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.0'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.0'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.0'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.0'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.0'}]},
#     {'nutrient_id': '324',
#      'name': 'Vitamin D',
#      'derivation': 'NONE',
#      'group': 'Vitamins',
#      'unit': 'IU',
#      'value': '0',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'}]},
#     {'nutrient_id': '430',
#      'name': 'Vitamin K (phylloquinone)',
#      'derivation': 'NONE',
#      'group': 'Vitamins',
#      'unit': 'µg',
#      'value': '2.2',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '2.8'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '2.4'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '4.9'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '4.0'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '3.3'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '2.2'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '5.3'}]},
#     {'nutrient_id': '606',
#      'name': 'Fatty acids, total saturated',
#      'derivation': 'NC',
#      'group': 'Lipids',
#      'unit': 'g',
#      'value': '0.028',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.035'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.031'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.062'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.051'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.042'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.028'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.068'}]},
#     {'nutrient_id': '645',
#      'name': 'Fatty acids, total monounsaturated',
#      'derivation': 'NC',
#      'group': 'Lipids',
#      'unit': 'g',
#      'value': '0.007',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.009'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.008'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.016'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.013'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.010'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.007'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.017'}]},
#     {'nutrient_id': '646',
#      'name': 'Fatty acids, total polyunsaturated',
#      'derivation': 'NC',
#      'group': 'Lipids',
#      'unit': 'g',
#      'value': '0.051',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.064'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.056'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.114'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.093'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.076'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.052'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.123'}]},
#     {'nutrient_id': '605',
#      'name': 'Fatty acids, total trans',
#      'derivation': 'NONE',
#      'group': 'Lipids',
#      'unit': 'g',
#      'value': '0.000',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.000'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.000'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.000'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.000'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.000'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.000'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.000'}]},
#     {'nutrient_id': '601',
#      'name': 'Cholesterol',
#      'derivation': 'NONE',
#      'group': 'Lipids',
#      'unit': 'mg',
#      'value': '0',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'}]},
#     {'nutrient_id': '262',
#      'name': 'Caffeine',
#      'derivation': 'NONE',
#      'group': 'Other',
#      'unit': 'mg',
#      'value': '0',
#      'measures': [{'label': 'cup, quartered or chopped',
#        'eqv': 125.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'},
#       {'label': 'cup slices',
#        'eqv': 109.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'},
#       {'label': 'large (3-1/4" dia)',
#        'eqv': 223.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'},
#       {'label': 'medium (3" dia)',
#        'eqv': 182.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'},
#       {'label': 'small (2-3/4" dia)',
#        'eqv': 149.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'},
#       {'label': 'extra small (2-1/2" dia)',
#        'eqv': 101.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'},
#       {'label': 'NLEA serving',
#        'eqv': 242.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'}]}],
#    'footnotes': [{'id': 'b',
#      'desc': '3 and 5 pound bags of apples typically contain small and extra small sizes.'},
#     {'id': 'a',
#      'desc': 'Based on analytical data for red delicious, golden delicious, gala, granny smith, and fuji varieties.'}]}},
#  {'food': {'sr': '1',
#    'type': 'b',
#    'desc': {'ndbno': '09252',
#     'name': 'Pears, raw',
#     'ds': 'Standard Reference',
#     'manu': '',
#     'ru': 'g'},
#    'nutrients': [{'nutrient_id': '255',
#      'name': 'Water',
#      'derivation': 'NONE',
#      'group': 'Proximates',
#      'unit': 'g',
#      'value': '83.96',
#      'measures': [{'label': 'cup, slices',
#        'eqv': 140.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '117.54'},
#       {'label': 'cup, cubes',
#        'eqv': 161.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '135.18'},
#       {'label': 'small',
#        'eqv': 148.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '124.26'},
#       {'label': 'medium',
#        'eqv': 178.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '149.45'},
#       {'label': 'large',
#        'eqv': 230.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '193.11'},
#       {'label': 'NLEA serving',
#        'eqv': 166.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '139.37'}]},
#     {'nutrient_id': '208',
#      'name': 'Energy',
#      'derivation': 'NC',
#      'group': 'Proximates',
#      'unit': 'kcal',
#      'value': '57',
#      'measures': [{'label': 'cup, slices',
#        'eqv': 140.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '80'},
#       {'label': 'cup, cubes',
#        'eqv': 161.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '92'},
#       {'label': 'small',
#        'eqv': 148.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '84'},
#       {'label': 'medium',
#        'eqv': 178.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '101'},
#       {'label': 'large',
#        'eqv': 230.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '131'},
#       {'label': 'NLEA serving',
#        'eqv': 166.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '95'}]},
#     {'nutrient_id': '203',
#      'name': 'Protein',
#      'derivation': 'NONE',
#      'group': 'Proximates',
#      'unit': 'g',
#      'value': '0.36',
#      'measures': [{'label': 'cup, slices',
#        'eqv': 140.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.50'},
#       {'label': 'cup, cubes',
#        'eqv': 161.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.58'},
#       {'label': 'small',
#        'eqv': 148.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.53'},
#       {'label': 'medium',
#        'eqv': 178.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.64'},
#       {'label': 'large',
#        'eqv': 230.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.83'},
#       {'label': 'NLEA serving',
#        'eqv': 166.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.60'}]},
#     {'nutrient_id': '204',
#      'name': 'Total lipid (fat)',
#      'derivation': 'NONE',
#      'group': 'Proximates',
#      'unit': 'g',
#      'value': '0.14',
#      'measures': [{'label': 'cup, slices',
#        'eqv': 140.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.20'},
#       {'label': 'cup, cubes',
#        'eqv': 161.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.23'},
#       {'label': 'small',
#        'eqv': 148.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.21'},
#       {'label': 'medium',
#        'eqv': 178.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.25'},
#       {'label': 'large',
#        'eqv': 230.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.32'},
#       {'label': 'NLEA serving',
#        'eqv': 166.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.23'}]},
#     {'nutrient_id': '205',
#      'name': 'Carbohydrate, by difference',
#      'derivation': 'NC',
#      'group': 'Proximates',
#      'unit': 'g',
#      'value': '15.23',
#      'measures': [{'label': 'cup, slices',
#        'eqv': 140.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '21.32'},
#       {'label': 'cup, cubes',
#        'eqv': 161.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '24.52'},
#       {'label': 'small',
#        'eqv': 148.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '22.54'},
#       {'label': 'medium',
#        'eqv': 178.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '27.11'},
#       {'label': 'large',
#        'eqv': 230.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '35.03'},
#       {'label': 'NLEA serving',
#        'eqv': 166.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '25.28'}]},
#     {'nutrient_id': '291',
#      'name': 'Fiber, total dietary',
#      'derivation': 'NONE',
#      'group': 'Proximates',
#      'unit': 'g',
#      'value': '3.1',
#      'measures': [{'label': 'cup, slices',
#        'eqv': 140.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '4.3'},
#       {'label': 'cup, cubes',
#        'eqv': 161.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '5.0'},
#       {'label': 'small',
#        'eqv': 148.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '4.6'},
#       {'label': 'medium',
#        'eqv': 178.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '5.5'},
#       {'label': 'large',
#        'eqv': 230.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '7.1'},
#       {'label': 'NLEA serving',
#        'eqv': 166.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '5.1'}]},
#     {'nutrient_id': '269',
#      'name': 'Sugars, total',
#      'derivation': 'NONE',
#      'group': 'Proximates',
#      'unit': 'g',
#      'value': '9.75',
#      'measures': [{'label': 'cup, slices',
#        'eqv': 140.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '13.65'},
#       {'label': 'cup, cubes',
#        'eqv': 161.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '15.70'},
#       {'label': 'small',
#        'eqv': 148.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '14.43'},
#       {'label': 'medium',
#        'eqv': 178.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '17.36'},
#       {'label': 'large',
#        'eqv': 230.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '22.43'},
#       {'label': 'NLEA serving',
#        'eqv': 166.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '16.18'}]},
#     {'nutrient_id': '301',
#      'name': 'Calcium, Ca',
#      'derivation': 'NONE',
#      'group': 'Minerals',
#      'unit': 'mg',
#      'value': '9',
#      'measures': [{'label': 'cup, slices',
#        'eqv': 140.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '13'},
#       {'label': 'cup, cubes',
#        'eqv': 161.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '14'},
#       {'label': 'small',
#        'eqv': 148.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '13'},
#       {'label': 'medium',
#        'eqv': 178.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '16'},
#       {'label': 'large',
#        'eqv': 230.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '21'},
#       {'label': 'NLEA serving',
#        'eqv': 166.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '15'}]},
#     {'nutrient_id': '303',
#      'name': 'Iron, Fe',
#      'derivation': 'NONE',
#      'group': 'Minerals',
#      'unit': 'mg',
#      'value': '0.18',
#      'measures': [{'label': 'cup, slices',
#        'eqv': 140.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.25'},
#       {'label': 'cup, cubes',
#        'eqv': 161.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.29'},
#       {'label': 'small',
#        'eqv': 148.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.27'},
#       {'label': 'medium',
#        'eqv': 178.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.32'},
#       {'label': 'large',
#        'eqv': 230.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.41'},
#       {'label': 'NLEA serving',
#        'eqv': 166.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.30'}]},
#     {'nutrient_id': '304',
#      'name': 'Magnesium, Mg',
#      'derivation': 'NONE',
#      'group': 'Minerals',
#      'unit': 'mg',
#      'value': '7',
#      'measures': [{'label': 'cup, slices',
#        'eqv': 140.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '10'},
#       {'label': 'cup, cubes',
#        'eqv': 161.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '11'},
#       {'label': 'small',
#        'eqv': 148.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '10'},
#       {'label': 'medium',
#        'eqv': 178.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '12'},
#       {'label': 'large',
#        'eqv': 230.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '16'},
#       {'label': 'NLEA serving',
#        'eqv': 166.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '12'}]},
#     {'nutrient_id': '305',
#      'name': 'Phosphorus, P',
#      'derivation': 'NONE',
#      'group': 'Minerals',
#      'unit': 'mg',
#      'value': '12',
#      'measures': [{'label': 'cup, slices',
#        'eqv': 140.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '17'},
#       {'label': 'cup, cubes',
#        'eqv': 161.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '19'},
#       {'label': 'small',
#        'eqv': 148.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '18'},
#       {'label': 'medium',
#        'eqv': 178.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '21'},
#       {'label': 'large',
#        'eqv': 230.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '28'},
#       {'label': 'NLEA serving',
#        'eqv': 166.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '20'}]},
#     {'nutrient_id': '306',
#      'name': 'Potassium, K',
#      'derivation': 'NONE',
#      'group': 'Minerals',
#      'unit': 'mg',
#      'value': '116',
#      'measures': [{'label': 'cup, slices',
#        'eqv': 140.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '162'},
#       {'label': 'cup, cubes',
#        'eqv': 161.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '187'},
#       {'label': 'small',
#        'eqv': 148.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '172'},
#       {'label': 'medium',
#        'eqv': 178.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '206'},
#       {'label': 'large',
#        'eqv': 230.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '267'},
#       {'label': 'NLEA serving',
#        'eqv': 166.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '193'}]},
#     {'nutrient_id': '307',
#      'name': 'Sodium, Na',
#      'derivation': 'NONE',
#      'group': 'Minerals',
#      'unit': 'mg',
#      'value': '1',
#      'measures': [{'label': 'cup, slices',
#        'eqv': 140.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '1'},
#       {'label': 'cup, cubes',
#        'eqv': 161.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '2'},
#       {'label': 'small', 'eqv': 148.0, 'eunit': 'g', 'qty': 1.0, 'value': '1'},
#       {'label': 'medium',
#        'eqv': 178.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '2'},
#       {'label': 'large', 'eqv': 230.0, 'eunit': 'g', 'qty': 1.0, 'value': '2'},
#       {'label': 'NLEA serving',
#        'eqv': 166.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '2'}]},
#     {'nutrient_id': '309',
#      'name': 'Zinc, Zn',
#      'derivation': 'NONE',
#      'group': 'Minerals',
#      'unit': 'mg',
#      'value': '0.10',
#      'measures': [{'label': 'cup, slices',
#        'eqv': 140.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.14'},
#       {'label': 'cup, cubes',
#        'eqv': 161.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.16'},
#       {'label': 'small',
#        'eqv': 148.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.15'},
#       {'label': 'medium',
#        'eqv': 178.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.18'},
#       {'label': 'large',
#        'eqv': 230.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.23'},
#       {'label': 'NLEA serving',
#        'eqv': 166.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.17'}]},
#     {'nutrient_id': '401',
#      'name': 'Vitamin C, total ascorbic acid',
#      'derivation': 'NONE',
#      'group': 'Vitamins',
#      'unit': 'mg',
#      'value': '4.3',
#      'measures': [{'label': 'cup, slices',
#        'eqv': 140.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '6.0'},
#       {'label': 'cup, cubes',
#        'eqv': 161.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '6.9'},
#       {'label': 'small',
#        'eqv': 148.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '6.4'},
#       {'label': 'medium',
#        'eqv': 178.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '7.7'},
#       {'label': 'large',
#        'eqv': 230.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '9.9'},
#       {'label': 'NLEA serving',
#        'eqv': 166.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '7.1'}]},
#     {'nutrient_id': '404',
#      'name': 'Thiamin',
#      'derivation': 'NONE',
#      'group': 'Vitamins',
#      'unit': 'mg',
#      'value': '0.012',
#      'measures': [{'label': 'cup, slices',
#        'eqv': 140.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.017'},
#       {'label': 'cup, cubes',
#        'eqv': 161.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.019'},
#       {'label': 'small',
#        'eqv': 148.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.018'},
#       {'label': 'medium',
#        'eqv': 178.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.021'},
#       {'label': 'large',
#        'eqv': 230.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.028'},
#       {'label': 'NLEA serving',
#        'eqv': 166.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.020'}]},
# ...
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '1.48'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '3.74'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '0.23'}]},
#     {'nutrient_id': '204',
#      'name': 'Total lipid (fat)',
#      'derivation': 'NONE',
#      'group': 'Proximates',
#      'unit': 'g',
#      'value': '0.65',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.80'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '2.03'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '0.12'}]},
#     {'nutrient_id': '205',
#      'name': 'Carbohydrate, by difference',
#      'derivation': 'NC',
#      'group': 'Proximates',
#      'unit': 'g',
#      'value': '11.94',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '14.69'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '37.25'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '2.27'}]},
#     {'nutrient_id': '291',
#      'name': 'Fiber, total dietary',
#      'derivation': 'NONE',
#      'group': 'Proximates',
#      'unit': 'g',
#      'value': '6.5',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '8.0'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '20.3'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '1.2'}]},
#     {'nutrient_id': '269',
#      'name': 'Sugars, total',
#      'derivation': 'NONE',
#      'group': 'Proximates',
#      'unit': 'g',
#      'value': '4.42',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '5.44'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '13.79'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '0.84'}]},
#     {'nutrient_id': '301',
#      'name': 'Calcium, Ca',
#      'derivation': 'NONE',
#      'group': 'Minerals',
#      'unit': 'mg',
#      'value': '25',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '31'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '78'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '5'}]},
#     {'nutrient_id': '303',
#      'name': 'Iron, Fe',
#      'derivation': 'NONE',
#      'group': 'Minerals',
#      'unit': 'mg',
#      'value': '0.69',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.85'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '2.15'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '0.13'}]},
#     {'nutrient_id': '304',
#      'name': 'Magnesium, Mg',
#      'derivation': 'NONE',
#      'group': 'Minerals',
#      'unit': 'mg',
#      'value': '22',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '27'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '69'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '4'}]},
#     {'nutrient_id': '305',
#      'name': 'Phosphorus, P',
#      'derivation': 'NONE',
#      'group': 'Minerals',
#      'unit': 'mg',
#      'value': '29',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '36'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '90'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '6'}]},
#     {'nutrient_id': '306',
#      'name': 'Potassium, K',
#      'derivation': 'NONE',
#      'group': 'Minerals',
#      'unit': 'mg',
#      'value': '151',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '186'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '471'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '29'}]},
#     {'nutrient_id': '307',
#      'name': 'Sodium, Na',
#      'derivation': 'NONE',
#      'group': 'Minerals',
#      'unit': 'mg',
#      'value': '1',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '1'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '3'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '0'}]},
#     {'nutrient_id': '309',
#      'name': 'Zinc, Zn',
#      'derivation': 'NONE',
#      'group': 'Minerals',
#      'unit': 'mg',
#      'value': '0.42',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.52'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '1.31'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '0.08'}]},
#     {'nutrient_id': '401',
#      'name': 'Vitamin C, total ascorbic acid',
#      'derivation': 'NONE',
#      'group': 'Vitamins',
#      'unit': 'mg',
#      'value': '26.2',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '32.2'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '81.7'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '5.0'}]},
#     {'nutrient_id': '404',
#      'name': 'Thiamin',
#      'derivation': 'NONE',
#      'group': 'Vitamins',
#      'unit': 'mg',
#      'value': '0.032',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.039'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.100'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '0.006'}]},
#     {'nutrient_id': '405',
#      'name': 'Riboflavin',
#      'derivation': 'NONE',
#      'group': 'Vitamins',
#      'unit': 'mg',
#      'value': '0.038',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.047'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.119'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '0.007'}]},
#     {'nutrient_id': '406',
#      'name': 'Niacin',
#      'derivation': 'NONE',
#      'group': 'Vitamins',
#      'unit': 'mg',
#      'value': '0.598',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.736'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '1.866'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '0.114'}]},
#     {'nutrient_id': '415',
#      'name': 'Vitamin B-6',
#      'derivation': 'NONE',
#      'group': 'Vitamins',
#      'unit': 'mg',
#      'value': '0.055',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.068'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.172'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '0.010'}]},
#     {'nutrient_id': '435',
#      'name': 'Folate, DFE',
#      'derivation': 'NC',
#      'group': 'Vitamins',
#      'unit': 'µg',
#      'value': '21',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '26'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '66'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '4'}]},
#     {'nutrient_id': '418',
#      'name': 'Vitamin B-12',
#      'derivation': 'NONE',
#      'group': 'Vitamins',
#      'unit': 'µg',
#      'value': '0.00',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.00'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.00'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '0.00'}]},
#     {'nutrient_id': '320',
#      'name': 'Vitamin A, RAE',
#      'derivation': 'AS',
#      'group': 'Vitamins',
#      'unit': 'µg',
#      'value': '2',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '2'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '6'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '0'}]},
#     {'nutrient_id': '318',
#      'name': 'Vitamin A, IU',
#      'derivation': 'AS',
#      'group': 'Vitamins',
#      'unit': 'IU',
#      'value': '33',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '41'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '103'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '6'}]},
#     {'nutrient_id': '323',
#      'name': 'Vitamin E (alpha-tocopherol)',
#      'derivation': 'NONE',
#      'group': 'Vitamins',
#      'unit': 'mg',
#      'value': '0.87',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '1.07'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '2.71'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '0.17'}]},
#     {'nutrient_id': '328',
#      'name': 'Vitamin D (D2 + D3)',
#      'derivation': 'NONE',
#      'group': 'Vitamins',
#      'unit': 'µg',
#      'value': '0.0',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.0'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.0'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '0.0'}]},
#     {'nutrient_id': '324',
#      'name': 'Vitamin D',
#      'derivation': 'NONE',
#      'group': 'Vitamins',
#      'unit': 'IU',
#      'value': '0',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '0'}]},
#     {'nutrient_id': '430',
#      'name': 'Vitamin K (phylloquinone)',
#      'derivation': 'NONE',
#      'group': 'Vitamins',
#      'unit': 'µg',
#      'value': '7.8',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '9.6'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '24.3'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '1.5'}]},
#     {'nutrient_id': '606',
#      'name': 'Fatty acids, total saturated',
#      'derivation': 'NC',
#      'group': 'Lipids',
#      'unit': 'g',
#      'value': '0.019',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.023'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.059'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '0.004'}]},
#     {'nutrient_id': '645',
#      'name': 'Fatty acids, total monounsaturated',
#      'derivation': 'NC',
#      'group': 'Lipids',
#      'unit': 'g',
#      'value': '0.064',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.079'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.200'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '0.012'}]},
#     {'nutrient_id': '646',
#      'name': 'Fatty acids, total polyunsaturated',
#      'derivation': 'NC',
#      'group': 'Lipids',
#      'unit': 'g',
#      'value': '0.375',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.461'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '1.170'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '0.071'}]},
#     {'nutrient_id': '605',
#      'name': 'Fatty acids, total trans',
#      'derivation': 'NONE',
#      'group': 'Lipids',
#      'unit': 'g',
#      'value': '0.000',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.000'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0.000'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '0.000'}]},
#     {'nutrient_id': '601',
#      'name': 'Cholesterol',
#      'derivation': 'NONE',
#      'group': 'Lipids',
#      'unit': 'mg',
#      'value': '0',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '0'}]},
#     {'nutrient_id': '262',
#      'name': 'Caffeine',
#      'derivation': 'NONE',
#      'group': 'Other',
#      'unit': 'mg',
#      'value': '0',
#      'measures': [{'label': 'cup',
#        'eqv': 123.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'},
#       {'label': 'pint as purchased, yields',
#        'eqv': 312.0,
#        'eunit': 'g',
#        'qty': 1.0,
#        'value': '0'},
#       {'label': 'raspberries',
#        'eqv': 19.0,
#        'eunit': 'g',
#        'qty': 10.0,
#        'value': '0'}]}],
#    'footnotes': []}}]

# %%
# creating output for one record per nutrient per food
for j in range(5):
    
    response = requests.get(query_url[j])
    response_json = response.json()
    foods = response_json['foods']
    
    for food in foods: 
        
        try:

            i = 0
            for nutrient in food['food']['nutrients']:
                food_item = {}
                food_item['category'] = category[j]
                food_item['name'] = food['food']['desc']['name']
                food_item['id'] = food['food']['desc']['ndbno']
                print(food_item['category'])
                nutrient_name = nutrient['name']
                nutrient_value = nutrient['value']
                nutrient_unit = nutrient['unit']

                food_item['nutrient'] = nutrient_name
                food_item['value'] = nutrient_value
                food_item['unit'] = nutrient_unit

                food_items.append(food_item)

                i = i + 1
                if i > 6:
                    break

        except:
            print("No food:(")
        foods=[]
# Out:
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# vegetables
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# grains
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# dairy
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# meats
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit
# fruit

# %%
len(food_items)
# Out:
# 812

# %%
food_items
# Out:
# [{'category': 'vegetables',
#   'name': 'Asparagus, raw',
#   'id': '11011',
#   'nutrient': 'Water',
#   'value': '93.22',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Asparagus, raw',
#   'id': '11011',
#   'nutrient': 'Energy',
#   'value': '20',
#   'unit': 'kcal'},
#  {'category': 'vegetables',
#   'name': 'Asparagus, raw',
#   'id': '11011',
#   'nutrient': 'Protein',
#   'value': '2.20',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Asparagus, raw',
#   'id': '11011',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.12',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Asparagus, raw',
#   'id': '11011',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '3.88',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Asparagus, raw',
#   'id': '11011',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.1',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Asparagus, raw',
#   'id': '11011',
#   'nutrient': 'Sugars, total',
#   'value': '1.88',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Beets, raw',
#   'id': '11080',
#   'nutrient': 'Water',
#   'value': '87.58',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Beets, raw',
#   'id': '11080',
#   'nutrient': 'Energy',
#   'value': '43',
#   'unit': 'kcal'},
#  {'category': 'vegetables',
#   'name': 'Beets, raw',
#   'id': '11080',
#   'nutrient': 'Protein',
#   'value': '1.61',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Beets, raw',
#   'id': '11080',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.17',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Beets, raw',
#   'id': '11080',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '9.56',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Beets, raw',
#   'id': '11080',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.8',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Beets, raw',
#   'id': '11080',
#   'nutrient': 'Sugars, total',
#   'value': '6.76',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Broccoli, raw',
#   'id': '11090',
#   'nutrient': 'Water',
#   'value': '89.30',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Broccoli, raw',
#   'id': '11090',
#   'nutrient': 'Energy',
#   'value': '34',
#   'unit': 'kcal'},
#  {'category': 'vegetables',
#   'name': 'Broccoli, raw',
#   'id': '11090',
#   'nutrient': 'Protein',
#   'value': '2.82',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Broccoli, raw',
#   'id': '11090',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.37',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Broccoli, raw',
#   'id': '11090',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '6.64',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Broccoli, raw',
#   'id': '11090',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.6',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Broccoli, raw',
#   'id': '11090',
#   'nutrient': 'Sugars, total',
#   'value': '1.70',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Cabbage, raw',
#   'id': '11109',
#   'nutrient': 'Water',
#   'value': '92.18',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Cabbage, raw',
#   'id': '11109',
#   'nutrient': 'Energy',
#   'value': '25',
#   'unit': 'kcal'},
#  {'category': 'vegetables',
#   'name': 'Cabbage, raw',
#   'id': '11109',
#   'nutrient': 'Protein',
#   'value': '1.28',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Cabbage, raw',
#   'id': '11109',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.10',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Cabbage, raw',
#   'id': '11109',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '5.80',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Cabbage, raw',
#   'id': '11109',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.5',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Cabbage, raw',
#   'id': '11109',
#   'nutrient': 'Sugars, total',
#   'value': '3.20',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Carrots, raw',
#   'id': '11124',
#   'nutrient': 'Water',
#   'value': '88.29',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Carrots, raw',
#   'id': '11124',
#   'nutrient': 'Energy',
#   'value': '41',
#   'unit': 'kcal'},
#  {'category': 'vegetables',
#   'name': 'Carrots, raw',
#   'id': '11124',
#   'nutrient': 'Protein',
#   'value': '0.93',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Carrots, raw',
#   'id': '11124',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.24',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Carrots, raw',
#   'id': '11124',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '9.58',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Carrots, raw',
#   'id': '11124',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.8',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Carrots, raw',
#   'id': '11124',
#   'nutrient': 'Sugars, total',
#   'value': '4.74',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Cauliflower, raw',
#   'id': '11135',
#   'nutrient': 'Water',
#   'value': '92.07',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Cauliflower, raw',
#   'id': '11135',
#   'nutrient': 'Energy',
#   'value': '25',
#   'unit': 'kcal'},
#  {'category': 'vegetables',
#   'name': 'Cauliflower, raw',
#   'id': '11135',
#   'nutrient': 'Protein',
#   'value': '1.92',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Cauliflower, raw',
#   'id': '11135',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.28',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Cauliflower, raw',
#   'id': '11135',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '4.97',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Cauliflower, raw',
#   'id': '11135',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.0',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Cauliflower, raw',
#   'id': '11135',
#   'nutrient': 'Sugars, total',
#   'value': '1.91',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Celery, raw',
#   'id': '11143',
#   'nutrient': 'Water',
#   'value': '95.43',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Celery, raw',
#   'id': '11143',
#   'nutrient': 'Energy',
#   'value': '14',
#   'unit': 'kcal'},
#  {'category': 'vegetables',
#   'name': 'Celery, raw',
#   'id': '11143',
#   'nutrient': 'Protein',
#   'value': '0.69',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Celery, raw',
#   'id': '11143',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.17',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Celery, raw',
#   'id': '11143',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '2.97',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Celery, raw',
#   'id': '11143',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.6',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Celery, raw',
#   'id': '11143',
#   'nutrient': 'Sugars, total',
#   'value': '1.34',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Cucumber, with peel, raw',
#   'id': '11205',
#   'nutrient': 'Water',
#   'value': '95.23',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Cucumber, with peel, raw',
#   'id': '11205',
#   'nutrient': 'Energy',
#   'value': '15',
#   'unit': 'kcal'},
#  {'category': 'vegetables',
#   'name': 'Cucumber, with peel, raw',
#   'id': '11205',
#   'nutrient': 'Protein',
#   'value': '0.65',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Cucumber, with peel, raw',
#   'id': '11205',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.11',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Cucumber, with peel, raw',
#   'id': '11205',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '3.63',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Cucumber, with peel, raw',
#   'id': '11205',
#   'nutrient': 'Fiber, total dietary',
#   'value': '0.5',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Cucumber, with peel, raw',
#   'id': '11205',
#   'nutrient': 'Sugars, total',
#   'value': '1.67',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Eggplant, cooked, boiled, drained, without salt',
#   'id': '11210',
#   'nutrient': 'Water',
#   'value': '89.67',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Eggplant, cooked, boiled, drained, without salt',
#   'id': '11210',
#   'nutrient': 'Energy',
#   'value': '35',
#   'unit': 'kcal'},
#  {'category': 'vegetables',
#   'name': 'Eggplant, cooked, boiled, drained, without salt',
#   'id': '11210',
#   'nutrient': 'Protein',
#   'value': '0.83',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Eggplant, cooked, boiled, drained, without salt',
#   'id': '11210',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.23',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Eggplant, cooked, boiled, drained, without salt',
#   'id': '11210',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '8.73',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Eggplant, cooked, boiled, drained, without salt',
#   'id': '11210',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.5',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Eggplant, cooked, boiled, drained, without salt',
#   'id': '11210',
#   'nutrient': 'Sugars, total',
#   'value': '3.20',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Mushrooms, shiitake, raw',
#   'id': '11238',
#   'nutrient': 'Water',
#   'value': '89.74',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Mushrooms, shiitake, raw',
#   'id': '11238',
#   'nutrient': 'Energy',
#   'value': '34',
#   'unit': 'kcal'},
#  {'category': 'vegetables',
#   'name': 'Mushrooms, shiitake, raw',
#   'id': '11238',
#   'nutrient': 'Protein',
#   'value': '2.24',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Mushrooms, shiitake, raw',
#   'id': '11238',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.49',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Mushrooms, shiitake, raw',
#   'id': '11238',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '6.79',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Mushrooms, shiitake, raw',
#   'id': '11238',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.5',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Mushrooms, shiitake, raw',
#   'id': '11238',
#   'nutrient': 'Sugars, total',
#   'value': '2.38',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Lentils, sprouted, raw',
#   'id': '11248',
#   'nutrient': 'Water',
#   'value': '67.34',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Lentils, sprouted, raw',
#   'id': '11248',
#   'nutrient': 'Energy',
#   'value': '106',
#   'unit': 'kcal'},
#  {'category': 'vegetables',
#   'name': 'Lentils, sprouted, raw',
#   'id': '11248',
#   'nutrient': 'Protein',
#   'value': '8.96',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Lentils, sprouted, raw',
#   'id': '11248',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.55',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Lentils, sprouted, raw',
#   'id': '11248',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '22.14',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Lentils, sprouted, raw',
#   'id': '11248',
#   'nutrient': 'Calcium, Ca',
#   'value': '25',
#   'unit': 'mg'},
#  {'category': 'vegetables',
#   'name': 'Lentils, sprouted, raw',
#   'id': '11248',
#   'nutrient': 'Iron, Fe',
#   'value': '3.21',
#   'unit': 'mg'},
#  {'category': 'vegetables',
#   'name': 'Lettuce, green leaf, raw',
#   'id': '11253',
#   'nutrient': 'Water',
#   'value': '94.98',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Lettuce, green leaf, raw',
#   'id': '11253',
#   'nutrient': 'Energy',
#   'value': '15',
#   'unit': 'kcal'},
#  {'category': 'vegetables',
#   'name': 'Lettuce, green leaf, raw',
#   'id': '11253',
#   'nutrient': 'Protein',
#   'value': '1.36',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Lettuce, green leaf, raw',
#   'id': '11253',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.15',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Lettuce, green leaf, raw',
#   'id': '11253',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '2.87',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Lettuce, green leaf, raw',
#   'id': '11253',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.3',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Lettuce, green leaf, raw',
#   'id': '11253',
#   'nutrient': 'Sugars, total',
#   'value': '0.78',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Onions, sweet, raw',
#   'id': '11294',
#   'nutrient': 'Water',
#   'value': '91.24',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Onions, sweet, raw',
#   'id': '11294',
#   'nutrient': 'Energy',
#   'value': '32',
#   'unit': 'kcal'},
#  {'category': 'vegetables',
#   'name': 'Onions, sweet, raw',
#   'id': '11294',
#   'nutrient': 'Protein',
#   'value': '0.80',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Onions, sweet, raw',
#   'id': '11294',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.08',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Onions, sweet, raw',
#   'id': '11294',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '7.55',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Onions, sweet, raw',
#   'id': '11294',
#   'nutrient': 'Fiber, total dietary',
#   'value': '0.9',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Onions, sweet, raw',
#   'id': '11294',
#   'nutrient': 'Sugars, total',
#   'value': '5.02',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Peas, green, raw',
#   'id': '11304',
#   'nutrient': 'Water',
#   'value': '78.86',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Peas, green, raw',
#   'id': '11304',
#   'nutrient': 'Energy',
#   'value': '81',
#   'unit': 'kcal'},
#  {'category': 'vegetables',
#   'name': 'Peas, green, raw',
#   'id': '11304',
#   'nutrient': 'Protein',
#   'value': '5.42',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Peas, green, raw',
#   'id': '11304',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.40',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Peas, green, raw',
#   'id': '11304',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '14.45',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Peas, green, raw',
#   'id': '11304',
#   'nutrient': 'Fiber, total dietary',
#   'value': '5.7',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Peas, green, raw',
#   'id': '11304',
#   'nutrient': 'Sugars, total',
#   'value': '5.67',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Peppers, sweet, green, raw',
#   'id': '11333',
#   'nutrient': 'Water',
#   'value': '93.89',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Peppers, sweet, green, raw',
#   'id': '11333',
#   'nutrient': 'Energy',
#   'value': '20',
#   'unit': 'kcal'},
#  {'category': 'vegetables',
#   'name': 'Peppers, sweet, green, raw',
#   'id': '11333',
#   'nutrient': 'Protein',
#   'value': '0.86',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Peppers, sweet, green, raw',
#   'id': '11333',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.17',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Peppers, sweet, green, raw',
#   'id': '11333',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '4.64',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Peppers, sweet, green, raw',
#   'id': '11333',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.7',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Peppers, sweet, green, raw',
#   'id': '11333',
#   'nutrient': 'Sugars, total',
#   'value': '2.40',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Potatoes, white, flesh and skin, baked',
#   'id': '11357',
#   'nutrient': 'Water',
#   'value': '75.43',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Potatoes, white, flesh and skin, baked',
#   'id': '11357',
#   'nutrient': 'Energy',
#   'value': '92',
#   'unit': 'kcal'},
#  {'category': 'vegetables',
#   'name': 'Potatoes, white, flesh and skin, baked',
#   'id': '11357',
#   'nutrient': 'Protein',
#   'value': '2.10',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Potatoes, white, flesh and skin, baked',
#   'id': '11357',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.15',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Potatoes, white, flesh and skin, baked',
#   'id': '11357',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '21.08',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Potatoes, white, flesh and skin, baked',
#   'id': '11357',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.1',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Potatoes, white, flesh and skin, baked',
#   'id': '11357',
#   'nutrient': 'Sugars, total',
#   'value': '1.53',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'id': '11484',
#   'nutrient': 'Water',
#   'value': '89.70',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'id': '11484',
#   'nutrient': 'Energy',
#   'value': '34',
#   'unit': 'kcal'},
#  {'category': 'vegetables',
#   'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'id': '11484',
#   'nutrient': 'Protein',
#   'value': '0.67',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'id': '11484',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.08',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'id': '11484',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '8.79',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'id': '11484',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.6',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'id': '11484',
#   'nutrient': 'Calcium, Ca',
#   'value': '26',
#   'unit': 'mg'},
#  {'category': 'vegetables',
#   'name': 'Tomatoes, orange, raw',
#   'id': '11695',
#   'nutrient': 'Water',
#   'value': '94.78',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Tomatoes, orange, raw',
#   'id': '11695',
#   'nutrient': 'Energy',
#   'value': '16',
#   'unit': 'kcal'},
#  {'category': 'vegetables',
#   'name': 'Tomatoes, orange, raw',
#   'id': '11695',
#   'nutrient': 'Protein',
#   'value': '1.16',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Tomatoes, orange, raw',
#   'id': '11695',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.19',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Tomatoes, orange, raw',
#   'id': '11695',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '3.18',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Tomatoes, orange, raw',
#   'id': '11695',
#   'nutrient': 'Fiber, total dietary',
#   'value': '0.9',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Tomatoes, orange, raw',
#   'id': '11695',
#   'nutrient': 'Calcium, Ca',
#   'value': '5',
#   'unit': 'mg'},
#  {'category': 'vegetables',
#   'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'id': '11932',
#   'nutrient': 'Water',
#   'value': '93.30',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'id': '11932',
#   'nutrient': 'Energy',
#   'value': '20',
#   'unit': 'kcal'},
#  {'category': 'vegetables',
#   'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'id': '11932',
#   'nutrient': 'Protein',
#   'value': '1.15',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'id': '11932',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.10',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'id': '11932',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '4.50',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'id': '11932',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.3',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'id': '11932',
#   'nutrient': 'Sugars, total',
#   'value': '0.78',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'id': '11705',
#   'nutrient': 'Water',
#   'value': '92.63',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'id': '11705',
#   'nutrient': 'Energy',
#   'value': '22',
#   'unit': 'kcal'},
#  {'category': 'vegetables',
#   'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'id': '11705',
#   'nutrient': 'Protein',
#   'value': '2.40',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'id': '11705',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.22',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'id': '11705',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '4.11',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'id': '11705',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.0',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'id': '11705',
#   'nutrient': 'Sugars, total',
#   'value': '1.30',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Garlic, raw',
#   'id': '11215',
#   'nutrient': 'Water',
#   'value': '58.58',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Garlic, raw',
#   'id': '11215',
#   'nutrient': 'Energy',
#   'value': '149',
#   'unit': 'kcal'},
#  {'category': 'vegetables',
#   'name': 'Garlic, raw',
#   'id': '11215',
#   'nutrient': 'Protein',
#   'value': '6.36',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Garlic, raw',
#   'id': '11215',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.50',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Garlic, raw',
#   'id': '11215',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '33.06',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Garlic, raw',
#   'id': '11215',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.1',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Garlic, raw',
#   'id': '11215',
#   'nutrient': 'Sugars, total',
#   'value': '1.00',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Kale, raw',
#   'id': '11233',
#   'nutrient': 'Water',
#   'value': '89.63',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Kale, raw',
#   'id': '11233',
#   'nutrient': 'Energy',
#   'value': '35',
#   'unit': 'kcal'},
#  {'category': 'vegetables',
#   'name': 'Kale, raw',
#   'id': '11233',
#   'nutrient': 'Protein',
#   'value': '2.92',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Kale, raw',
#   'id': '11233',
#   'nutrient': 'Total lipid (fat)',
#   'value': '1.49',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Kale, raw',
#   'id': '11233',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '4.42',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Kale, raw',
#   'id': '11233',
#   'nutrient': 'Fiber, total dietary',
#   'value': '4.1',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Kale, raw',
#   'id': '11233',
#   'nutrient': 'Sugars, total',
#   'value': '0.99',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Artichokes, (globe or french), raw',
#   'id': '11007',
#   'nutrient': 'Water',
#   'value': '84.94',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Artichokes, (globe or french), raw',
#   'id': '11007',
#   'nutrient': 'Energy',
#   'value': '47',
#   'unit': 'kcal'},
#  {'category': 'vegetables',
#   'name': 'Artichokes, (globe or french), raw',
#   'id': '11007',
#   'nutrient': 'Protein',
#   'value': '3.27',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Artichokes, (globe or french), raw',
#   'id': '11007',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.15',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Artichokes, (globe or french), raw',
#   'id': '11007',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '10.51',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Artichokes, (globe or french), raw',
#   'id': '11007',
#   'nutrient': 'Fiber, total dietary',
#   'value': '5.4',
#   'unit': 'g'},
#  {'category': 'vegetables',
#   'name': 'Artichokes, (globe or french), raw',
#   'id': '11007',
#   'nutrient': 'Sugars, total',
#   'value': '0.99',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Bagels, whole grain white',
#   'id': '28319',
#   'nutrient': 'Water',
#   'value': '34.52',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Bagels, whole grain white',
#   'id': '28319',
#   'nutrient': 'Energy',
#   'value': '255',
#   'unit': 'kcal'},
#  {'category': 'grains',
#   'name': 'Bagels, whole grain white',
#   'id': '28319',
#   'nutrient': 'Protein',
#   'value': '9.30',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Bagels, whole grain white',
#   'id': '28319',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.00',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Bagels, whole grain white',
#   'id': '28319',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '54.52',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Bagels, whole grain white',
#   'id': '28319',
#   'nutrient': 'Fiber, total dietary',
#   'value': '4.7',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Bagels, whole grain white',
#   'id': '28319',
#   'nutrient': 'Sugars, total',
#   'value': '9.30',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Rye grain',
#   'id': '20062',
#   'nutrient': 'Water',
#   'value': '10.60',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Rye grain',
#   'id': '20062',
#   'nutrient': 'Energy',
#   'value': '338',
#   'unit': 'kcal'},
#  {'category': 'grains',
#   'name': 'Rye grain',
#   'id': '20062',
#   'nutrient': 'Protein',
#   'value': '10.34',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Rye grain',
#   'id': '20062',
#   'nutrient': 'Total lipid (fat)',
#   'value': '1.63',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Rye grain',
#   'id': '20062',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '75.86',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Rye grain',
#   'id': '20062',
#   'nutrient': 'Fiber, total dietary',
#   'value': '15.1',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Rye grain',
#   'id': '20062',
#   'nutrient': 'Sugars, total',
#   'value': '0.98',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Corn grain, yellow',
#   'id': '20014',
#   'nutrient': 'Water',
#   'value': '10.37',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Corn grain, yellow',
#   'id': '20014',
#   'nutrient': 'Energy',
#   'value': '365',
#   'unit': 'kcal'},
#  {'category': 'grains',
#   'name': 'Corn grain, yellow',
#   'id': '20014',
#   'nutrient': 'Protein',
#   'value': '9.42',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Corn grain, yellow',
#   'id': '20014',
#   'nutrient': 'Total lipid (fat)',
#   'value': '4.74',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Corn grain, yellow',
#   'id': '20014',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '74.26',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Corn grain, yellow',
#   'id': '20014',
#   'nutrient': 'Fiber, total dietary',
#   'value': '7.3',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Corn grain, yellow',
#   'id': '20014',
#   'nutrient': 'Sugars, total',
#   'value': '0.64',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Corn flour, whole-grain, yellow',
#   'id': '20016',
#   'nutrient': 'Water',
#   'value': '10.91',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Corn flour, whole-grain, yellow',
#   'id': '20016',
#   'nutrient': 'Energy',
#   'value': '361',
#   'unit': 'kcal'},
#  {'category': 'grains',
#   'name': 'Corn flour, whole-grain, yellow',
#   'id': '20016',
#   'nutrient': 'Protein',
#   'value': '6.93',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Corn flour, whole-grain, yellow',
#   'id': '20016',
#   'nutrient': 'Total lipid (fat)',
#   'value': '3.86',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Corn flour, whole-grain, yellow',
#   'id': '20016',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '76.85',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Corn flour, whole-grain, yellow',
#   'id': '20016',
#   'nutrient': 'Fiber, total dietary',
#   'value': '7.3',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Corn flour, whole-grain, yellow',
#   'id': '20016',
#   'nutrient': 'Sugars, total',
#   'value': '0.64',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Rice, white, long-grain, regular, raw, enriched',
#   'id': '20044',
#   'nutrient': 'Water',
#   'value': '11.62',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Rice, white, long-grain, regular, raw, enriched',
#   'id': '20044',
#   'nutrient': 'Energy',
#   'value': '365',
#   'unit': 'kcal'},
#  {'category': 'grains',
#   'name': 'Rice, white, long-grain, regular, raw, enriched',
#   'id': '20044',
#   'nutrient': 'Protein',
#   'value': '7.13',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Rice, white, long-grain, regular, raw, enriched',
#   'id': '20044',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.66',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Rice, white, long-grain, regular, raw, enriched',
#   'id': '20044',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '79.95',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Rice, white, long-grain, regular, raw, enriched',
#   'id': '20044',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.3',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Rice, white, long-grain, regular, raw, enriched',
#   'id': '20044',
#   'nutrient': 'Sugars, total',
#   'value': '0.12',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Pasta, whole grain, 51% whole wheat, remaining unenriched semolina, dry',
#   'id': '20135',
#   'nutrient': 'Water',
#   'value': '8.85',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Pasta, whole grain, 51% whole wheat, remaining unenriched semolina, dry',
#   'id': '20135',
#   'nutrient': 'Energy',
#   'value': '362',
#   'unit': 'kcal'},
#  {'category': 'grains',
#   'name': 'Pasta, whole grain, 51% whole wheat, remaining unenriched semolina, dry',
#   'id': '20135',
#   'nutrient': 'Protein',
#   'value': '13.51',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Pasta, whole grain, 51% whole wheat, remaining unenriched semolina, dry',
#   'id': '20135',
#   'nutrient': 'Total lipid (fat)',
#   'value': '2.68',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Pasta, whole grain, 51% whole wheat, remaining unenriched semolina, dry',
#   'id': '20135',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '73.10',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Pasta, whole grain, 51% whole wheat, remaining unenriched semolina, dry',
#   'id': '20135',
#   'nutrient': 'Fiber, total dietary',
#   'value': '10.1',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Pasta, whole grain, 51% whole wheat, remaining unenriched semolina, dry',
#   'id': '20135',
#   'nutrient': 'Sugars, total',
#   'value': '2.60',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Wheat flour, whole-grain, soft wheat',
#   'id': '20649',
#   'nutrient': 'Water',
#   'value': '12.42',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Wheat flour, whole-grain, soft wheat',
#   'id': '20649',
#   'nutrient': 'Energy',
#   'value': '332',
#   'unit': 'kcal'},
#  {'category': 'grains',
#   'name': 'Wheat flour, whole-grain, soft wheat',
#   'id': '20649',
#   'nutrient': 'Protein',
#   'value': '9.61',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Wheat flour, whole-grain, soft wheat',
#   'id': '20649',
#   'nutrient': 'Total lipid (fat)',
#   'value': '1.95',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Wheat flour, whole-grain, soft wheat',
#   'id': '20649',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '74.48',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Wheat flour, whole-grain, soft wheat',
#   'id': '20649',
#   'nutrient': 'Fiber, total dietary',
#   'value': '13.1',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Wheat flour, whole-grain, soft wheat',
#   'id': '20649',
#   'nutrient': 'Sugars, total',
#   'value': '1.02',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Pasta, gluten-free, corn, dry',
#   'id': '20091',
#   'nutrient': 'Water',
#   'value': '10.00',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Pasta, gluten-free, corn, dry',
#   'id': '20091',
#   'nutrient': 'Energy',
#   'value': '357',
#   'unit': 'kcal'},
#  {'category': 'grains',
#   'name': 'Pasta, gluten-free, corn, dry',
#   'id': '20091',
#   'nutrient': 'Protein',
#   'value': '7.46',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Pasta, gluten-free, corn, dry',
#   'id': '20091',
#   'nutrient': 'Total lipid (fat)',
#   'value': '2.08',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Pasta, gluten-free, corn, dry',
#   'id': '20091',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '79.26',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Pasta, gluten-free, corn, dry',
#   'id': '20091',
#   'nutrient': 'Fiber, total dietary',
#   'value': '11.0',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Pasta, gluten-free, corn, dry',
#   'id': '20091',
#   'nutrient': 'Calcium, Ca',
#   'value': '4',
#   'unit': 'mg'},
#  {'category': 'grains',
#   'name': 'Pasta, gluten-free, corn and rice flour, cooked',
#   'id': '20657',
#   'nutrient': 'Water',
#   'value': '57.67',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Pasta, gluten-free, corn and rice flour, cooked',
#   'id': '20657',
#   'nutrient': 'Energy',
#   'value': '179',
#   'unit': 'kcal'},
#  {'category': 'grains',
#   'name': 'Pasta, gluten-free, corn and rice flour, cooked',
#   'id': '20657',
#   'nutrient': 'Protein',
#   'value': '3.20',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Pasta, gluten-free, corn and rice flour, cooked',
#   'id': '20657',
#   'nutrient': 'Total lipid (fat)',
#   'value': '1.00',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Pasta, gluten-free, corn and rice flour, cooked',
#   'id': '20657',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '38.05',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Pasta, gluten-free, corn and rice flour, cooked',
#   'id': '20657',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.4',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Pasta, gluten-free, corn and rice flour, cooked',
#   'id': '20657',
#   'nutrient': 'Sugars, total',
#   'value': '0.00',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Pasta, dry, enriched',
#   'id': '20120',
#   'nutrient': 'Water',
#   'value': '9.90',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Pasta, dry, enriched',
#   'id': '20120',
#   'nutrient': 'Energy',
#   'value': '371',
#   'unit': 'kcal'},
#  {'category': 'grains',
#   'name': 'Pasta, dry, enriched',
#   'id': '20120',
#   'nutrient': 'Protein',
#   'value': '13.04',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Pasta, dry, enriched',
#   'id': '20120',
#   'nutrient': 'Total lipid (fat)',
#   'value': '1.51',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Pasta, dry, enriched',
#   'id': '20120',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '74.67',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Pasta, dry, enriched',
#   'id': '20120',
#   'nutrient': 'Fiber, total dietary',
#   'value': '3.2',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Pasta, dry, enriched',
#   'id': '20120',
#   'nutrient': 'Sugars, total',
#   'value': '2.67',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, pine nuts, dried',
#   'id': '12147',
#   'nutrient': 'Water',
#   'value': '2.28',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, pine nuts, dried',
#   'id': '12147',
#   'nutrient': 'Energy',
#   'value': '673',
#   'unit': 'kcal'},
#  {'category': 'grains',
#   'name': 'Nuts, pine nuts, dried',
#   'id': '12147',
#   'nutrient': 'Protein',
#   'value': '13.69',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, pine nuts, dried',
#   'id': '12147',
#   'nutrient': 'Total lipid (fat)',
#   'value': '68.37',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, pine nuts, dried',
#   'id': '12147',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '13.08',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, pine nuts, dried',
#   'id': '12147',
#   'nutrient': 'Fiber, total dietary',
#   'value': '3.7',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, pine nuts, dried',
#   'id': '12147',
#   'nutrient': 'Sugars, total',
#   'value': '3.59',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, cashew nuts, oil roasted, with salt added',
#   'id': '12586',
#   'nutrient': 'Water',
#   'value': '2.34',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, cashew nuts, oil roasted, with salt added',
#   'id': '12586',
#   'nutrient': 'Energy',
#   'value': '581',
#   'unit': 'kcal'},
#  {'category': 'grains',
#   'name': 'Nuts, cashew nuts, oil roasted, with salt added',
#   'id': '12586',
#   'nutrient': 'Protein',
#   'value': '16.84',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, cashew nuts, oil roasted, with salt added',
#   'id': '12586',
#   'nutrient': 'Total lipid (fat)',
#   'value': '47.77',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, cashew nuts, oil roasted, with salt added',
#   'id': '12586',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '30.16',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, cashew nuts, oil roasted, with salt added',
#   'id': '12586',
#   'nutrient': 'Fiber, total dietary',
#   'value': '3.3',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, cashew nuts, oil roasted, with salt added',
#   'id': '12586',
#   'nutrient': 'Sugars, total',
#   'value': '5.01',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, coconut meat, raw',
#   'id': '12104',
#   'nutrient': 'Water',
#   'value': '46.99',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, coconut meat, raw',
#   'id': '12104',
#   'nutrient': 'Energy',
#   'value': '354',
#   'unit': 'kcal'},
#  {'category': 'grains',
#   'name': 'Nuts, coconut meat, raw',
#   'id': '12104',
#   'nutrient': 'Protein',
#   'value': '3.33',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, coconut meat, raw',
#   'id': '12104',
#   'nutrient': 'Total lipid (fat)',
#   'value': '33.49',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, coconut meat, raw',
#   'id': '12104',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '15.23',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, coconut meat, raw',
#   'id': '12104',
#   'nutrient': 'Fiber, total dietary',
#   'value': '9.0',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, coconut meat, raw',
#   'id': '12104',
#   'nutrient': 'Sugars, total',
#   'value': '6.23',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, walnuts, english',
#   'id': '12155',
#   'nutrient': 'Water',
#   'value': '4.07',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, walnuts, english',
#   'id': '12155',
#   'nutrient': 'Energy',
#   'value': '654',
#   'unit': 'kcal'},
#  {'category': 'grains',
#   'name': 'Nuts, walnuts, english',
#   'id': '12155',
#   'nutrient': 'Protein',
#   'value': '15.23',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, walnuts, english',
#   'id': '12155',
#   'nutrient': 'Total lipid (fat)',
#   'value': '65.21',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, walnuts, english',
#   'id': '12155',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '13.71',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, walnuts, english',
#   'id': '12155',
#   'nutrient': 'Fiber, total dietary',
#   'value': '6.7',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, walnuts, english',
#   'id': '12155',
#   'nutrient': 'Sugars, total',
#   'value': '2.61',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, almonds, dry roasted, without salt added',
#   'id': '12063',
#   'nutrient': 'Water',
#   'value': '2.41',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, almonds, dry roasted, without salt added',
#   'id': '12063',
#   'nutrient': 'Energy',
#   'value': '598',
#   'unit': 'kcal'},
#  {'category': 'grains',
#   'name': 'Nuts, almonds, dry roasted, without salt added',
#   'id': '12063',
#   'nutrient': 'Protein',
#   'value': '20.96',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, almonds, dry roasted, without salt added',
#   'id': '12063',
#   'nutrient': 'Total lipid (fat)',
#   'value': '52.54',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, almonds, dry roasted, without salt added',
#   'id': '12063',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '21.01',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, almonds, dry roasted, without salt added',
#   'id': '12063',
#   'nutrient': 'Fiber, total dietary',
#   'value': '10.9',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Nuts, almonds, dry roasted, without salt added',
#   'id': '12063',
#   'nutrient': 'Sugars, total',
#   'value': '4.86',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Sorghum flour, whole-grain',
#   'id': '20648',
#   'nutrient': 'Water',
#   'value': '10.26',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Sorghum flour, whole-grain',
#   'id': '20648',
#   'nutrient': 'Energy',
#   'value': '359',
#   'unit': 'kcal'},
#  {'category': 'grains',
#   'name': 'Sorghum flour, whole-grain',
#   'id': '20648',
#   'nutrient': 'Protein',
#   'value': '8.43',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Sorghum flour, whole-grain',
#   'id': '20648',
#   'nutrient': 'Total lipid (fat)',
#   'value': '3.34',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Sorghum flour, whole-grain',
#   'id': '20648',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '76.64',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Sorghum flour, whole-grain',
#   'id': '20648',
#   'nutrient': 'Fiber, total dietary',
#   'value': '6.6',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Sorghum flour, whole-grain',
#   'id': '20648',
#   'nutrient': 'Sugars, total',
#   'value': '1.94',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Biscuits, mixed grain, refrigerated dough',
#   'id': '18017',
#   'nutrient': 'Water',
#   'value': '37.80',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Biscuits, mixed grain, refrigerated dough',
#   'id': '18017',
#   'nutrient': 'Energy',
#   'value': '263',
#   'unit': 'kcal'},
#  {'category': 'grains',
#   'name': 'Biscuits, mixed grain, refrigerated dough',
#   'id': '18017',
#   'nutrient': 'Protein',
#   'value': '6.10',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Biscuits, mixed grain, refrigerated dough',
#   'id': '18017',
#   'nutrient': 'Total lipid (fat)',
#   'value': '5.60',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Biscuits, mixed grain, refrigerated dough',
#   'id': '18017',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '47.40',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Biscuits, mixed grain, refrigerated dough',
#   'id': '18017',
#   'nutrient': 'Calcium, Ca',
#   'value': '17',
#   'unit': 'mg'},
#  {'category': 'grains',
#   'name': 'Biscuits, mixed grain, refrigerated dough',
#   'id': '18017',
#   'nutrient': 'Iron, Fe',
#   'value': '2.75',
#   'unit': 'mg'},
#  {'category': 'grains',
#   'name': 'Muffins, English, mixed-grain (includes granola)',
#   'id': '18260',
#   'nutrient': 'Water',
#   'value': '40.20',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Muffins, English, mixed-grain (includes granola)',
#   'id': '18260',
#   'nutrient': 'Energy',
#   'value': '235',
#   'unit': 'kcal'},
#  {'category': 'grains',
#   'name': 'Muffins, English, mixed-grain (includes granola)',
#   'id': '18260',
#   'nutrient': 'Protein',
#   'value': '9.10',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Muffins, English, mixed-grain (includes granola)',
#   'id': '18260',
#   'nutrient': 'Total lipid (fat)',
#   'value': '1.80',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Muffins, English, mixed-grain (includes granola)',
#   'id': '18260',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '46.30',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Muffins, English, mixed-grain (includes granola)',
#   'id': '18260',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.8',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Muffins, English, mixed-grain (includes granola)',
#   'id': '18260',
#   'nutrient': 'Sugars, total',
#   'value': '0.81',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Rolls, hamburger or hotdog, mixed-grain',
#   'id': '18351',
#   'nutrient': 'Water',
#   'value': '38.00',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Rolls, hamburger or hotdog, mixed-grain',
#   'id': '18351',
#   'nutrient': 'Energy',
#   'value': '263',
#   'unit': 'kcal'},
#  {'category': 'grains',
#   'name': 'Rolls, hamburger or hotdog, mixed-grain',
#   'id': '18351',
#   'nutrient': 'Protein',
#   'value': '9.60',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Rolls, hamburger or hotdog, mixed-grain',
#   'id': '18351',
#   'nutrient': 'Total lipid (fat)',
#   'value': '6.00',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Rolls, hamburger or hotdog, mixed-grain',
#   'id': '18351',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '44.60',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Rolls, hamburger or hotdog, mixed-grain',
#   'id': '18351',
#   'nutrient': 'Fiber, total dietary',
#   'value': '3.8',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Rolls, hamburger or hotdog, mixed-grain',
#   'id': '18351',
#   'nutrient': 'Sugars, total',
#   'value': '6.25',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'School Lunch, chicken nuggets, whole grain breaded',
#   'id': '21611',
#   'nutrient': 'Water',
#   'value': '46.53',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'School Lunch, chicken nuggets, whole grain breaded',
#   'id': '21611',
#   'nutrient': 'Energy',
#   'value': '270',
#   'unit': 'kcal'},
#  {'category': 'grains',
#   'name': 'School Lunch, chicken nuggets, whole grain breaded',
#   'id': '21611',
#   'nutrient': 'Protein',
#   'value': '15.67',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'School Lunch, chicken nuggets, whole grain breaded',
#   'id': '21611',
#   'nutrient': 'Total lipid (fat)',
#   'value': '12.90',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'School Lunch, chicken nuggets, whole grain breaded',
#   'id': '21611',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '22.86',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'School Lunch, chicken nuggets, whole grain breaded',
#   'id': '21611',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.2',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'School Lunch, chicken nuggets, whole grain breaded',
#   'id': '21611',
#   'nutrient': 'Sugars, total',
#   'value': '0.49',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Cereals ready-to-eat, POST, GREAT GRAINS, Raisin, Date & Pecan',
#   'id': '42265',
#   'nutrient': 'Water',
#   'value': '8.50',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Cereals ready-to-eat, POST, GREAT GRAINS, Raisin, Date & Pecan',
#   'id': '42265',
#   'nutrient': 'Energy',
#   'value': '378',
#   'unit': 'kcal'},
#  {'category': 'grains',
#   'name': 'Cereals ready-to-eat, POST, GREAT GRAINS, Raisin, Date & Pecan',
#   'id': '42265',
#   'nutrient': 'Protein',
#   'value': '7.90',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Cereals ready-to-eat, POST, GREAT GRAINS, Raisin, Date & Pecan',
#   'id': '42265',
#   'nutrient': 'Total lipid (fat)',
#   'value': '7.10',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Cereals ready-to-eat, POST, GREAT GRAINS, Raisin, Date & Pecan',
#   'id': '42265',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '74.30',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Cereals ready-to-eat, POST, GREAT GRAINS, Raisin, Date & Pecan',
#   'id': '42265',
#   'nutrient': 'Fiber, total dietary',
#   'value': '9.3',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Cereals ready-to-eat, POST, GREAT GRAINS, Raisin, Date & Pecan',
#   'id': '42265',
#   'nutrient': 'Sugars, total',
#   'value': '24.10',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Cereals ready-to-eat, POST, GREAT GRAINS Crunchy Pecan Cereal',
#   'id': '42261',
#   'nutrient': 'Water',
#   'value': '5.20',
#   'unit': 'g'},
#  {'category': 'grains',
#   'name': 'Cereals ready-to-eat, POST, GREAT GRAINS Crunchy Pecan Cereal',
#   'id': '42261',
#   'nutrient': 'Energy',
#   'value': '403',
#   'unit': 'kcal'},
#  {'category': 'grains',
#   'name': 'Cereals ready-to-eat, POST, GREAT GRAINS Crunchy Pecan Cereal',
#   'id': '42261',
#   'nutrient': 'Protein',
#   'value': '9.00',
#   'unit': 'g'},
#  {'category': 'grains',
# ...
#  {'category': 'fruit',
#   'name': 'Papayas, raw',
#   'id': '09226',
#   'nutrient': 'Water',
#   'value': '88.06',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Papayas, raw',
#   'id': '09226',
#   'nutrient': 'Energy',
#   'value': '43',
#   'unit': 'kcal'},
#  {'category': 'fruit',
#   'name': 'Papayas, raw',
#   'id': '09226',
#   'nutrient': 'Protein',
#   'value': '0.47',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Papayas, raw',
#   'id': '09226',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.26',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Papayas, raw',
#   'id': '09226',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '10.82',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Papayas, raw',
#   'id': '09226',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.7',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Papayas, raw',
#   'id': '09226',
#   'nutrient': 'Sugars, total',
#   'value': '7.82',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Blueberries, raw',
#   'id': '09050',
#   'nutrient': 'Water',
#   'value': '84.21',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Blueberries, raw',
#   'id': '09050',
#   'nutrient': 'Energy',
#   'value': '57',
#   'unit': 'kcal'},
#  {'category': 'fruit',
#   'name': 'Blueberries, raw',
#   'id': '09050',
#   'nutrient': 'Protein',
#   'value': '0.74',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Blueberries, raw',
#   'id': '09050',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.33',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Blueberries, raw',
#   'id': '09050',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '14.49',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Blueberries, raw',
#   'id': '09050',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.4',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Blueberries, raw',
#   'id': '09050',
#   'nutrient': 'Sugars, total',
#   'value': '9.96',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Strawberries, raw',
#   'id': '09316',
#   'nutrient': 'Water',
#   'value': '90.95',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Strawberries, raw',
#   'id': '09316',
#   'nutrient': 'Energy',
#   'value': '32',
#   'unit': 'kcal'},
#  {'category': 'fruit',
#   'name': 'Strawberries, raw',
#   'id': '09316',
#   'nutrient': 'Protein',
#   'value': '0.67',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Strawberries, raw',
#   'id': '09316',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.30',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Strawberries, raw',
#   'id': '09316',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '7.68',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Strawberries, raw',
#   'id': '09316',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.0',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Strawberries, raw',
#   'id': '09316',
#   'nutrient': 'Sugars, total',
#   'value': '4.89',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Bananas, raw',
#   'id': '09040',
#   'nutrient': 'Water',
#   'value': '74.91',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Bananas, raw',
#   'id': '09040',
#   'nutrient': 'Energy',
#   'value': '89',
#   'unit': 'kcal'},
#  {'category': 'fruit',
#   'name': 'Bananas, raw',
#   'id': '09040',
#   'nutrient': 'Protein',
#   'value': '1.09',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Bananas, raw',
#   'id': '09040',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.33',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Bananas, raw',
#   'id': '09040',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '22.84',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Bananas, raw',
#   'id': '09040',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.6',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Bananas, raw',
#   'id': '09040',
#   'nutrient': 'Sugars, total',
#   'value': '12.23',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Kiwifruit, green, raw',
#   'id': '09148',
#   'nutrient': 'Water',
#   'value': '83.07',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Kiwifruit, green, raw',
#   'id': '09148',
#   'nutrient': 'Energy',
#   'value': '61',
#   'unit': 'kcal'},
#  {'category': 'fruit',
#   'name': 'Kiwifruit, green, raw',
#   'id': '09148',
#   'nutrient': 'Protein',
#   'value': '1.14',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Kiwifruit, green, raw',
#   'id': '09148',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.52',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Kiwifruit, green, raw',
#   'id': '09148',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '14.66',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Kiwifruit, green, raw',
#   'id': '09148',
#   'nutrient': 'Fiber, total dietary',
#   'value': '3.0',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Kiwifruit, green, raw',
#   'id': '09148',
#   'nutrient': 'Sugars, total',
#   'value': '8.99',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Oranges, raw, all commercial varieties',
#   'id': '09200',
#   'nutrient': 'Water',
#   'value': '86.75',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Oranges, raw, all commercial varieties',
#   'id': '09200',
#   'nutrient': 'Energy',
#   'value': '47',
#   'unit': 'kcal'},
#  {'category': 'fruit',
#   'name': 'Oranges, raw, all commercial varieties',
#   'id': '09200',
#   'nutrient': 'Protein',
#   'value': '0.94',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Oranges, raw, all commercial varieties',
#   'id': '09200',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.12',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Oranges, raw, all commercial varieties',
#   'id': '09200',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '11.75',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Oranges, raw, all commercial varieties',
#   'id': '09200',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.4',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Oranges, raw, all commercial varieties',
#   'id': '09200',
#   'nutrient': 'Sugars, total',
#   'value': '9.35',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Avocados, raw, all commercial varieties',
#   'id': '09037',
#   'nutrient': 'Water',
#   'value': '73.23',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Avocados, raw, all commercial varieties',
#   'id': '09037',
#   'nutrient': 'Energy',
#   'value': '160',
#   'unit': 'kcal'},
#  {'category': 'fruit',
#   'name': 'Avocados, raw, all commercial varieties',
#   'id': '09037',
#   'nutrient': 'Protein',
#   'value': '2.00',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Avocados, raw, all commercial varieties',
#   'id': '09037',
#   'nutrient': 'Total lipid (fat)',
#   'value': '14.66',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Avocados, raw, all commercial varieties',
#   'id': '09037',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '8.53',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Avocados, raw, all commercial varieties',
#   'id': '09037',
#   'nutrient': 'Fiber, total dietary',
#   'value': '6.7',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Avocados, raw, all commercial varieties',
#   'id': '09037',
#   'nutrient': 'Sugars, total',
#   'value': '0.66',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Grapefruit, raw, pink and red and white, all areas',
#   'id': '09111',
#   'nutrient': 'Water',
#   'value': '90.89',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Grapefruit, raw, pink and red and white, all areas',
#   'id': '09111',
#   'nutrient': 'Energy',
#   'value': '32',
#   'unit': 'kcal'},
#  {'category': 'fruit',
#   'name': 'Grapefruit, raw, pink and red and white, all areas',
#   'id': '09111',
#   'nutrient': 'Protein',
#   'value': '0.63',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Grapefruit, raw, pink and red and white, all areas',
#   'id': '09111',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.10',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Grapefruit, raw, pink and red and white, all areas',
#   'id': '09111',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '8.08',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Grapefruit, raw, pink and red and white, all areas',
#   'id': '09111',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.1',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Grapefruit, raw, pink and red and white, all areas',
#   'id': '09111',
#   'nutrient': 'Sugars, total',
#   'value': '6.98',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Grapes, american type (slip skin), raw',
#   'id': '09131',
#   'nutrient': 'Water',
#   'value': '81.30',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Grapes, american type (slip skin), raw',
#   'id': '09131',
#   'nutrient': 'Energy',
#   'value': '67',
#   'unit': 'kcal'},
#  {'category': 'fruit',
#   'name': 'Grapes, american type (slip skin), raw',
#   'id': '09131',
#   'nutrient': 'Protein',
#   'value': '0.63',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Grapes, american type (slip skin), raw',
#   'id': '09131',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.35',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Grapes, american type (slip skin), raw',
#   'id': '09131',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '17.15',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Grapes, american type (slip skin), raw',
#   'id': '09131',
#   'nutrient': 'Fiber, total dietary',
#   'value': '0.9',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Grapes, american type (slip skin), raw',
#   'id': '09131',
#   'nutrient': 'Sugars, total',
#   'value': '16.25',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Cherries, sweet, raw',
#   'id': '09070',
#   'nutrient': 'Water',
#   'value': '82.25',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Cherries, sweet, raw',
#   'id': '09070',
#   'nutrient': 'Energy',
#   'value': '63',
#   'unit': 'kcal'},
#  {'category': 'fruit',
#   'name': 'Cherries, sweet, raw',
#   'id': '09070',
#   'nutrient': 'Protein',
#   'value': '1.06',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Cherries, sweet, raw',
#   'id': '09070',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.20',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Cherries, sweet, raw',
#   'id': '09070',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '16.01',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Cherries, sweet, raw',
#   'id': '09070',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.1',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Cherries, sweet, raw',
#   'id': '09070',
#   'nutrient': 'Sugars, total',
#   'value': '12.82',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Lemons, raw, without peel',
#   'id': '09150',
#   'nutrient': 'Water',
#   'value': '88.98',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Lemons, raw, without peel',
#   'id': '09150',
#   'nutrient': 'Energy',
#   'value': '29',
#   'unit': 'kcal'},
#  {'category': 'fruit',
#   'name': 'Lemons, raw, without peel',
#   'id': '09150',
#   'nutrient': 'Protein',
#   'value': '1.10',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Lemons, raw, without peel',
#   'id': '09150',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.30',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Lemons, raw, without peel',
#   'id': '09150',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '9.32',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Lemons, raw, without peel',
#   'id': '09150',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.8',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Lemons, raw, without peel',
#   'id': '09150',
#   'nutrient': 'Sugars, total',
#   'value': '2.50',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Mangos, raw',
#   'id': '09176',
#   'nutrient': 'Water',
#   'value': '83.46',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Mangos, raw',
#   'id': '09176',
#   'nutrient': 'Energy',
#   'value': '60',
#   'unit': 'kcal'},
#  {'category': 'fruit',
#   'name': 'Mangos, raw',
#   'id': '09176',
#   'nutrient': 'Protein',
#   'value': '0.82',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Mangos, raw',
#   'id': '09176',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.38',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Mangos, raw',
#   'id': '09176',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '14.98',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Mangos, raw',
#   'id': '09176',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.6',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Mangos, raw',
#   'id': '09176',
#   'nutrient': 'Sugars, total',
#   'value': '13.66',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Limes, raw',
#   'id': '09159',
#   'nutrient': 'Water',
#   'value': '88.26',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Limes, raw',
#   'id': '09159',
#   'nutrient': 'Energy',
#   'value': '30',
#   'unit': 'kcal'},
#  {'category': 'fruit',
#   'name': 'Limes, raw',
#   'id': '09159',
#   'nutrient': 'Protein',
#   'value': '0.70',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Limes, raw',
#   'id': '09159',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.20',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Limes, raw',
#   'id': '09159',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '10.54',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Limes, raw',
#   'id': '09159',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.8',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Limes, raw',
#   'id': '09159',
#   'nutrient': 'Sugars, total',
#   'value': '1.69',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Plums, raw',
#   'id': '09279',
#   'nutrient': 'Water',
#   'value': '87.23',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Plums, raw',
#   'id': '09279',
#   'nutrient': 'Energy',
#   'value': '46',
#   'unit': 'kcal'},
#  {'category': 'fruit',
#   'name': 'Plums, raw',
#   'id': '09279',
#   'nutrient': 'Protein',
#   'value': '0.70',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Plums, raw',
#   'id': '09279',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.28',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Plums, raw',
#   'id': '09279',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '11.42',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Plums, raw',
#   'id': '09279',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.4',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Plums, raw',
#   'id': '09279',
#   'nutrient': 'Sugars, total',
#   'value': '9.92',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Watermelon, raw',
#   'id': '09326',
#   'nutrient': 'Water',
#   'value': '91.45',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Watermelon, raw',
#   'id': '09326',
#   'nutrient': 'Energy',
#   'value': '30',
#   'unit': 'kcal'},
#  {'category': 'fruit',
#   'name': 'Watermelon, raw',
#   'id': '09326',
#   'nutrient': 'Protein',
#   'value': '0.61',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Watermelon, raw',
#   'id': '09326',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.15',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Watermelon, raw',
#   'id': '09326',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '7.55',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Watermelon, raw',
#   'id': '09326',
#   'nutrient': 'Fiber, total dietary',
#   'value': '0.4',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Watermelon, raw',
#   'id': '09326',
#   'nutrient': 'Sugars, total',
#   'value': '6.20',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Raspberries, raw',
#   'id': '09302',
#   'nutrient': 'Water',
#   'value': '85.75',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Raspberries, raw',
#   'id': '09302',
#   'nutrient': 'Energy',
#   'value': '52',
#   'unit': 'kcal'},
#  {'category': 'fruit',
#   'name': 'Raspberries, raw',
#   'id': '09302',
#   'nutrient': 'Protein',
#   'value': '1.20',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Raspberries, raw',
#   'id': '09302',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.65',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Raspberries, raw',
#   'id': '09302',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '11.94',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Raspberries, raw',
#   'id': '09302',
#   'nutrient': 'Fiber, total dietary',
#   'value': '6.5',
#   'unit': 'g'},
#  {'category': 'fruit',
#   'name': 'Raspberries, raw',
#   'id': '09302',
#   'nutrient': 'Sugars, total',
#   'value': '4.42',
#   'unit': 'g'}]

# %% [markdown]
# ## Load API data to database

# %%
# Connect to a database and input the data
db.data_api.insert_many(food_items)

# %%
# Inquire
x=db.data_api.find({'nutrient': "Water"})
list(x)
# Out:
# [{'_id': ObjectId('5c9fe3034ae97b5be81ff148'),
#   'category': 'vegetables',
#   'name': 'Asparagus, raw',
#   'id': '11011',
#   'nutrient': 'Water',
#   'value': '93.22',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff14f'),
#   'category': 'vegetables',
#   'name': 'Beets, raw',
#   'id': '11080',
#   'nutrient': 'Water',
#   'value': '87.58',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff156'),
#   'category': 'vegetables',
#   'name': 'Broccoli, raw',
#   'id': '11090',
#   'nutrient': 'Water',
#   'value': '89.30',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff15d'),
#   'category': 'vegetables',
#   'name': 'Cabbage, raw',
#   'id': '11109',
#   'nutrient': 'Water',
#   'value': '92.18',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff164'),
#   'category': 'vegetables',
#   'name': 'Carrots, raw',
#   'id': '11124',
#   'nutrient': 'Water',
#   'value': '88.29',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff16b'),
#   'category': 'vegetables',
#   'name': 'Cauliflower, raw',
#   'id': '11135',
#   'nutrient': 'Water',
#   'value': '92.07',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff172'),
#   'category': 'vegetables',
#   'name': 'Celery, raw',
#   'id': '11143',
#   'nutrient': 'Water',
#   'value': '95.43',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff179'),
#   'category': 'vegetables',
#   'name': 'Cucumber, with peel, raw',
#   'id': '11205',
#   'nutrient': 'Water',
#   'value': '95.23',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff180'),
#   'category': 'vegetables',
#   'name': 'Eggplant, cooked, boiled, drained, without salt',
#   'id': '11210',
#   'nutrient': 'Water',
#   'value': '89.67',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff187'),
#   'category': 'vegetables',
#   'name': 'Mushrooms, shiitake, raw',
#   'id': '11238',
#   'nutrient': 'Water',
#   'value': '89.74',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff18e'),
#   'category': 'vegetables',
#   'name': 'Lentils, sprouted, raw',
#   'id': '11248',
#   'nutrient': 'Water',
#   'value': '67.34',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff195'),
#   'category': 'vegetables',
#   'name': 'Lettuce, green leaf, raw',
#   'id': '11253',
#   'nutrient': 'Water',
#   'value': '94.98',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff19c'),
#   'category': 'vegetables',
#   'name': 'Onions, sweet, raw',
#   'id': '11294',
#   'nutrient': 'Water',
#   'value': '91.24',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1a3'),
#   'category': 'vegetables',
#   'name': 'Peas, green, raw',
#   'id': '11304',
#   'nutrient': 'Water',
#   'value': '78.86',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1aa'),
#   'category': 'vegetables',
#   'name': 'Peppers, sweet, green, raw',
#   'id': '11333',
#   'nutrient': 'Water',
#   'value': '93.89',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1b1'),
#   'category': 'vegetables',
#   'name': 'Potatoes, white, flesh and skin, baked',
#   'id': '11357',
#   'nutrient': 'Water',
#   'value': '75.43',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1b8'),
#   'category': 'vegetables',
#   'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'id': '11484',
#   'nutrient': 'Water',
#   'value': '89.70',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1bf'),
#   'category': 'vegetables',
#   'name': 'Tomatoes, orange, raw',
#   'id': '11695',
#   'nutrient': 'Water',
#   'value': '94.78',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1c6'),
#   'category': 'vegetables',
#   'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'id': '11932',
#   'nutrient': 'Water',
#   'value': '93.30',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1cd'),
#   'category': 'vegetables',
#   'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'id': '11705',
#   'nutrient': 'Water',
#   'value': '92.63',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1d4'),
#   'category': 'vegetables',
#   'name': 'Garlic, raw',
#   'id': '11215',
#   'nutrient': 'Water',
#   'value': '58.58',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1db'),
#   'category': 'vegetables',
#   'name': 'Kale, raw',
#   'id': '11233',
#   'nutrient': 'Water',
#   'value': '89.63',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1e2'),
#   'category': 'vegetables',
#   'name': 'Artichokes, (globe or french), raw',
#   'id': '11007',
#   'nutrient': 'Water',
#   'value': '84.94',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1e9'),
#   'category': 'grains',
#   'name': 'Bagels, whole grain white',
#   'id': '28319',
#   'nutrient': 'Water',
#   'value': '34.52',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1f0'),
#   'category': 'grains',
#   'name': 'Rye grain',
#   'id': '20062',
#   'nutrient': 'Water',
#   'value': '10.60',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1f7'),
#   'category': 'grains',
#   'name': 'Corn grain, yellow',
#   'id': '20014',
#   'nutrient': 'Water',
#   'value': '10.37',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1fe'),
#   'category': 'grains',
#   'name': 'Corn flour, whole-grain, yellow',
#   'id': '20016',
#   'nutrient': 'Water',
#   'value': '10.91',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff205'),
#   'category': 'grains',
#   'name': 'Rice, white, long-grain, regular, raw, enriched',
#   'id': '20044',
#   'nutrient': 'Water',
#   'value': '11.62',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff20c'),
#   'category': 'grains',
#   'name': 'Pasta, whole grain, 51% whole wheat, remaining unenriched semolina, dry',
#   'id': '20135',
#   'nutrient': 'Water',
#   'value': '8.85',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff213'),
#   'category': 'grains',
#   'name': 'Wheat flour, whole-grain, soft wheat',
#   'id': '20649',
#   'nutrient': 'Water',
#   'value': '12.42',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff21a'),
#   'category': 'grains',
#   'name': 'Pasta, gluten-free, corn, dry',
#   'id': '20091',
#   'nutrient': 'Water',
#   'value': '10.00',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff221'),
#   'category': 'grains',
#   'name': 'Pasta, gluten-free, corn and rice flour, cooked',
#   'id': '20657',
#   'nutrient': 'Water',
#   'value': '57.67',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff228'),
#   'category': 'grains',
#   'name': 'Pasta, dry, enriched',
#   'id': '20120',
#   'nutrient': 'Water',
#   'value': '9.90',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff22f'),
#   'category': 'grains',
#   'name': 'Nuts, pine nuts, dried',
#   'id': '12147',
#   'nutrient': 'Water',
#   'value': '2.28',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff236'),
#   'category': 'grains',
#   'name': 'Nuts, cashew nuts, oil roasted, with salt added',
#   'id': '12586',
#   'nutrient': 'Water',
#   'value': '2.34',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff23d'),
#   'category': 'grains',
#   'name': 'Nuts, coconut meat, raw',
#   'id': '12104',
#   'nutrient': 'Water',
#   'value': '46.99',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff244'),
#   'category': 'grains',
#   'name': 'Nuts, walnuts, english',
#   'id': '12155',
#   'nutrient': 'Water',
#   'value': '4.07',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff24b'),
#   'category': 'grains',
#   'name': 'Nuts, almonds, dry roasted, without salt added',
#   'id': '12063',
#   'nutrient': 'Water',
#   'value': '2.41',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff252'),
#   'category': 'grains',
#   'name': 'Sorghum flour, whole-grain',
#   'id': '20648',
#   'nutrient': 'Water',
#   'value': '10.26',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff259'),
#   'category': 'grains',
#   'name': 'Biscuits, mixed grain, refrigerated dough',
#   'id': '18017',
#   'nutrient': 'Water',
#   'value': '37.80',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff260'),
#   'category': 'grains',
#   'name': 'Muffins, English, mixed-grain (includes granola)',
#   'id': '18260',
#   'nutrient': 'Water',
#   'value': '40.20',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff267'),
#   'category': 'grains',
#   'name': 'Rolls, hamburger or hotdog, mixed-grain',
#   'id': '18351',
#   'nutrient': 'Water',
#   'value': '38.00',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff26e'),
#   'category': 'grains',
#   'name': 'School Lunch, chicken nuggets, whole grain breaded',
#   'id': '21611',
#   'nutrient': 'Water',
#   'value': '46.53',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff275'),
#   'category': 'grains',
#   'name': 'Cereals ready-to-eat, POST, GREAT GRAINS, Raisin, Date & Pecan',
#   'id': '42265',
#   'nutrient': 'Water',
#   'value': '8.50',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff27c'),
#   'category': 'grains',
#   'name': 'Cereals ready-to-eat, POST, GREAT GRAINS Crunchy Pecan Cereal',
#   'id': '42261',
#   'nutrient': 'Water',
#   'value': '5.20',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff283'),
#   'category': 'grains',
#   'name': 'Crackers, whole grain, sandwich-type, with peanut butter filling',
#   'id': '28326',
#   'nutrient': 'Water',
#   'value': '7.32',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff28a'),
#   'category': 'grains',
#   'name': "Rice, brown, long-grain, raw (Includes foods for USDA's Food Distribution Program)",
#   'id': '20036',
#   'nutrient': 'Water',
#   'value': '11.80',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff291'),
#   'category': 'dairy',
#   'name': 'Cheese, blue',
#   'id': '01004',
#   'nutrient': 'Water',
#   'value': '42.41',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff298'),
#   'category': 'dairy',
#   'name': 'Cheese, swiss',
#   'id': '01040',
#   'nutrient': 'Water',
#   'value': '37.63',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff29f'),
#   'category': 'dairy',
#   'name': 'Egg, whole, cooked, scrambled',
#   'id': '01132',
#   'nutrient': 'Water',
#   'value': '76.40',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff2a6'),
#   'category': 'dairy',
#   'name': 'Butter, salted',
#   'id': '01001',
#   'nutrient': 'Water',
#   'value': '16.17',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff2ad'),
#   'category': 'dairy',
#   'name': "Cheese, cheddar (Includes foods for USDA's Food Distribution Program)",
#   'id': '01009',
#   'nutrient': 'Water',
#   'value': '36.75',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff2b4'),
#   'category': 'dairy',
#   'name': 'Cream, fluid, heavy whipping',
#   'id': '01053',
#   'nutrient': 'Water',
#   'value': '57.71',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff2bb'),
#   'category': 'dairy',
#   'name': 'Milk, lowfat, fluid, 1% milkfat, with added vitamin A and vitamin D',
#   'id': '01082',
#   'nutrient': 'Water',
#   'value': '89.92',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff2c2'),
#   'category': 'dairy',
#   'name': 'Yogurt, plain, low fat',
#   'id': '01117',
#   'nutrient': 'Water',
#   'value': '85.07',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff2c9'),
#   'category': 'dairy',
#   'name': 'Yogurt, Greek, plain, lowfat',
#   'id': '01287',
#   'nutrient': 'Water',
#   'value': '83.56',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff2d0'),
#   'category': 'dairy',
#   'name': 'Butter, Clarified butter (ghee)',
#   'id': '01323',
#   'nutrient': 'Water',
#   'value': '0.50',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff2d7'),
#   'category': 'dairy',
#   'name': 'Cheese, white, queso blanco',
#   'id': '01229',
#   'nutrient': 'Water',
#   'value': '48.70',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff2de'),
#   'category': 'dairy',
#   'name': 'Butter, without salt',
#   'id': '01145',
#   'nutrient': 'Water',
#   'value': '16.17',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff2e5'),
#   'category': 'dairy',
#   'name': 'Cheese, goat, soft type',
#   'id': '01159',
#   'nutrient': 'Water',
#   'value': '60.75',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff2ec'),
#   'category': 'dairy',
#   'name': 'Eggnog',
#   'id': '01057',
#   'nutrient': 'Water',
#   'value': '82.54',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff2f3'),
#   'category': 'dairy',
#   'name': 'Milk, whole, 3.25% milkfat, with added vitamin D',
#   'id': '01077',
#   'nutrient': 'Water',
#   'value': '88.13',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff2fa'),
#   'category': 'dairy',
#   'name': 'Cheese, parmesan, grated',
#   'id': '01032',
#   'nutrient': 'Water',
#   'value': '22.65',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff301'),
#   'category': 'dairy',
#   'name': 'Cheese, cottage, creamed, large or small curd',
#   'id': '01012',
#   'nutrient': 'Water',
#   'value': '79.79',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff308'),
#   'category': 'dairy',
#   'name': 'Cheese, cottage, lowfat, 2% milkfat',
#   'id': '01015',
#   'nutrient': 'Water',
#   'value': '81.24',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff30f'),
#   'category': 'dairy',
#   'name': 'Cheese, cream',
#   'id': '01017',
#   'nutrient': 'Water',
#   'value': '52.62',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff316'),
#   'category': 'dairy',
#   'name': 'Cheese, feta',
#   'id': '01019',
#   'nutrient': 'Water',
#   'value': '55.22',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff31d'),
#   'category': 'dairy',
#   'name': 'Cheese, mozzarella, whole milk',
#   'id': '01026',
#   'nutrient': 'Water',
#   'value': '50.01',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff324'),
#   'category': 'dairy',
#   'name': 'Cream, sour, cultured',
#   'id': '01056',
#   'nutrient': 'Water',
#   'value': '73.07',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff32b'),
#   'category': 'dairy',
#   'name': 'Milk, human, mature, fluid',
#   'id': '01107',
#   'nutrient': 'Water',
#   'value': '87.50',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff332'),
#   'category': 'dairy',
#   'name': 'Cheese product, pasteurized process, American, vitamin D fortified',
#   'id': '01252',
#   'nutrient': 'Water',
#   'value': '45.07',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff339'),
#   'category': 'dairy',
#   'name': 'Yogurt, Greek, plain, whole milk',
#   'id': '01293',
#   'nutrient': 'Water',
#   'value': '81.30',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff340'),
#   'category': 'meats',
#   'name': 'Beef, cured, corned beef, brisket, raw',
#   'id': '13346',
#   'nutrient': 'Water',
#   'value': '66.56',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff347'),
#   'category': 'meats',
#   'name': 'Beef, corned beef hash, with potato, canned',
#   'id': '22908',
#   'nutrient': 'Water',
#   'value': '70.32',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff34e'),
#   'category': 'meats',
#   'name': 'Sandwich spread, pork, beef',
#   'id': '07073',
#   'nutrient': 'Water',
#   'value': '60.28',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff355'),
#   'category': 'meats',
#   'name': 'Snacks, beef jerky, chopped and formed',
#   'id': '19002',
#   'nutrient': 'Water',
#   'value': '23.36',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff35c'),
#   'category': 'meats',
#   'name': 'Bologna, beef',
#   'id': '07007',
#   'nutrient': 'Water',
#   'value': '55.31',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff363'),
#   'category': 'meats',
#   'name': 'Beef, chuck for stew, separable lean and fat, all grades, cooked, braised',
#   'id': '23090',
#   'nutrient': 'Water',
#   'value': '60.08',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff36a'),
#   'category': 'meats',
#   'name': 'Beef, variety meats and by-products, mechanically separated beef, raw',
#   'id': '13330',
#   'nutrient': 'Water',
#   'value': '59.39',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff371'),
#   'category': 'meats',
#   'name': 'Beef, ground, patties, frozen, cooked, broiled',
#   'id': '13317',
#   'nutrient': 'Water',
#   'value': '53.91',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff378'),
#   'category': 'meats',
#   'name': 'Salami, cooked, beef',
#   'id': '07068',
#   'nutrient': 'Water',
#   'value': '60.00',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff37f'),
#   'category': 'meats',
#   'name': 'Bacon and beef sticks',
#   'id': '07921',
#   'nutrient': 'Water',
#   'value': '21.60',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff386'),
#   'category': 'meats',
#   'name': 'Beef, tenderloin, separable lean and fat, trimmed to 1/8" fat, prime, raw',
#   'id': '13926',
#   'nutrient': 'Water',
#   'value': '59.52',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff38d'),
#   'category': 'meats',
#   'name': 'Beef, chuck eye Country-Style ribs, boneless, separable lean and fat, trimmed to 0" fat, select, cooked, braised',
#   'id': '23136',
#   'nutrient': 'Water',
#   'value': '52.74',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff394'),
#   'category': 'meats',
#   'name': 'Beef, rib, shortribs, separable lean and fat, choice, cooked, braised',
#   'id': '13148',
#   'nutrient': 'Water',
#   'value': '35.72',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff39b'),
#   'category': 'meats',
#   'name': 'Ham and cheese spread',
#   'id': '07033',
#   'nutrient': 'Water',
#   'value': '59.13',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff3a2'),
#   'category': 'meats',
#   'name': 'Pork, cured, ham, whole, separable lean only, roasted',
#   'id': '10153',
#   'nutrient': 'Water',
#   'value': '65.78',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff3a9'),
#   'category': 'meats',
#   'name': 'Pork, cured, ham and water product, slice, boneless, separable lean only, heated, pan-broil',
#   'id': '10870',
#   'nutrient': 'Water',
#   'value': '71.20',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff3b0'),
#   'category': 'meats',
#   'name': 'Fish, salmon, sockeye, raw',
#   'id': '15085',
#   'nutrient': 'Water',
#   'value': '72.54',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff3b7'),
#   'category': 'meats',
#   'name': 'Fish, salmon, pink, canned, total can contents',
#   'id': '15084',
#   'nutrient': 'Water',
#   'value': '74.04',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff3be'),
#   'category': 'meats',
#   'name': 'Fish, pollock, Alaska, raw',
#   'id': '15266',
#   'nutrient': 'Water',
#   'value': '81.99',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff3c5'),
#   'category': 'meats',
#   'name': 'Fish, tuna salad',
#   'id': '15128',
#   'nutrient': 'Water',
#   'value': '63.16',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff3cc'),
#   'category': 'meats',
#   'name': 'Fish, salmon, red, canned, bones removed (Alaska Native)',
#   'id': '35157',
#   'nutrient': 'Water',
#   'value': '65.82',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff3d3'),
#   'category': 'meats',
#   'name': 'Fish, bluefish, raw',
#   'id': '15005',
#   'nutrient': 'Water',
#   'value': '70.86',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff3da'),
#   'category': 'meats',
#   'name': 'Fish, carp, cooked, dry heat',
#   'id': '15009',
#   'nutrient': 'Water',
#   'value': '69.63',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff3e1'),
#   'category': 'meats',
#   'name': 'Fish, cod, Atlantic, canned, solids and liquid',
#   'id': '15017',
#   'nutrient': 'Water',
#   'value': '75.61',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff3e8'),
#   'category': 'meats',
#   'name': 'Fish, herring, Atlantic, cooked, dry heat',
#   'id': '15040',
#   'nutrient': 'Water',
#   'value': '64.16',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff3ef'),
#   'category': 'fruit',
#   'name': "Apples, raw, with skin (Includes foods for USDA's Food Distribution Program)",
#   'id': '09003',
#   'nutrient': 'Water',
#   'value': '85.56',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff3f6'),
#   'category': 'fruit',
#   'name': 'Pears, raw',
#   'id': '09252',
#   'nutrient': 'Water',
#   'value': '83.96',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff3fd'),
#   'category': 'fruit',
#   'name': 'Peaches, yellow, raw',
#   'id': '09236',
#   'nutrient': 'Water',
#   'value': '88.87',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff404'),
#   'category': 'fruit',
#   'name': 'Papayas, raw',
#   'id': '09226',
#   'nutrient': 'Water',
#   'value': '88.06',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff40b'),
#   'category': 'fruit',
#   'name': 'Blueberries, raw',
#   'id': '09050',
#   'nutrient': 'Water',
#   'value': '84.21',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff412'),
#   'category': 'fruit',
#   'name': 'Strawberries, raw',
#   'id': '09316',
#   'nutrient': 'Water',
#   'value': '90.95',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff419'),
#   'category': 'fruit',
#   'name': 'Bananas, raw',
#   'id': '09040',
#   'nutrient': 'Water',
#   'value': '74.91',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff420'),
#   'category': 'fruit',
#   'name': 'Kiwifruit, green, raw',
#   'id': '09148',
#   'nutrient': 'Water',
#   'value': '83.07',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff427'),
#   'category': 'fruit',
#   'name': 'Oranges, raw, all commercial varieties',
#   'id': '09200',
#   'nutrient': 'Water',
#   'value': '86.75',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff42e'),
#   'category': 'fruit',
#   'name': 'Avocados, raw, all commercial varieties',
#   'id': '09037',
#   'nutrient': 'Water',
#   'value': '73.23',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff435'),
#   'category': 'fruit',
#   'name': 'Grapefruit, raw, pink and red and white, all areas',
#   'id': '09111',
#   'nutrient': 'Water',
#   'value': '90.89',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff43c'),
#   'category': 'fruit',
#   'name': 'Grapes, american type (slip skin), raw',
#   'id': '09131',
#   'nutrient': 'Water',
#   'value': '81.30',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff443'),
#   'category': 'fruit',
#   'name': 'Cherries, sweet, raw',
#   'id': '09070',
#   'nutrient': 'Water',
#   'value': '82.25',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff44a'),
#   'category': 'fruit',
#   'name': 'Lemons, raw, without peel',
#   'id': '09150',
#   'nutrient': 'Water',
#   'value': '88.98',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff451'),
#   'category': 'fruit',
#   'name': 'Mangos, raw',
#   'id': '09176',
#   'nutrient': 'Water',
#   'value': '83.46',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff458'),
#   'category': 'fruit',
#   'name': 'Limes, raw',
#   'id': '09159',
#   'nutrient': 'Water',
#   'value': '88.26',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff45f'),
#   'category': 'fruit',
#   'name': 'Plums, raw',
#   'id': '09279',
#   'nutrient': 'Water',
#   'value': '87.23',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff466'),
#   'category': 'fruit',
#   'name': 'Watermelon, raw',
#   'id': '09326',
#   'nutrient': 'Water',
#   'value': '91.45',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff46d'),
#   'category': 'fruit',
#   'name': 'Raspberries, raw',
#   'id': '09302',
#   'nutrient': 'Water',
#   'value': '85.75',
#   'unit': 'g'}]

# %%
x=list(db.data_csv.find({'id': 27481}))[0]
x['sugars']
list(db.data_api.find())
# Out:
# [{'_id': ObjectId('5c9fe3034ae97b5be81ff148'),
#   'category': 'vegetables',
#   'name': 'Asparagus, raw',
#   'id': '11011',
#   'nutrient': 'Water',
#   'value': '93.22',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff149'),
#   'category': 'vegetables',
#   'name': 'Asparagus, raw',
#   'id': '11011',
#   'nutrient': 'Energy',
#   'value': '20',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff14a'),
#   'category': 'vegetables',
#   'name': 'Asparagus, raw',
#   'id': '11011',
#   'nutrient': 'Protein',
#   'value': '2.20',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff14b'),
#   'category': 'vegetables',
#   'name': 'Asparagus, raw',
#   'id': '11011',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.12',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff14c'),
#   'category': 'vegetables',
#   'name': 'Asparagus, raw',
#   'id': '11011',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '3.88',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff14d'),
#   'category': 'vegetables',
#   'name': 'Asparagus, raw',
#   'id': '11011',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.1',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff14e'),
#   'category': 'vegetables',
#   'name': 'Asparagus, raw',
#   'id': '11011',
#   'nutrient': 'Sugars, total',
#   'value': '1.88',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff14f'),
#   'category': 'vegetables',
#   'name': 'Beets, raw',
#   'id': '11080',
#   'nutrient': 'Water',
#   'value': '87.58',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff150'),
#   'category': 'vegetables',
#   'name': 'Beets, raw',
#   'id': '11080',
#   'nutrient': 'Energy',
#   'value': '43',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff151'),
#   'category': 'vegetables',
#   'name': 'Beets, raw',
#   'id': '11080',
#   'nutrient': 'Protein',
#   'value': '1.61',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff152'),
#   'category': 'vegetables',
#   'name': 'Beets, raw',
#   'id': '11080',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.17',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff153'),
#   'category': 'vegetables',
#   'name': 'Beets, raw',
#   'id': '11080',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '9.56',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff154'),
#   'category': 'vegetables',
#   'name': 'Beets, raw',
#   'id': '11080',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.8',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff155'),
#   'category': 'vegetables',
#   'name': 'Beets, raw',
#   'id': '11080',
#   'nutrient': 'Sugars, total',
#   'value': '6.76',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff156'),
#   'category': 'vegetables',
#   'name': 'Broccoli, raw',
#   'id': '11090',
#   'nutrient': 'Water',
#   'value': '89.30',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff157'),
#   'category': 'vegetables',
#   'name': 'Broccoli, raw',
#   'id': '11090',
#   'nutrient': 'Energy',
#   'value': '34',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff158'),
#   'category': 'vegetables',
#   'name': 'Broccoli, raw',
#   'id': '11090',
#   'nutrient': 'Protein',
#   'value': '2.82',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff159'),
#   'category': 'vegetables',
#   'name': 'Broccoli, raw',
#   'id': '11090',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.37',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff15a'),
#   'category': 'vegetables',
#   'name': 'Broccoli, raw',
#   'id': '11090',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '6.64',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff15b'),
#   'category': 'vegetables',
#   'name': 'Broccoli, raw',
#   'id': '11090',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.6',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff15c'),
#   'category': 'vegetables',
#   'name': 'Broccoli, raw',
#   'id': '11090',
#   'nutrient': 'Sugars, total',
#   'value': '1.70',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff15d'),
#   'category': 'vegetables',
#   'name': 'Cabbage, raw',
#   'id': '11109',
#   'nutrient': 'Water',
#   'value': '92.18',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff15e'),
#   'category': 'vegetables',
#   'name': 'Cabbage, raw',
#   'id': '11109',
#   'nutrient': 'Energy',
#   'value': '25',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff15f'),
#   'category': 'vegetables',
#   'name': 'Cabbage, raw',
#   'id': '11109',
#   'nutrient': 'Protein',
#   'value': '1.28',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff160'),
#   'category': 'vegetables',
#   'name': 'Cabbage, raw',
#   'id': '11109',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.10',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff161'),
#   'category': 'vegetables',
#   'name': 'Cabbage, raw',
#   'id': '11109',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '5.80',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff162'),
#   'category': 'vegetables',
#   'name': 'Cabbage, raw',
#   'id': '11109',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.5',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff163'),
#   'category': 'vegetables',
#   'name': 'Cabbage, raw',
#   'id': '11109',
#   'nutrient': 'Sugars, total',
#   'value': '3.20',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff164'),
#   'category': 'vegetables',
#   'name': 'Carrots, raw',
#   'id': '11124',
#   'nutrient': 'Water',
#   'value': '88.29',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff165'),
#   'category': 'vegetables',
#   'name': 'Carrots, raw',
#   'id': '11124',
#   'nutrient': 'Energy',
#   'value': '41',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff166'),
#   'category': 'vegetables',
#   'name': 'Carrots, raw',
#   'id': '11124',
#   'nutrient': 'Protein',
#   'value': '0.93',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff167'),
#   'category': 'vegetables',
#   'name': 'Carrots, raw',
#   'id': '11124',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.24',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff168'),
#   'category': 'vegetables',
#   'name': 'Carrots, raw',
#   'id': '11124',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '9.58',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff169'),
#   'category': 'vegetables',
#   'name': 'Carrots, raw',
#   'id': '11124',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.8',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff16a'),
#   'category': 'vegetables',
#   'name': 'Carrots, raw',
#   'id': '11124',
#   'nutrient': 'Sugars, total',
#   'value': '4.74',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff16b'),
#   'category': 'vegetables',
#   'name': 'Cauliflower, raw',
#   'id': '11135',
#   'nutrient': 'Water',
#   'value': '92.07',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff16c'),
#   'category': 'vegetables',
#   'name': 'Cauliflower, raw',
#   'id': '11135',
#   'nutrient': 'Energy',
#   'value': '25',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff16d'),
#   'category': 'vegetables',
#   'name': 'Cauliflower, raw',
#   'id': '11135',
#   'nutrient': 'Protein',
#   'value': '1.92',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff16e'),
#   'category': 'vegetables',
#   'name': 'Cauliflower, raw',
#   'id': '11135',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.28',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff16f'),
#   'category': 'vegetables',
#   'name': 'Cauliflower, raw',
#   'id': '11135',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '4.97',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff170'),
#   'category': 'vegetables',
#   'name': 'Cauliflower, raw',
#   'id': '11135',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.0',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff171'),
#   'category': 'vegetables',
#   'name': 'Cauliflower, raw',
#   'id': '11135',
#   'nutrient': 'Sugars, total',
#   'value': '1.91',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff172'),
#   'category': 'vegetables',
#   'name': 'Celery, raw',
#   'id': '11143',
#   'nutrient': 'Water',
#   'value': '95.43',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff173'),
#   'category': 'vegetables',
#   'name': 'Celery, raw',
#   'id': '11143',
#   'nutrient': 'Energy',
#   'value': '14',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff174'),
#   'category': 'vegetables',
#   'name': 'Celery, raw',
#   'id': '11143',
#   'nutrient': 'Protein',
#   'value': '0.69',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff175'),
#   'category': 'vegetables',
#   'name': 'Celery, raw',
#   'id': '11143',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.17',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff176'),
#   'category': 'vegetables',
#   'name': 'Celery, raw',
#   'id': '11143',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '2.97',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff177'),
#   'category': 'vegetables',
#   'name': 'Celery, raw',
#   'id': '11143',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.6',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff178'),
#   'category': 'vegetables',
#   'name': 'Celery, raw',
#   'id': '11143',
#   'nutrient': 'Sugars, total',
#   'value': '1.34',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff179'),
#   'category': 'vegetables',
#   'name': 'Cucumber, with peel, raw',
#   'id': '11205',
#   'nutrient': 'Water',
#   'value': '95.23',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff17a'),
#   'category': 'vegetables',
#   'name': 'Cucumber, with peel, raw',
#   'id': '11205',
#   'nutrient': 'Energy',
#   'value': '15',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff17b'),
#   'category': 'vegetables',
#   'name': 'Cucumber, with peel, raw',
#   'id': '11205',
#   'nutrient': 'Protein',
#   'value': '0.65',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff17c'),
#   'category': 'vegetables',
#   'name': 'Cucumber, with peel, raw',
#   'id': '11205',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.11',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff17d'),
#   'category': 'vegetables',
#   'name': 'Cucumber, with peel, raw',
#   'id': '11205',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '3.63',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff17e'),
#   'category': 'vegetables',
#   'name': 'Cucumber, with peel, raw',
#   'id': '11205',
#   'nutrient': 'Fiber, total dietary',
#   'value': '0.5',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff17f'),
#   'category': 'vegetables',
#   'name': 'Cucumber, with peel, raw',
#   'id': '11205',
#   'nutrient': 'Sugars, total',
#   'value': '1.67',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff180'),
#   'category': 'vegetables',
#   'name': 'Eggplant, cooked, boiled, drained, without salt',
#   'id': '11210',
#   'nutrient': 'Water',
#   'value': '89.67',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff181'),
#   'category': 'vegetables',
#   'name': 'Eggplant, cooked, boiled, drained, without salt',
#   'id': '11210',
#   'nutrient': 'Energy',
#   'value': '35',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff182'),
#   'category': 'vegetables',
#   'name': 'Eggplant, cooked, boiled, drained, without salt',
#   'id': '11210',
#   'nutrient': 'Protein',
#   'value': '0.83',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff183'),
#   'category': 'vegetables',
#   'name': 'Eggplant, cooked, boiled, drained, without salt',
#   'id': '11210',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.23',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff184'),
#   'category': 'vegetables',
#   'name': 'Eggplant, cooked, boiled, drained, without salt',
#   'id': '11210',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '8.73',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff185'),
#   'category': 'vegetables',
#   'name': 'Eggplant, cooked, boiled, drained, without salt',
#   'id': '11210',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.5',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff186'),
#   'category': 'vegetables',
#   'name': 'Eggplant, cooked, boiled, drained, without salt',
#   'id': '11210',
#   'nutrient': 'Sugars, total',
#   'value': '3.20',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff187'),
#   'category': 'vegetables',
#   'name': 'Mushrooms, shiitake, raw',
#   'id': '11238',
#   'nutrient': 'Water',
#   'value': '89.74',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff188'),
#   'category': 'vegetables',
#   'name': 'Mushrooms, shiitake, raw',
#   'id': '11238',
#   'nutrient': 'Energy',
#   'value': '34',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff189'),
#   'category': 'vegetables',
#   'name': 'Mushrooms, shiitake, raw',
#   'id': '11238',
#   'nutrient': 'Protein',
#   'value': '2.24',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff18a'),
#   'category': 'vegetables',
#   'name': 'Mushrooms, shiitake, raw',
#   'id': '11238',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.49',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff18b'),
#   'category': 'vegetables',
#   'name': 'Mushrooms, shiitake, raw',
#   'id': '11238',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '6.79',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff18c'),
#   'category': 'vegetables',
#   'name': 'Mushrooms, shiitake, raw',
#   'id': '11238',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.5',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff18d'),
#   'category': 'vegetables',
#   'name': 'Mushrooms, shiitake, raw',
#   'id': '11238',
#   'nutrient': 'Sugars, total',
#   'value': '2.38',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff18e'),
#   'category': 'vegetables',
#   'name': 'Lentils, sprouted, raw',
#   'id': '11248',
#   'nutrient': 'Water',
#   'value': '67.34',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff18f'),
#   'category': 'vegetables',
#   'name': 'Lentils, sprouted, raw',
#   'id': '11248',
#   'nutrient': 'Energy',
#   'value': '106',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff190'),
#   'category': 'vegetables',
#   'name': 'Lentils, sprouted, raw',
#   'id': '11248',
#   'nutrient': 'Protein',
#   'value': '8.96',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff191'),
#   'category': 'vegetables',
#   'name': 'Lentils, sprouted, raw',
#   'id': '11248',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.55',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff192'),
#   'category': 'vegetables',
#   'name': 'Lentils, sprouted, raw',
#   'id': '11248',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '22.14',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff193'),
#   'category': 'vegetables',
#   'name': 'Lentils, sprouted, raw',
#   'id': '11248',
#   'nutrient': 'Calcium, Ca',
#   'value': '25',
#   'unit': 'mg'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff194'),
#   'category': 'vegetables',
#   'name': 'Lentils, sprouted, raw',
#   'id': '11248',
#   'nutrient': 'Iron, Fe',
#   'value': '3.21',
#   'unit': 'mg'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff195'),
#   'category': 'vegetables',
#   'name': 'Lettuce, green leaf, raw',
#   'id': '11253',
#   'nutrient': 'Water',
#   'value': '94.98',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff196'),
#   'category': 'vegetables',
#   'name': 'Lettuce, green leaf, raw',
#   'id': '11253',
#   'nutrient': 'Energy',
#   'value': '15',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff197'),
#   'category': 'vegetables',
#   'name': 'Lettuce, green leaf, raw',
#   'id': '11253',
#   'nutrient': 'Protein',
#   'value': '1.36',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff198'),
#   'category': 'vegetables',
#   'name': 'Lettuce, green leaf, raw',
#   'id': '11253',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.15',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff199'),
#   'category': 'vegetables',
#   'name': 'Lettuce, green leaf, raw',
#   'id': '11253',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '2.87',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff19a'),
#   'category': 'vegetables',
#   'name': 'Lettuce, green leaf, raw',
#   'id': '11253',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.3',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff19b'),
#   'category': 'vegetables',
#   'name': 'Lettuce, green leaf, raw',
#   'id': '11253',
#   'nutrient': 'Sugars, total',
#   'value': '0.78',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff19c'),
#   'category': 'vegetables',
#   'name': 'Onions, sweet, raw',
#   'id': '11294',
#   'nutrient': 'Water',
#   'value': '91.24',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff19d'),
#   'category': 'vegetables',
#   'name': 'Onions, sweet, raw',
#   'id': '11294',
#   'nutrient': 'Energy',
#   'value': '32',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff19e'),
#   'category': 'vegetables',
#   'name': 'Onions, sweet, raw',
#   'id': '11294',
#   'nutrient': 'Protein',
#   'value': '0.80',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff19f'),
#   'category': 'vegetables',
#   'name': 'Onions, sweet, raw',
#   'id': '11294',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.08',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1a0'),
#   'category': 'vegetables',
#   'name': 'Onions, sweet, raw',
#   'id': '11294',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '7.55',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1a1'),
#   'category': 'vegetables',
#   'name': 'Onions, sweet, raw',
#   'id': '11294',
#   'nutrient': 'Fiber, total dietary',
#   'value': '0.9',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1a2'),
#   'category': 'vegetables',
#   'name': 'Onions, sweet, raw',
#   'id': '11294',
#   'nutrient': 'Sugars, total',
#   'value': '5.02',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1a3'),
#   'category': 'vegetables',
#   'name': 'Peas, green, raw',
#   'id': '11304',
#   'nutrient': 'Water',
#   'value': '78.86',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1a4'),
#   'category': 'vegetables',
#   'name': 'Peas, green, raw',
#   'id': '11304',
#   'nutrient': 'Energy',
#   'value': '81',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1a5'),
#   'category': 'vegetables',
#   'name': 'Peas, green, raw',
#   'id': '11304',
#   'nutrient': 'Protein',
#   'value': '5.42',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1a6'),
#   'category': 'vegetables',
#   'name': 'Peas, green, raw',
#   'id': '11304',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.40',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1a7'),
#   'category': 'vegetables',
#   'name': 'Peas, green, raw',
#   'id': '11304',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '14.45',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1a8'),
#   'category': 'vegetables',
#   'name': 'Peas, green, raw',
#   'id': '11304',
#   'nutrient': 'Fiber, total dietary',
#   'value': '5.7',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1a9'),
#   'category': 'vegetables',
#   'name': 'Peas, green, raw',
#   'id': '11304',
#   'nutrient': 'Sugars, total',
#   'value': '5.67',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1aa'),
#   'category': 'vegetables',
#   'name': 'Peppers, sweet, green, raw',
#   'id': '11333',
#   'nutrient': 'Water',
#   'value': '93.89',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1ab'),
#   'category': 'vegetables',
#   'name': 'Peppers, sweet, green, raw',
#   'id': '11333',
#   'nutrient': 'Energy',
#   'value': '20',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1ac'),
#   'category': 'vegetables',
#   'name': 'Peppers, sweet, green, raw',
#   'id': '11333',
#   'nutrient': 'Protein',
#   'value': '0.86',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1ad'),
#   'category': 'vegetables',
#   'name': 'Peppers, sweet, green, raw',
#   'id': '11333',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.17',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1ae'),
#   'category': 'vegetables',
#   'name': 'Peppers, sweet, green, raw',
#   'id': '11333',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '4.64',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1af'),
#   'category': 'vegetables',
#   'name': 'Peppers, sweet, green, raw',
#   'id': '11333',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.7',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1b0'),
#   'category': 'vegetables',
#   'name': 'Peppers, sweet, green, raw',
#   'id': '11333',
#   'nutrient': 'Sugars, total',
#   'value': '2.40',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1b1'),
#   'category': 'vegetables',
#   'name': 'Potatoes, white, flesh and skin, baked',
#   'id': '11357',
#   'nutrient': 'Water',
#   'value': '75.43',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1b2'),
#   'category': 'vegetables',
#   'name': 'Potatoes, white, flesh and skin, baked',
#   'id': '11357',
#   'nutrient': 'Energy',
#   'value': '92',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1b3'),
#   'category': 'vegetables',
#   'name': 'Potatoes, white, flesh and skin, baked',
#   'id': '11357',
#   'nutrient': 'Protein',
#   'value': '2.10',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1b4'),
#   'category': 'vegetables',
#   'name': 'Potatoes, white, flesh and skin, baked',
#   'id': '11357',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.15',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1b5'),
#   'category': 'vegetables',
#   'name': 'Potatoes, white, flesh and skin, baked',
#   'id': '11357',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '21.08',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1b6'),
#   'category': 'vegetables',
#   'name': 'Potatoes, white, flesh and skin, baked',
#   'id': '11357',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.1',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1b7'),
#   'category': 'vegetables',
#   'name': 'Potatoes, white, flesh and skin, baked',
#   'id': '11357',
#   'nutrient': 'Sugars, total',
#   'value': '1.53',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1b8'),
#   'category': 'vegetables',
#   'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'id': '11484',
#   'nutrient': 'Water',
#   'value': '89.70',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1b9'),
#   'category': 'vegetables',
#   'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'id': '11484',
#   'nutrient': 'Energy',
#   'value': '34',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1ba'),
#   'category': 'vegetables',
#   'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'id': '11484',
#   'nutrient': 'Protein',
#   'value': '0.67',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1bb'),
#   'category': 'vegetables',
#   'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'id': '11484',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.08',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1bc'),
#   'category': 'vegetables',
#   'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'id': '11484',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '8.79',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1bd'),
#   'category': 'vegetables',
#   'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'id': '11484',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.6',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1be'),
#   'category': 'vegetables',
#   'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'id': '11484',
#   'nutrient': 'Calcium, Ca',
#   'value': '26',
#   'unit': 'mg'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1bf'),
#   'category': 'vegetables',
#   'name': 'Tomatoes, orange, raw',
#   'id': '11695',
#   'nutrient': 'Water',
#   'value': '94.78',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1c0'),
#   'category': 'vegetables',
#   'name': 'Tomatoes, orange, raw',
#   'id': '11695',
#   'nutrient': 'Energy',
#   'value': '16',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1c1'),
#   'category': 'vegetables',
#   'name': 'Tomatoes, orange, raw',
#   'id': '11695',
#   'nutrient': 'Protein',
#   'value': '1.16',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1c2'),
#   'category': 'vegetables',
#   'name': 'Tomatoes, orange, raw',
#   'id': '11695',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.19',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1c3'),
#   'category': 'vegetables',
#   'name': 'Tomatoes, orange, raw',
#   'id': '11695',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '3.18',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1c4'),
#   'category': 'vegetables',
#   'name': 'Tomatoes, orange, raw',
#   'id': '11695',
#   'nutrient': 'Fiber, total dietary',
#   'value': '0.9',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1c5'),
#   'category': 'vegetables',
#   'name': 'Tomatoes, orange, raw',
#   'id': '11695',
#   'nutrient': 'Calcium, Ca',
#   'value': '5',
#   'unit': 'mg'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1c6'),
#   'category': 'vegetables',
#   'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'id': '11932',
#   'nutrient': 'Water',
#   'value': '93.30',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1c7'),
#   'category': 'vegetables',
#   'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'id': '11932',
#   'nutrient': 'Energy',
#   'value': '20',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1c8'),
#   'category': 'vegetables',
#   'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'id': '11932',
#   'nutrient': 'Protein',
#   'value': '1.15',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1c9'),
#   'category': 'vegetables',
#   'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'id': '11932',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.10',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1ca'),
#   'category': 'vegetables',
#   'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'id': '11932',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '4.50',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1cb'),
#   'category': 'vegetables',
#   'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'id': '11932',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.3',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1cc'),
#   'category': 'vegetables',
#   'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'id': '11932',
#   'nutrient': 'Sugars, total',
#   'value': '0.78',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1cd'),
#   'category': 'vegetables',
#   'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'id': '11705',
#   'nutrient': 'Water',
#   'value': '92.63',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1ce'),
#   'category': 'vegetables',
#   'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'id': '11705',
#   'nutrient': 'Energy',
#   'value': '22',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1cf'),
#   'category': 'vegetables',
#   'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'id': '11705',
#   'nutrient': 'Protein',
#   'value': '2.40',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1d0'),
#   'category': 'vegetables',
#   'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'id': '11705',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.22',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1d1'),
#   'category': 'vegetables',
#   'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'id': '11705',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '4.11',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1d2'),
#   'category': 'vegetables',
#   'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'id': '11705',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.0',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1d3'),
#   'category': 'vegetables',
#   'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'id': '11705',
#   'nutrient': 'Sugars, total',
#   'value': '1.30',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1d4'),
#   'category': 'vegetables',
#   'name': 'Garlic, raw',
#   'id': '11215',
#   'nutrient': 'Water',
#   'value': '58.58',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1d5'),
#   'category': 'vegetables',
#   'name': 'Garlic, raw',
#   'id': '11215',
#   'nutrient': 'Energy',
#   'value': '149',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1d6'),
#   'category': 'vegetables',
#   'name': 'Garlic, raw',
#   'id': '11215',
#   'nutrient': 'Protein',
#   'value': '6.36',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1d7'),
#   'category': 'vegetables',
#   'name': 'Garlic, raw',
#   'id': '11215',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.50',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1d8'),
#   'category': 'vegetables',
#   'name': 'Garlic, raw',
#   'id': '11215',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '33.06',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1d9'),
#   'category': 'vegetables',
#   'name': 'Garlic, raw',
#   'id': '11215',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.1',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1da'),
#   'category': 'vegetables',
#   'name': 'Garlic, raw',
#   'id': '11215',
#   'nutrient': 'Sugars, total',
#   'value': '1.00',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1db'),
#   'category': 'vegetables',
#   'name': 'Kale, raw',
#   'id': '11233',
#   'nutrient': 'Water',
#   'value': '89.63',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1dc'),
#   'category': 'vegetables',
#   'name': 'Kale, raw',
#   'id': '11233',
#   'nutrient': 'Energy',
#   'value': '35',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1dd'),
#   'category': 'vegetables',
#   'name': 'Kale, raw',
#   'id': '11233',
#   'nutrient': 'Protein',
#   'value': '2.92',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1de'),
#   'category': 'vegetables',
#   'name': 'Kale, raw',
#   'id': '11233',
#   'nutrient': 'Total lipid (fat)',
#   'value': '1.49',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1df'),
#   'category': 'vegetables',
#   'name': 'Kale, raw',
#   'id': '11233',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '4.42',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1e0'),
#   'category': 'vegetables',
#   'name': 'Kale, raw',
#   'id': '11233',
#   'nutrient': 'Fiber, total dietary',
#   'value': '4.1',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1e1'),
#   'category': 'vegetables',
#   'name': 'Kale, raw',
#   'id': '11233',
#   'nutrient': 'Sugars, total',
#   'value': '0.99',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1e2'),
#   'category': 'vegetables',
#   'name': 'Artichokes, (globe or french), raw',
#   'id': '11007',
#   'nutrient': 'Water',
#   'value': '84.94',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1e3'),
#   'category': 'vegetables',
#   'name': 'Artichokes, (globe or french), raw',
#   'id': '11007',
#   'nutrient': 'Energy',
#   'value': '47',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1e4'),
#   'category': 'vegetables',
#   'name': 'Artichokes, (globe or french), raw',
#   'id': '11007',
#   'nutrient': 'Protein',
#   'value': '3.27',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1e5'),
#   'category': 'vegetables',
#   'name': 'Artichokes, (globe or french), raw',
#   'id': '11007',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.15',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1e6'),
#   'category': 'vegetables',
#   'name': 'Artichokes, (globe or french), raw',
#   'id': '11007',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '10.51',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1e7'),
#   'category': 'vegetables',
#   'name': 'Artichokes, (globe or french), raw',
#   'id': '11007',
#   'nutrient': 'Fiber, total dietary',
#   'value': '5.4',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1e8'),
#   'category': 'vegetables',
#   'name': 'Artichokes, (globe or french), raw',
#   'id': '11007',
#   'nutrient': 'Sugars, total',
#   'value': '0.99',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1e9'),
#   'category': 'grains',
#   'name': 'Bagels, whole grain white',
#   'id': '28319',
#   'nutrient': 'Water',
#   'value': '34.52',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1ea'),
#   'category': 'grains',
#   'name': 'Bagels, whole grain white',
#   'id': '28319',
#   'nutrient': 'Energy',
#   'value': '255',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1eb'),
#   'category': 'grains',
#   'name': 'Bagels, whole grain white',
#   'id': '28319',
#   'nutrient': 'Protein',
#   'value': '9.30',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1ec'),
#   'category': 'grains',
#   'name': 'Bagels, whole grain white',
#   'id': '28319',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.00',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1ed'),
#   'category': 'grains',
#   'name': 'Bagels, whole grain white',
#   'id': '28319',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '54.52',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1ee'),
#   'category': 'grains',
#   'name': 'Bagels, whole grain white',
#   'id': '28319',
#   'nutrient': 'Fiber, total dietary',
#   'value': '4.7',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1ef'),
#   'category': 'grains',
#   'name': 'Bagels, whole grain white',
#   'id': '28319',
#   'nutrient': 'Sugars, total',
#   'value': '9.30',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1f0'),
#   'category': 'grains',
#   'name': 'Rye grain',
#   'id': '20062',
#   'nutrient': 'Water',
#   'value': '10.60',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1f1'),
#   'category': 'grains',
#   'name': 'Rye grain',
#   'id': '20062',
#   'nutrient': 'Energy',
#   'value': '338',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1f2'),
#   'category': 'grains',
#   'name': 'Rye grain',
#   'id': '20062',
#   'nutrient': 'Protein',
#   'value': '10.34',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1f3'),
#   'category': 'grains',
#   'name': 'Rye grain',
#   'id': '20062',
#   'nutrient': 'Total lipid (fat)',
#   'value': '1.63',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1f4'),
#   'category': 'grains',
#   'name': 'Rye grain',
#   'id': '20062',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '75.86',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1f5'),
#   'category': 'grains',
#   'name': 'Rye grain',
#   'id': '20062',
#   'nutrient': 'Fiber, total dietary',
#   'value': '15.1',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1f6'),
#   'category': 'grains',
#   'name': 'Rye grain',
#   'id': '20062',
#   'nutrient': 'Sugars, total',
#   'value': '0.98',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1f7'),
#   'category': 'grains',
#   'name': 'Corn grain, yellow',
#   'id': '20014',
#   'nutrient': 'Water',
#   'value': '10.37',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1f8'),
#   'category': 'grains',
#   'name': 'Corn grain, yellow',
#   'id': '20014',
#   'nutrient': 'Energy',
#   'value': '365',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1f9'),
#   'category': 'grains',
#   'name': 'Corn grain, yellow',
#   'id': '20014',
#   'nutrient': 'Protein',
#   'value': '9.42',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1fa'),
#   'category': 'grains',
#   'name': 'Corn grain, yellow',
#   'id': '20014',
#   'nutrient': 'Total lipid (fat)',
#   'value': '4.74',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1fb'),
#   'category': 'grains',
#   'name': 'Corn grain, yellow',
#   'id': '20014',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '74.26',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1fc'),
#   'category': 'grains',
#   'name': 'Corn grain, yellow',
#   'id': '20014',
#   'nutrient': 'Fiber, total dietary',
#   'value': '7.3',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1fd'),
#   'category': 'grains',
#   'name': 'Corn grain, yellow',
#   'id': '20014',
#   'nutrient': 'Sugars, total',
#   'value': '0.64',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1fe'),
#   'category': 'grains',
#   'name': 'Corn flour, whole-grain, yellow',
#   'id': '20016',
#   'nutrient': 'Water',
#   'value': '10.91',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff1ff'),
#   'category': 'grains',
#   'name': 'Corn flour, whole-grain, yellow',
#   'id': '20016',
#   'nutrient': 'Energy',
#   'value': '361',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff200'),
#   'category': 'grains',
#   'name': 'Corn flour, whole-grain, yellow',
#   'id': '20016',
#   'nutrient': 'Protein',
#   'value': '6.93',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff201'),
#   'category': 'grains',
#   'name': 'Corn flour, whole-grain, yellow',
#   'id': '20016',
#   'nutrient': 'Total lipid (fat)',
#   'value': '3.86',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff202'),
#   'category': 'grains',
#   'name': 'Corn flour, whole-grain, yellow',
#   'id': '20016',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '76.85',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff203'),
#   'category': 'grains',
#   'name': 'Corn flour, whole-grain, yellow',
#   'id': '20016',
#   'nutrient': 'Fiber, total dietary',
#   'value': '7.3',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff204'),
#   'category': 'grains',
#   'name': 'Corn flour, whole-grain, yellow',
#   'id': '20016',
#   'nutrient': 'Sugars, total',
#   'value': '0.64',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff205'),
#   'category': 'grains',
#   'name': 'Rice, white, long-grain, regular, raw, enriched',
#   'id': '20044',
#   'nutrient': 'Water',
#   'value': '11.62',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff206'),
#   'category': 'grains',
#   'name': 'Rice, white, long-grain, regular, raw, enriched',
#   'id': '20044',
#   'nutrient': 'Energy',
#   'value': '365',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff207'),
#   'category': 'grains',
#   'name': 'Rice, white, long-grain, regular, raw, enriched',
#   'id': '20044',
#   'nutrient': 'Protein',
#   'value': '7.13',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff208'),
#   'category': 'grains',
#   'name': 'Rice, white, long-grain, regular, raw, enriched',
#   'id': '20044',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.66',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff209'),
#   'category': 'grains',
#   'name': 'Rice, white, long-grain, regular, raw, enriched',
#   'id': '20044',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '79.95',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff20a'),
#   'category': 'grains',
#   'name': 'Rice, white, long-grain, regular, raw, enriched',
#   'id': '20044',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.3',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff20b'),
#   'category': 'grains',
#   'name': 'Rice, white, long-grain, regular, raw, enriched',
#   'id': '20044',
#   'nutrient': 'Sugars, total',
#   'value': '0.12',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff20c'),
#   'category': 'grains',
#   'name': 'Pasta, whole grain, 51% whole wheat, remaining unenriched semolina, dry',
#   'id': '20135',
#   'nutrient': 'Water',
#   'value': '8.85',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff20d'),
#   'category': 'grains',
#   'name': 'Pasta, whole grain, 51% whole wheat, remaining unenriched semolina, dry',
#   'id': '20135',
#   'nutrient': 'Energy',
#   'value': '362',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff20e'),
#   'category': 'grains',
#   'name': 'Pasta, whole grain, 51% whole wheat, remaining unenriched semolina, dry',
#   'id': '20135',
#   'nutrient': 'Protein',
#   'value': '13.51',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff20f'),
#   'category': 'grains',
#   'name': 'Pasta, whole grain, 51% whole wheat, remaining unenriched semolina, dry',
#   'id': '20135',
#   'nutrient': 'Total lipid (fat)',
#   'value': '2.68',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff210'),
#   'category': 'grains',
#   'name': 'Pasta, whole grain, 51% whole wheat, remaining unenriched semolina, dry',
#   'id': '20135',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '73.10',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff211'),
#   'category': 'grains',
#   'name': 'Pasta, whole grain, 51% whole wheat, remaining unenriched semolina, dry',
#   'id': '20135',
#   'nutrient': 'Fiber, total dietary',
#   'value': '10.1',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff212'),
#   'category': 'grains',
#   'name': 'Pasta, whole grain, 51% whole wheat, remaining unenriched semolina, dry',
#   'id': '20135',
#   'nutrient': 'Sugars, total',
#   'value': '2.60',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff213'),
#   'category': 'grains',
#   'name': 'Wheat flour, whole-grain, soft wheat',
#   'id': '20649',
#   'nutrient': 'Water',
#   'value': '12.42',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff214'),
#   'category': 'grains',
#   'name': 'Wheat flour, whole-grain, soft wheat',
#   'id': '20649',
#   'nutrient': 'Energy',
#   'value': '332',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff215'),
#   'category': 'grains',
#   'name': 'Wheat flour, whole-grain, soft wheat',
#   'id': '20649',
#   'nutrient': 'Protein',
#   'value': '9.61',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff216'),
#   'category': 'grains',
#   'name': 'Wheat flour, whole-grain, soft wheat',
#   'id': '20649',
#   'nutrient': 'Total lipid (fat)',
#   'value': '1.95',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff217'),
#   'category': 'grains',
#   'name': 'Wheat flour, whole-grain, soft wheat',
#   'id': '20649',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '74.48',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff218'),
#   'category': 'grains',
#   'name': 'Wheat flour, whole-grain, soft wheat',
#   'id': '20649',
#   'nutrient': 'Fiber, total dietary',
#   'value': '13.1',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff219'),
#   'category': 'grains',
#   'name': 'Wheat flour, whole-grain, soft wheat',
#   'id': '20649',
#   'nutrient': 'Sugars, total',
#   'value': '1.02',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff21a'),
#   'category': 'grains',
#   'name': 'Pasta, gluten-free, corn, dry',
#   'id': '20091',
#   'nutrient': 'Water',
#   'value': '10.00',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff21b'),
#   'category': 'grains',
#   'name': 'Pasta, gluten-free, corn, dry',
#   'id': '20091',
#   'nutrient': 'Energy',
#   'value': '357',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff21c'),
#   'category': 'grains',
#   'name': 'Pasta, gluten-free, corn, dry',
#   'id': '20091',
#   'nutrient': 'Protein',
#   'value': '7.46',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff21d'),
#   'category': 'grains',
#   'name': 'Pasta, gluten-free, corn, dry',
#   'id': '20091',
#   'nutrient': 'Total lipid (fat)',
#   'value': '2.08',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff21e'),
#   'category': 'grains',
#   'name': 'Pasta, gluten-free, corn, dry',
#   'id': '20091',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '79.26',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff21f'),
#   'category': 'grains',
#   'name': 'Pasta, gluten-free, corn, dry',
#   'id': '20091',
#   'nutrient': 'Fiber, total dietary',
#   'value': '11.0',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff220'),
#   'category': 'grains',
#   'name': 'Pasta, gluten-free, corn, dry',
#   'id': '20091',
#   'nutrient': 'Calcium, Ca',
#   'value': '4',
#   'unit': 'mg'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff221'),
#   'category': 'grains',
#   'name': 'Pasta, gluten-free, corn and rice flour, cooked',
#   'id': '20657',
#   'nutrient': 'Water',
#   'value': '57.67',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff222'),
#   'category': 'grains',
#   'name': 'Pasta, gluten-free, corn and rice flour, cooked',
#   'id': '20657',
#   'nutrient': 'Energy',
#   'value': '179',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff223'),
#   'category': 'grains',
#   'name': 'Pasta, gluten-free, corn and rice flour, cooked',
#   'id': '20657',
#   'nutrient': 'Protein',
#   'value': '3.20',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff224'),
#   'category': 'grains',
#   'name': 'Pasta, gluten-free, corn and rice flour, cooked',
#   'id': '20657',
#   'nutrient': 'Total lipid (fat)',
#   'value': '1.00',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff225'),
#   'category': 'grains',
#   'name': 'Pasta, gluten-free, corn and rice flour, cooked',
#   'id': '20657',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '38.05',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff226'),
#   'category': 'grains',
#   'name': 'Pasta, gluten-free, corn and rice flour, cooked',
#   'id': '20657',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.4',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff227'),
#   'category': 'grains',
#   'name': 'Pasta, gluten-free, corn and rice flour, cooked',
#   'id': '20657',
#   'nutrient': 'Sugars, total',
#   'value': '0.00',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff228'),
#   'category': 'grains',
#   'name': 'Pasta, dry, enriched',
#   'id': '20120',
#   'nutrient': 'Water',
#   'value': '9.90',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff229'),
#   'category': 'grains',
#   'name': 'Pasta, dry, enriched',
#   'id': '20120',
#   'nutrient': 'Energy',
#   'value': '371',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff22a'),
#   'category': 'grains',
#   'name': 'Pasta, dry, enriched',
#   'id': '20120',
#   'nutrient': 'Protein',
#   'value': '13.04',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff22b'),
#   'category': 'grains',
#   'name': 'Pasta, dry, enriched',
#   'id': '20120',
#   'nutrient': 'Total lipid (fat)',
#   'value': '1.51',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff22c'),
#   'category': 'grains',
#   'name': 'Pasta, dry, enriched',
#   'id': '20120',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '74.67',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff22d'),
#   'category': 'grains',
#   'name': 'Pasta, dry, enriched',
#   'id': '20120',
#   'nutrient': 'Fiber, total dietary',
#   'value': '3.2',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff22e'),
#   'category': 'grains',
#   'name': 'Pasta, dry, enriched',
#   'id': '20120',
#   'nutrient': 'Sugars, total',
#   'value': '2.67',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff22f'),
#   'category': 'grains',
#   'name': 'Nuts, pine nuts, dried',
#   'id': '12147',
#   'nutrient': 'Water',
#   'value': '2.28',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff230'),
#   'category': 'grains',
#   'name': 'Nuts, pine nuts, dried',
#   'id': '12147',
#   'nutrient': 'Energy',
#   'value': '673',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff231'),
#   'category': 'grains',
#   'name': 'Nuts, pine nuts, dried',
#   'id': '12147',
#   'nutrient': 'Protein',
#   'value': '13.69',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff232'),
#   'category': 'grains',
#   'name': 'Nuts, pine nuts, dried',
#   'id': '12147',
#   'nutrient': 'Total lipid (fat)',
#   'value': '68.37',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff233'),
#   'category': 'grains',
#   'name': 'Nuts, pine nuts, dried',
#   'id': '12147',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '13.08',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff234'),
#   'category': 'grains',
#   'name': 'Nuts, pine nuts, dried',
#   'id': '12147',
#   'nutrient': 'Fiber, total dietary',
#   'value': '3.7',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff235'),
#   'category': 'grains',
#   'name': 'Nuts, pine nuts, dried',
#   'id': '12147',
#   'nutrient': 'Sugars, total',
#   'value': '3.59',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff236'),
#   'category': 'grains',
#   'name': 'Nuts, cashew nuts, oil roasted, with salt added',
#   'id': '12586',
#   'nutrient': 'Water',
#   'value': '2.34',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff237'),
#   'category': 'grains',
#   'name': 'Nuts, cashew nuts, oil roasted, with salt added',
#   'id': '12586',
#   'nutrient': 'Energy',
#   'value': '581',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff238'),
#   'category': 'grains',
#   'name': 'Nuts, cashew nuts, oil roasted, with salt added',
#   'id': '12586',
#   'nutrient': 'Protein',
#   'value': '16.84',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff239'),
#   'category': 'grains',
#   'name': 'Nuts, cashew nuts, oil roasted, with salt added',
# ...
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff421'),
#   'category': 'fruit',
#   'name': 'Kiwifruit, green, raw',
#   'id': '09148',
#   'nutrient': 'Energy',
#   'value': '61',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff422'),
#   'category': 'fruit',
#   'name': 'Kiwifruit, green, raw',
#   'id': '09148',
#   'nutrient': 'Protein',
#   'value': '1.14',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff423'),
#   'category': 'fruit',
#   'name': 'Kiwifruit, green, raw',
#   'id': '09148',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.52',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff424'),
#   'category': 'fruit',
#   'name': 'Kiwifruit, green, raw',
#   'id': '09148',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '14.66',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff425'),
#   'category': 'fruit',
#   'name': 'Kiwifruit, green, raw',
#   'id': '09148',
#   'nutrient': 'Fiber, total dietary',
#   'value': '3.0',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff426'),
#   'category': 'fruit',
#   'name': 'Kiwifruit, green, raw',
#   'id': '09148',
#   'nutrient': 'Sugars, total',
#   'value': '8.99',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff427'),
#   'category': 'fruit',
#   'name': 'Oranges, raw, all commercial varieties',
#   'id': '09200',
#   'nutrient': 'Water',
#   'value': '86.75',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff428'),
#   'category': 'fruit',
#   'name': 'Oranges, raw, all commercial varieties',
#   'id': '09200',
#   'nutrient': 'Energy',
#   'value': '47',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff429'),
#   'category': 'fruit',
#   'name': 'Oranges, raw, all commercial varieties',
#   'id': '09200',
#   'nutrient': 'Protein',
#   'value': '0.94',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff42a'),
#   'category': 'fruit',
#   'name': 'Oranges, raw, all commercial varieties',
#   'id': '09200',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.12',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff42b'),
#   'category': 'fruit',
#   'name': 'Oranges, raw, all commercial varieties',
#   'id': '09200',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '11.75',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff42c'),
#   'category': 'fruit',
#   'name': 'Oranges, raw, all commercial varieties',
#   'id': '09200',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.4',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff42d'),
#   'category': 'fruit',
#   'name': 'Oranges, raw, all commercial varieties',
#   'id': '09200',
#   'nutrient': 'Sugars, total',
#   'value': '9.35',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff42e'),
#   'category': 'fruit',
#   'name': 'Avocados, raw, all commercial varieties',
#   'id': '09037',
#   'nutrient': 'Water',
#   'value': '73.23',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff42f'),
#   'category': 'fruit',
#   'name': 'Avocados, raw, all commercial varieties',
#   'id': '09037',
#   'nutrient': 'Energy',
#   'value': '160',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff430'),
#   'category': 'fruit',
#   'name': 'Avocados, raw, all commercial varieties',
#   'id': '09037',
#   'nutrient': 'Protein',
#   'value': '2.00',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff431'),
#   'category': 'fruit',
#   'name': 'Avocados, raw, all commercial varieties',
#   'id': '09037',
#   'nutrient': 'Total lipid (fat)',
#   'value': '14.66',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff432'),
#   'category': 'fruit',
#   'name': 'Avocados, raw, all commercial varieties',
#   'id': '09037',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '8.53',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff433'),
#   'category': 'fruit',
#   'name': 'Avocados, raw, all commercial varieties',
#   'id': '09037',
#   'nutrient': 'Fiber, total dietary',
#   'value': '6.7',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff434'),
#   'category': 'fruit',
#   'name': 'Avocados, raw, all commercial varieties',
#   'id': '09037',
#   'nutrient': 'Sugars, total',
#   'value': '0.66',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff435'),
#   'category': 'fruit',
#   'name': 'Grapefruit, raw, pink and red and white, all areas',
#   'id': '09111',
#   'nutrient': 'Water',
#   'value': '90.89',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff436'),
#   'category': 'fruit',
#   'name': 'Grapefruit, raw, pink and red and white, all areas',
#   'id': '09111',
#   'nutrient': 'Energy',
#   'value': '32',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff437'),
#   'category': 'fruit',
#   'name': 'Grapefruit, raw, pink and red and white, all areas',
#   'id': '09111',
#   'nutrient': 'Protein',
#   'value': '0.63',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff438'),
#   'category': 'fruit',
#   'name': 'Grapefruit, raw, pink and red and white, all areas',
#   'id': '09111',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.10',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff439'),
#   'category': 'fruit',
#   'name': 'Grapefruit, raw, pink and red and white, all areas',
#   'id': '09111',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '8.08',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff43a'),
#   'category': 'fruit',
#   'name': 'Grapefruit, raw, pink and red and white, all areas',
#   'id': '09111',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.1',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff43b'),
#   'category': 'fruit',
#   'name': 'Grapefruit, raw, pink and red and white, all areas',
#   'id': '09111',
#   'nutrient': 'Sugars, total',
#   'value': '6.98',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff43c'),
#   'category': 'fruit',
#   'name': 'Grapes, american type (slip skin), raw',
#   'id': '09131',
#   'nutrient': 'Water',
#   'value': '81.30',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff43d'),
#   'category': 'fruit',
#   'name': 'Grapes, american type (slip skin), raw',
#   'id': '09131',
#   'nutrient': 'Energy',
#   'value': '67',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff43e'),
#   'category': 'fruit',
#   'name': 'Grapes, american type (slip skin), raw',
#   'id': '09131',
#   'nutrient': 'Protein',
#   'value': '0.63',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff43f'),
#   'category': 'fruit',
#   'name': 'Grapes, american type (slip skin), raw',
#   'id': '09131',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.35',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff440'),
#   'category': 'fruit',
#   'name': 'Grapes, american type (slip skin), raw',
#   'id': '09131',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '17.15',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff441'),
#   'category': 'fruit',
#   'name': 'Grapes, american type (slip skin), raw',
#   'id': '09131',
#   'nutrient': 'Fiber, total dietary',
#   'value': '0.9',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff442'),
#   'category': 'fruit',
#   'name': 'Grapes, american type (slip skin), raw',
#   'id': '09131',
#   'nutrient': 'Sugars, total',
#   'value': '16.25',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff443'),
#   'category': 'fruit',
#   'name': 'Cherries, sweet, raw',
#   'id': '09070',
#   'nutrient': 'Water',
#   'value': '82.25',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff444'),
#   'category': 'fruit',
#   'name': 'Cherries, sweet, raw',
#   'id': '09070',
#   'nutrient': 'Energy',
#   'value': '63',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff445'),
#   'category': 'fruit',
#   'name': 'Cherries, sweet, raw',
#   'id': '09070',
#   'nutrient': 'Protein',
#   'value': '1.06',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff446'),
#   'category': 'fruit',
#   'name': 'Cherries, sweet, raw',
#   'id': '09070',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.20',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff447'),
#   'category': 'fruit',
#   'name': 'Cherries, sweet, raw',
#   'id': '09070',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '16.01',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff448'),
#   'category': 'fruit',
#   'name': 'Cherries, sweet, raw',
#   'id': '09070',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.1',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff449'),
#   'category': 'fruit',
#   'name': 'Cherries, sweet, raw',
#   'id': '09070',
#   'nutrient': 'Sugars, total',
#   'value': '12.82',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff44a'),
#   'category': 'fruit',
#   'name': 'Lemons, raw, without peel',
#   'id': '09150',
#   'nutrient': 'Water',
#   'value': '88.98',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff44b'),
#   'category': 'fruit',
#   'name': 'Lemons, raw, without peel',
#   'id': '09150',
#   'nutrient': 'Energy',
#   'value': '29',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff44c'),
#   'category': 'fruit',
#   'name': 'Lemons, raw, without peel',
#   'id': '09150',
#   'nutrient': 'Protein',
#   'value': '1.10',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff44d'),
#   'category': 'fruit',
#   'name': 'Lemons, raw, without peel',
#   'id': '09150',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.30',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff44e'),
#   'category': 'fruit',
#   'name': 'Lemons, raw, without peel',
#   'id': '09150',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '9.32',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff44f'),
#   'category': 'fruit',
#   'name': 'Lemons, raw, without peel',
#   'id': '09150',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.8',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff450'),
#   'category': 'fruit',
#   'name': 'Lemons, raw, without peel',
#   'id': '09150',
#   'nutrient': 'Sugars, total',
#   'value': '2.50',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff451'),
#   'category': 'fruit',
#   'name': 'Mangos, raw',
#   'id': '09176',
#   'nutrient': 'Water',
#   'value': '83.46',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff452'),
#   'category': 'fruit',
#   'name': 'Mangos, raw',
#   'id': '09176',
#   'nutrient': 'Energy',
#   'value': '60',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff453'),
#   'category': 'fruit',
#   'name': 'Mangos, raw',
#   'id': '09176',
#   'nutrient': 'Protein',
#   'value': '0.82',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff454'),
#   'category': 'fruit',
#   'name': 'Mangos, raw',
#   'id': '09176',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.38',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff455'),
#   'category': 'fruit',
#   'name': 'Mangos, raw',
#   'id': '09176',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '14.98',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff456'),
#   'category': 'fruit',
#   'name': 'Mangos, raw',
#   'id': '09176',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.6',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff457'),
#   'category': 'fruit',
#   'name': 'Mangos, raw',
#   'id': '09176',
#   'nutrient': 'Sugars, total',
#   'value': '13.66',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff458'),
#   'category': 'fruit',
#   'name': 'Limes, raw',
#   'id': '09159',
#   'nutrient': 'Water',
#   'value': '88.26',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff459'),
#   'category': 'fruit',
#   'name': 'Limes, raw',
#   'id': '09159',
#   'nutrient': 'Energy',
#   'value': '30',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff45a'),
#   'category': 'fruit',
#   'name': 'Limes, raw',
#   'id': '09159',
#   'nutrient': 'Protein',
#   'value': '0.70',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff45b'),
#   'category': 'fruit',
#   'name': 'Limes, raw',
#   'id': '09159',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.20',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff45c'),
#   'category': 'fruit',
#   'name': 'Limes, raw',
#   'id': '09159',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '10.54',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff45d'),
#   'category': 'fruit',
#   'name': 'Limes, raw',
#   'id': '09159',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.8',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff45e'),
#   'category': 'fruit',
#   'name': 'Limes, raw',
#   'id': '09159',
#   'nutrient': 'Sugars, total',
#   'value': '1.69',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff45f'),
#   'category': 'fruit',
#   'name': 'Plums, raw',
#   'id': '09279',
#   'nutrient': 'Water',
#   'value': '87.23',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff460'),
#   'category': 'fruit',
#   'name': 'Plums, raw',
#   'id': '09279',
#   'nutrient': 'Energy',
#   'value': '46',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff461'),
#   'category': 'fruit',
#   'name': 'Plums, raw',
#   'id': '09279',
#   'nutrient': 'Protein',
#   'value': '0.70',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff462'),
#   'category': 'fruit',
#   'name': 'Plums, raw',
#   'id': '09279',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.28',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff463'),
#   'category': 'fruit',
#   'name': 'Plums, raw',
#   'id': '09279',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '11.42',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff464'),
#   'category': 'fruit',
#   'name': 'Plums, raw',
#   'id': '09279',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.4',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff465'),
#   'category': 'fruit',
#   'name': 'Plums, raw',
#   'id': '09279',
#   'nutrient': 'Sugars, total',
#   'value': '9.92',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff466'),
#   'category': 'fruit',
#   'name': 'Watermelon, raw',
#   'id': '09326',
#   'nutrient': 'Water',
#   'value': '91.45',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff467'),
#   'category': 'fruit',
#   'name': 'Watermelon, raw',
#   'id': '09326',
#   'nutrient': 'Energy',
#   'value': '30',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff468'),
#   'category': 'fruit',
#   'name': 'Watermelon, raw',
#   'id': '09326',
#   'nutrient': 'Protein',
#   'value': '0.61',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff469'),
#   'category': 'fruit',
#   'name': 'Watermelon, raw',
#   'id': '09326',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.15',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff46a'),
#   'category': 'fruit',
#   'name': 'Watermelon, raw',
#   'id': '09326',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '7.55',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff46b'),
#   'category': 'fruit',
#   'name': 'Watermelon, raw',
#   'id': '09326',
#   'nutrient': 'Fiber, total dietary',
#   'value': '0.4',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff46c'),
#   'category': 'fruit',
#   'name': 'Watermelon, raw',
#   'id': '09326',
#   'nutrient': 'Sugars, total',
#   'value': '6.20',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff46d'),
#   'category': 'fruit',
#   'name': 'Raspberries, raw',
#   'id': '09302',
#   'nutrient': 'Water',
#   'value': '85.75',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff46e'),
#   'category': 'fruit',
#   'name': 'Raspberries, raw',
#   'id': '09302',
#   'nutrient': 'Energy',
#   'value': '52',
#   'unit': 'kcal'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff46f'),
#   'category': 'fruit',
#   'name': 'Raspberries, raw',
#   'id': '09302',
#   'nutrient': 'Protein',
#   'value': '1.20',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff470'),
#   'category': 'fruit',
#   'name': 'Raspberries, raw',
#   'id': '09302',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.65',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff471'),
#   'category': 'fruit',
#   'name': 'Raspberries, raw',
#   'id': '09302',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '11.94',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff472'),
#   'category': 'fruit',
#   'name': 'Raspberries, raw',
#   'id': '09302',
#   'nutrient': 'Fiber, total dietary',
#   'value': '6.5',
#   'unit': 'g'},
#  {'_id': ObjectId('5c9fe3034ae97b5be81ff473'),
#   'category': 'fruit',
#   'name': 'Raspberries, raw',
#   'id': '09302',
#   'nutrient': 'Sugars, total',
#   'value': '4.42',
#   'unit': 'g'}]
