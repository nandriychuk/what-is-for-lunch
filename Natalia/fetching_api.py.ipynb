# %%
import csv
import matplotlib.pyplot as plt
import requests
import pandas as pd
from config import API_KEY
from pprint import pprint

# %%
query_url = f"https://api.nal.usda.gov/ndb/V2/reports?ndbno=11011&ndbno=11080&ndbno=11090&type=b&format=json&api_key={API_KEY}"

# %%
vegetables = "ndbno=11011&ndbno=11080&ndbno=11090&ndbno=11109&ndbno=11124&ndbno=11135&ndbno=11143&\
            ndbno=11167&ndbno=11205&ndbno=11210"
vegetables2 = "ndbno=11238&ndbno=11248&ndbno=11253&ndbno=11294&ndbno=11304&ndbno=11333&ndbno=11357&ndbno=11484&ndbno=11695&\
            ndbno=11959&ndbno=11932&ndbno=11705&ndbno=11215&ndbno=11233&ndbno=11007"

# %%
query_url = f"https://api.nal.usda.gov/ndb/V2/reports?{vegetables}{vegetables2}&type=b&format=json&api_key={API_KEY}"
# print(query_url)

# %%
response = requests.get(query_url)
response_json = response.json()
pprint(response_json)
# Out:
# {'api': 2.0,
#  'count': 22,
#  'foods': [{'food': {'desc': {'ds': 'Standard Reference',
#                               'manu': '',
#                               'name': 'Asparagus, raw',
#                               'ndbno': '11011',
#                               'ru': 'g'},
#                      'footnotes': [],
#                      'nutrients': [{'derivation': 'JO',
#                                     'group': 'Proximates',
#                                     'measures': [{'eqv': 134.0,
#                                                   'eunit': 'g',
#                                                   'label': 'cup',
#                                                   'qty': 1.0,
#                                                   'value': '124.91'},
#                                                  {'eqv': 12.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, small (5" '
#                                                            'long or less)',
#                                                   'qty': 1.0,
#                                                   'value': '11.19'},
#                                                  {'eqv': 16.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, medium '
#                                                            '(5-1/4" to 7" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '14.92'},
#                                                  {'eqv': 20.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, large '
#                                                            '(7-1/4" to 8-1/2")',
#                                                   'qty': 1.0,
#                                                   'value': '18.64'},
#                                                  {'eqv': 24.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, extra large '
#                                                            '(8-3/4" to 10" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '22.37'},
#                                                  {'eqv': 3.5,
#                                                   'eunit': 'g',
#                                                   'label': 'spear tip (2" long '
#                                                            'or less)',
#                                                   'qty': 1.0,
#                                                   'value': '3.26'}],
#                                     'name': 'Water',
#                                     'nutrient_id': '255',
#                                     'unit': 'g',
#                                     'value': '93.22'},
#                                    {'derivation': 'NC',
#                                     'group': 'Proximates',
#                                     'measures': [{'eqv': 134.0,
#                                                   'eunit': 'g',
#                                                   'label': 'cup',
#                                                   'qty': 1.0,
#                                                   'value': '27'},
#                                                  {'eqv': 12.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, small (5" '
#                                                            'long or less)',
#                                                   'qty': 1.0,
#                                                   'value': '2'},
#                                                  {'eqv': 16.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, medium '
#                                                            '(5-1/4" to 7" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '3'},
#                                                  {'eqv': 20.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, large '
#                                                            '(7-1/4" to 8-1/2")',
#                                                   'qty': 1.0,
#                                                   'value': '4'},
#                                                  {'eqv': 24.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, extra large '
#                                                            '(8-3/4" to 10" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '5'},
#                                                  {'eqv': 3.5,
#                                                   'eunit': 'g',
#                                                   'label': 'spear tip (2" long '
#                                                            'or less)',
#                                                   'qty': 1.0,
#                                                   'value': '1'}],
#                                     'name': 'Energy',
#                                     'nutrient_id': '208',
#                                     'unit': 'kcal',
#                                     'value': '20'},
#                                    {'derivation': 'NONE',
#                                     'group': 'Proximates',
#                                     'measures': [{'eqv': 134.0,
#                                                   'eunit': 'g',
#                                                   'label': 'cup',
#                                                   'qty': 1.0,
#                                                   'value': '2.95'},
#                                                  {'eqv': 12.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, small (5" '
#                                                            'long or less)',
#                                                   'qty': 1.0,
#                                                   'value': '0.26'},
#                                                  {'eqv': 16.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, medium '
#                                                            '(5-1/4" to 7" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '0.35'},
#                                                  {'eqv': 20.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, large '
#                                                            '(7-1/4" to 8-1/2")',
#                                                   'qty': 1.0,
#                                                   'value': '0.44'},
#                                                  {'eqv': 24.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, extra large '
#                                                            '(8-3/4" to 10" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '0.53'},
#                                                  {'eqv': 3.5,
#                                                   'eunit': 'g',
#                                                   'label': 'spear tip (2" long '
#                                                            'or less)',
#                                                   'qty': 1.0,
#                                                   'value': '0.08'}],
#                                     'name': 'Protein',
#                                     'nutrient_id': '203',
#                                     'unit': 'g',
#                                     'value': '2.20'},
#                                    {'derivation': 'JO',
#                                     'group': 'Proximates',
#                                     'measures': [{'eqv': 134.0,
#                                                   'eunit': 'g',
#                                                   'label': 'cup',
#                                                   'qty': 1.0,
#                                                   'value': '0.16'},
#                                                  {'eqv': 12.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, small (5" '
#                                                            'long or less)',
#                                                   'qty': 1.0,
#                                                   'value': '0.01'},
#                                                  {'eqv': 16.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, medium '
#                                                            '(5-1/4" to 7" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '0.02'},
#                                                  {'eqv': 20.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, large '
#                                                            '(7-1/4" to 8-1/2")',
#                                                   'qty': 1.0,
#                                                   'value': '0.02'},
#                                                  {'eqv': 24.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, extra large '
#                                                            '(8-3/4" to 10" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '0.03'},
#                                                  {'eqv': 3.5,
#                                                   'eunit': 'g',
#                                                   'label': 'spear tip (2" long '
#                                                            'or less)',
#                                                   'qty': 1.0,
#                                                   'value': '0.00'}],
#                                     'name': 'Total lipid (fat)',
#                                     'nutrient_id': '204',
#                                     'unit': 'g',
#                                     'value': '0.12'},
#                                    {'derivation': 'NC',
#                                     'group': 'Proximates',
#                                     'measures': [{'eqv': 134.0,
#                                                   'eunit': 'g',
#                                                   'label': 'cup',
#                                                   'qty': 1.0,
#                                                   'value': '5.20'},
#                                                  {'eqv': 12.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, small (5" '
#                                                            'long or less)',
#                                                   'qty': 1.0,
#                                                   'value': '0.47'},
#                                                  {'eqv': 16.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, medium '
#                                                            '(5-1/4" to 7" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '0.62'},
#                                                  {'eqv': 20.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, large '
#                                                            '(7-1/4" to 8-1/2")',
#                                                   'qty': 1.0,
#                                                   'value': '0.78'},
#                                                  {'eqv': 24.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, extra large '
#                                                            '(8-3/4" to 10" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '0.93'},
#                                                  {'eqv': 3.5,
#                                                   'eunit': 'g',
#                                                   'label': 'spear tip (2" long '
#                                                            'or less)',
#                                                   'qty': 1.0,
#                                                   'value': '0.14'}],
#                                     'name': 'Carbohydrate, by difference',
#                                     'nutrient_id': '205',
#                                     'unit': 'g',
#                                     'value': '3.88'},
#                                    {'derivation': 'NONE',
#                                     'group': 'Proximates',
#                                     'measures': [{'eqv': 134.0,
#                                                   'eunit': 'g',
#                                                   'label': 'cup',
#                                                   'qty': 1.0,
#                                                   'value': '2.8'},
#                                                  {'eqv': 12.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, small (5" '
#                                                            'long or less)',
#                                                   'qty': 1.0,
#                                                   'value': '0.3'},
#                                                  {'eqv': 16.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, medium '
#                                                            '(5-1/4" to 7" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '0.3'},
#                                                  {'eqv': 20.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, large '
#                                                            '(7-1/4" to 8-1/2")',
#                                                   'qty': 1.0,
#                                                   'value': '0.4'},
#                                                  {'eqv': 24.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, extra large '
#                                                            '(8-3/4" to 10" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '0.5'},
#                                                  {'eqv': 3.5,
#                                                   'eunit': 'g',
#                                                   'label': 'spear tip (2" long '
#                                                            'or less)',
#                                                   'qty': 1.0,
#                                                   'value': '0.1'}],
#                                     'name': 'Fiber, total dietary',
#                                     'nutrient_id': '291',
#                                     'unit': 'g',
#                                     'value': '2.1'},
#                                    {'derivation': 'NC',
#                                     'group': 'Proximates',
#                                     'measures': [{'eqv': 134.0,
#                                                   'eunit': 'g',
#                                                   'label': 'cup',
#                                                   'qty': 1.0,
#                                                   'value': '2.52'},
#                                                  {'eqv': 12.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, small (5" '
#                                                            'long or less)',
#                                                   'qty': 1.0,
#                                                   'value': '0.23'},
#                                                  {'eqv': 16.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, medium '
#                                                            '(5-1/4" to 7" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '0.30'},
#                                                  {'eqv': 20.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, large '
#                                                            '(7-1/4" to 8-1/2")',
#                                                   'qty': 1.0,
#                                                   'value': '0.38'},
#                                                  {'eqv': 24.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, extra large '
#                                                            '(8-3/4" to 10" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '0.45'},
#                                                  {'eqv': 3.5,
#                                                   'eunit': 'g',
#                                                   'label': 'spear tip (2" long '
#                                                            'or less)',
#                                                   'qty': 1.0,
#                                                   'value': '0.07'}],
#                                     'name': 'Sugars, total',
#                                     'nutrient_id': '269',
#                                     'unit': 'g',
#                                     'value': '1.88'},
#                                    {'derivation': 'NONE',
#                                     'group': 'Minerals',
#                                     'measures': [{'eqv': 134.0,
#                                                   'eunit': 'g',
#                                                   'label': 'cup',
#                                                   'qty': 1.0,
#                                                   'value': '32'},
#                                                  {'eqv': 12.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, small (5" '
#                                                            'long or less)',
#                                                   'qty': 1.0,
#                                                   'value': '3'},
#                                                  {'eqv': 16.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, medium '
#                                                            '(5-1/4" to 7" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '4'},
#                                                  {'eqv': 20.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, large '
#                                                            '(7-1/4" to 8-1/2")',
#                                                   'qty': 1.0,
#                                                   'value': '5'},
#                                                  {'eqv': 24.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, extra large '
#                                                            '(8-3/4" to 10" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '6'},
#                                                  {'eqv': 3.5,
#                                                   'eunit': 'g',
#                                                   'label': 'spear tip (2" long '
#                                                            'or less)',
#                                                   'qty': 1.0,
#                                                   'value': '1'}],
#                                     'name': 'Calcium, Ca',
#                                     'nutrient_id': '301',
#                                     'unit': 'mg',
#                                     'value': '24'},
#                                    {'derivation': 'NONE',
#                                     'group': 'Minerals',
#                                     'measures': [{'eqv': 134.0,
#                                                   'eunit': 'g',
#                                                   'label': 'cup',
#                                                   'qty': 1.0,
#                                                   'value': '2.87'},
#                                                  {'eqv': 12.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, small (5" '
#                                                            'long or less)',
#                                                   'qty': 1.0,
#                                                   'value': '0.26'},
#                                                  {'eqv': 16.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, medium '
#                                                            '(5-1/4" to 7" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '0.34'},
#                                                  {'eqv': 20.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, large '
#                                                            '(7-1/4" to 8-1/2")',
#                                                   'qty': 1.0,
#                                                   'value': '0.43'},
#                                                  {'eqv': 24.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, extra large '
#                                                            '(8-3/4" to 10" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '0.51'},
#                                                  {'eqv': 3.5,
#                                                   'eunit': 'g',
#                                                   'label': 'spear tip (2" long '
#                                                            'or less)',
#                                                   'qty': 1.0,
#                                                   'value': '0.07'}],
#                                     'name': 'Iron, Fe',
#                                     'nutrient_id': '303',
#                                     'unit': 'mg',
#                                     'value': '2.14'},
#                                    {'derivation': 'NONE',
#                                     'group': 'Minerals',
#                                     'measures': [{'eqv': 134.0,
#                                                   'eunit': 'g',
#                                                   'label': 'cup',
#                                                   'qty': 1.0,
#                                                   'value': '19'},
#                                                  {'eqv': 12.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, small (5" '
#                                                            'long or less)',
#                                                   'qty': 1.0,
#                                                   'value': '2'},
#                                                  {'eqv': 16.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, medium '
#                                                            '(5-1/4" to 7" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '2'},
#                                                  {'eqv': 20.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, large '
#                                                            '(7-1/4" to 8-1/2")',
#                                                   'qty': 1.0,
#                                                   'value': '3'},
#                                                  {'eqv': 24.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, extra large '
#                                                            '(8-3/4" to 10" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '3'},
#                                                  {'eqv': 3.5,
#                                                   'eunit': 'g',
#                                                   'label': 'spear tip (2" long '
#                                                            'or less)',
#                                                   'qty': 1.0,
#                                                   'value': '0'}],
#                                     'name': 'Magnesium, Mg',
#                                     'nutrient_id': '304',
#                                     'unit': 'mg',
#                                     'value': '14'},
#                                    {'derivation': 'NONE',
#                                     'group': 'Minerals',
#                                     'measures': [{'eqv': 134.0,
#                                                   'eunit': 'g',
#                                                   'label': 'cup',
#                                                   'qty': 1.0,
#                                                   'value': '70'},
#                                                  {'eqv': 12.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, small (5" '
#                                                            'long or less)',
#                                                   'qty': 1.0,
#                                                   'value': '6'},
#                                                  {'eqv': 16.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, medium '
#                                                            '(5-1/4" to 7" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '8'},
#                                                  {'eqv': 20.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, large '
#                                                            '(7-1/4" to 8-1/2")',
#                                                   'qty': 1.0,
#                                                   'value': '10'},
#                                                  {'eqv': 24.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, extra large '
#                                                            '(8-3/4" to 10" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '12'},
#                                                  {'eqv': 3.5,
#                                                   'eunit': 'g',
#                                                   'label': 'spear tip (2" long '
#                                                            'or less)',
#                                                   'qty': 1.0,
#                                                   'value': '2'}],
#                                     'name': 'Phosphorus, P',
#                                     'nutrient_id': '305',
#                                     'unit': 'mg',
#                                     'value': '52'},
#                                    {'derivation': 'NONE',
#                                     'group': 'Minerals',
#                                     'measures': [{'eqv': 134.0,
#                                                   'eunit': 'g',
#                                                   'label': 'cup',
#                                                   'qty': 1.0,
#                                                   'value': '271'},
#                                                  {'eqv': 12.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, small (5" '
#                                                            'long or less)',
#                                                   'qty': 1.0,
#                                                   'value': '24'},
#                                                  {'eqv': 16.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, medium '
#                                                            '(5-1/4" to 7" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '32'},
#                                                  {'eqv': 20.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, large '
#                                                            '(7-1/4" to 8-1/2")',
#                                                   'qty': 1.0,
#                                                   'value': '40'},
#                                                  {'eqv': 24.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, extra large '
#                                                            '(8-3/4" to 10" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '48'},
#                                                  {'eqv': 3.5,
#                                                   'eunit': 'g',
#                                                   'label': 'spear tip (2" long '
#                                                            'or less)',
#                                                   'qty': 1.0,
#                                                   'value': '7'}],
#                                     'name': 'Potassium, K',
#                                     'nutrient_id': '306',
#                                     'unit': 'mg',
#                                     'value': '202'},
#                                    {'derivation': 'NONE',
#                                     'group': 'Minerals',
#                                     'measures': [{'eqv': 134.0,
#                                                   'eunit': 'g',
#                                                   'label': 'cup',
#                                                   'qty': 1.0,
#                                                   'value': '3'},
#                                                  {'eqv': 12.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, small (5" '
#                                                            'long or less)',
#                                                   'qty': 1.0,
#                                                   'value': '0'},
#                                                  {'eqv': 16.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, medium '
#                                                            '(5-1/4" to 7" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '0'},
#                                                  {'eqv': 20.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, large '
#                                                            '(7-1/4" to 8-1/2")',
#                                                   'qty': 1.0,
#                                                   'value': '0'},
#                                                  {'eqv': 24.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, extra large '
#                                                            '(8-3/4" to 10" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '0'},
#                                                  {'eqv': 3.5,
#                                                   'eunit': 'g',
#                                                   'label': 'spear tip (2" long '
#                                                            'or less)',
#                                                   'qty': 1.0,
#                                                   'value': '0'}],
#                                     'name': 'Sodium, Na',
#                                     'nutrient_id': '307',
#                                     'unit': 'mg',
#                                     'value': '2'},
#                                    {'derivation': 'NONE',
#                                     'group': 'Minerals',
#                                     'measures': [{'eqv': 134.0,
#                                                   'eunit': 'g',
#                                                   'label': 'cup',
#                                                   'qty': 1.0,
#                                                   'value': '0.72'},
#                                                  {'eqv': 12.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, small (5" '
#                                                            'long or less)',
#                                                   'qty': 1.0,
#                                                   'value': '0.06'},
#                                                  {'eqv': 16.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, medium '
#                                                            '(5-1/4" to 7" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '0.09'},
#                                                  {'eqv': 20.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, large '
#                                                            '(7-1/4" to 8-1/2")',
#                                                   'qty': 1.0,
#                                                   'value': '0.11'},
#                                                  {'eqv': 24.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, extra large '
#                                                            '(8-3/4" to 10" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '0.13'},
#                                                  {'eqv': 3.5,
#                                                   'eunit': 'g',
#                                                   'label': 'spear tip (2" long '
#                                                            'or less)',
#                                                   'qty': 1.0,
#                                                   'value': '0.02'}],
#                                     'name': 'Zinc, Zn',
#                                     'nutrient_id': '309',
#                                     'unit': 'mg',
#                                     'value': '0.54'},
#                                    {'derivation': 'NONE',
#                                     'group': 'Vitamins',
#                                     'measures': [{'eqv': 134.0,
#                                                   'eunit': 'g',
#                                                   'label': 'cup',
#                                                   'qty': 1.0,
#                                                   'value': '7.5'},
#                                                  {'eqv': 12.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, small (5" '
#                                                            'long or less)',
#                                                   'qty': 1.0,
#                                                   'value': '0.7'},
#                                                  {'eqv': 16.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, medium '
#                                                            '(5-1/4" to 7" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '0.9'},
#                                                  {'eqv': 20.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, large '
#                                                            '(7-1/4" to 8-1/2")',
#                                                   'qty': 1.0,
#                                                   'value': '1.1'},
#                                                  {'eqv': 24.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, extra large '
#                                                            '(8-3/4" to 10" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '1.3'},
#                                                  {'eqv': 3.5,
#                                                   'eunit': 'g',
#                                                   'label': 'spear tip (2" long '
#                                                            'or less)',
#                                                   'qty': 1.0,
#                                                   'value': '0.2'}],
#                                     'name': 'Vitamin C, total ascorbic acid',
#                                     'nutrient_id': '401',
#                                     'unit': 'mg',
#                                     'value': '5.6'},
#                                    {'derivation': 'NONE',
#                                     'group': 'Vitamins',
#                                     'measures': [{'eqv': 134.0,
#                                                   'eunit': 'g',
#                                                   'label': 'cup',
#                                                   'qty': 1.0,
#                                                   'value': '0.192'},
#                                                  {'eqv': 12.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, small (5" '
#                                                            'long or less)',
#                                                   'qty': 1.0,
#                                                   'value': '0.017'},
#                                                  {'eqv': 16.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, medium '
#                                                            '(5-1/4" to 7" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '0.023'},
#                                                  {'eqv': 20.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, large '
#                                                            '(7-1/4" to 8-1/2")',
#                                                   'qty': 1.0,
#                                                   'value': '0.029'},
#                                                  {'eqv': 24.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, extra large '
#                                                            '(8-3/4" to 10" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '0.034'},
#                                                  {'eqv': 3.5,
#                                                   'eunit': 'g',
#                                                   'label': 'spear tip (2" long '
#                                                            'or less)',
#                                                   'qty': 1.0,
#                                                   'value': '0.005'}],
#                                     'name': 'Thiamin',
#                                     'nutrient_id': '404',
#                                     'unit': 'mg',
#                                     'value': '0.143'},
#                                    {'derivation': 'NONE',
#                                     'group': 'Vitamins',
#                                     'measures': [{'eqv': 134.0,
#                                                   'eunit': 'g',
#                                                   'label': 'cup',
#                                                   'qty': 1.0,
#                                                   'value': '0.189'},
#                                                  {'eqv': 12.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, small (5" '
#                                                            'long or less)',
#                                                   'qty': 1.0,
#                                                   'value': '0.017'},
#                                                  {'eqv': 16.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, medium '
#                                                            '(5-1/4" to 7" '
#                                                            'long)',
#                                                   'qty': 1.0,
#                                                   'value': '0.023'},
#                                                  {'eqv': 20.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, large '
#                                                            '(7-1/4" to 8-1/2")',
#                                                   'qty': 1.0,
#                                                   'value': '0.028'},
#                                                  {'eqv': 24.0,
#                                                   'eunit': 'g',
#                                                   'label': 'spear, extra large '
#                                                            '(8-3/4" to 10" '
#                                                            'long)',
# ...
#                                                  {'eqv': 162.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, large',
#                                                   'qty': 1.0,
#                                                   'value': '0.107'}],
#                                     'name': 'Riboflavin',
#                                     'nutrient_id': '405',
#                                     'unit': 'mg',
#                                     'value': '0.066'},
#                                    {'derivation': 'NONE',
#                                     'group': 'Vitamins',
#                                     'measures': [{'eqv': 128.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, medium',
#                                                   'qty': 1.0,
#                                                   'value': '1.339'},
#                                                  {'eqv': 162.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, large',
#                                                   'qty': 1.0,
#                                                   'value': '1.695'}],
#                                     'name': 'Niacin',
#                                     'nutrient_id': '406',
#                                     'unit': 'mg',
#                                     'value': '1.046'},
#                                    {'derivation': 'NONE',
#                                     'group': 'Vitamins',
#                                     'measures': [{'eqv': 128.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, medium',
#                                                   'qty': 1.0,
#                                                   'value': '0.148'},
#                                                  {'eqv': 162.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, large',
#                                                   'qty': 1.0,
#                                                   'value': '0.188'}],
#                                     'name': 'Vitamin B-6',
#                                     'nutrient_id': '415',
#                                     'unit': 'mg',
#                                     'value': '0.116'},
#                                    {'derivation': 'NC',
#                                     'group': 'Vitamins',
#                                     'measures': [{'eqv': 128.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, medium',
#                                                   'qty': 1.0,
#                                                   'value': '87'},
#                                                  {'eqv': 162.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, large',
#                                                   'qty': 1.0,
#                                                   'value': '110'}],
#                                     'name': 'Folate, DFE',
#                                     'nutrient_id': '435',
#                                     'unit': 'µg',
#                                     'value': '68'},
#                                    {'derivation': 'NONE',
#                                     'group': 'Vitamins',
#                                     'measures': [{'eqv': 128.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, medium',
#                                                   'qty': 1.0,
#                                                   'value': '0.00'},
#                                                  {'eqv': 162.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, large',
#                                                   'qty': 1.0,
#                                                   'value': '0.00'}],
#                                     'name': 'Vitamin B-12',
#                                     'nutrient_id': '418',
#                                     'unit': 'µg',
#                                     'value': '0.00'},
#                                    {'derivation': 'NC',
#                                     'group': 'Vitamins',
#                                     'measures': [{'eqv': 128.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, medium',
#                                                   'qty': 1.0,
#                                                   'value': '1'},
#                                                  {'eqv': 162.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, large',
#                                                   'qty': 1.0,
#                                                   'value': '2'}],
#                                     'name': 'Vitamin A, RAE',
#                                     'nutrient_id': '320',
#                                     'unit': 'µg',
#                                     'value': '1'},
#                                    {'derivation': 'NC',
#                                     'group': 'Vitamins',
#                                     'measures': [{'eqv': 128.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, medium',
#                                                   'qty': 1.0,
#                                                   'value': '17'},
#                                                  {'eqv': 162.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, large',
#                                                   'qty': 1.0,
#                                                   'value': '21'}],
#                                     'name': 'Vitamin A, IU',
#                                     'nutrient_id': '318',
#                                     'unit': 'IU',
#                                     'value': '13'},
#                                    {'derivation': 'BFZN',
#                                     'group': 'Vitamins',
#                                     'measures': [{'eqv': 128.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, medium',
#                                                   'qty': 1.0,
#                                                   'value': '0.24'},
#                                                  {'eqv': 162.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, large',
#                                                   'qty': 1.0,
#                                                   'value': '0.31'}],
#                                     'name': 'Vitamin E (alpha-tocopherol)',
#                                     'nutrient_id': '323',
#                                     'unit': 'mg',
#                                     'value': '0.19'},
#                                    {'derivation': 'NONE',
#                                     'group': 'Vitamins',
#                                     'measures': [{'eqv': 128.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, medium',
#                                                   'qty': 1.0,
#                                                   'value': '0.0'},
#                                                  {'eqv': 162.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, large',
#                                                   'qty': 1.0,
#                                                   'value': '0.0'}],
#                                     'name': 'Vitamin D (D2 + D3)',
#                                     'nutrient_id': '328',
#                                     'unit': 'µg',
#                                     'value': '0.0'},
#                                    {'derivation': 'NONE',
#                                     'group': 'Vitamins',
#                                     'measures': [{'eqv': 128.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, medium',
#                                                   'qty': 1.0,
#                                                   'value': '0'},
#                                                  {'eqv': 162.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, large',
#                                                   'qty': 1.0,
#                                                   'value': '0'}],
#                                     'name': 'Vitamin D',
#                                     'nutrient_id': '324',
#                                     'unit': 'IU',
#                                     'value': '0'},
#                                    {'derivation': 'BFZN',
#                                     'group': 'Vitamins',
#                                     'measures': [{'eqv': 128.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, medium',
#                                                   'qty': 1.0,
#                                                   'value': '18.9'},
#                                                  {'eqv': 162.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, large',
#                                                   'qty': 1.0,
#                                                   'value': '24.0'}],
#                                     'name': 'Vitamin K (phylloquinone)',
#                                     'nutrient_id': '430',
#                                     'unit': 'µg',
#                                     'value': '14.8'},
#                                    {'derivation': 'NC',
#                                     'group': 'Lipids',
#                                     'measures': [{'eqv': 128.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, medium',
#                                                   'qty': 1.0,
#                                                   'value': '0.046'},
#                                                  {'eqv': 162.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, large',
#                                                   'qty': 1.0,
#                                                   'value': '0.058'}],
#                                     'name': 'Fatty acids, total saturated',
#                                     'nutrient_id': '606',
#                                     'unit': 'g',
#                                     'value': '0.036'},
#                                    {'derivation': 'NC',
#                                     'group': 'Lipids',
#                                     'measures': [{'eqv': 128.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, medium',
#                                                   'qty': 1.0,
#                                                   'value': '0.006'},
#                                                  {'eqv': 162.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, large',
#                                                   'qty': 1.0,
#                                                   'value': '0.008'}],
#                                     'name': 'Fatty acids, total '
#                                             'monounsaturated',
#                                     'nutrient_id': '645',
#                                     'unit': 'g',
#                                     'value': '0.005'},
#                                    {'derivation': 'NC',
#                                     'group': 'Lipids',
#                                     'measures': [{'eqv': 128.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, medium',
#                                                   'qty': 1.0,
#                                                   'value': '0.082'},
#                                                  {'eqv': 162.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, large',
#                                                   'qty': 1.0,
#                                                   'value': '0.104'}],
#                                     'name': 'Fatty acids, total '
#                                             'polyunsaturated',
#                                     'nutrient_id': '646',
#                                     'unit': 'g',
#                                     'value': '0.064'},
#                                    {'derivation': 'NONE',
#                                     'group': 'Lipids',
#                                     'measures': [{'eqv': 128.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, medium',
#                                                   'qty': 1.0,
#                                                   'value': '0.000'},
#                                                  {'eqv': 162.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, large',
#                                                   'qty': 1.0,
#                                                   'value': '0.000'}],
#                                     'name': 'Fatty acids, total trans',
#                                     'nutrient_id': '605',
#                                     'unit': 'g',
#                                     'value': '0.000'},
#                                    {'derivation': 'NONE',
#                                     'group': 'Lipids',
#                                     'measures': [{'eqv': 128.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, medium',
#                                                   'qty': 1.0,
#                                                   'value': '0'},
#                                                  {'eqv': 162.0,
#                                                   'eunit': 'g',
#                                                   'label': 'artichoke, large',
#                                                   'qty': 1.0,
#                                                   'value': '0'}],
#                                     'name': 'Cholesterol',
#                                     'nutrient_id': '601',
#                                     'unit': 'mg',
#                                     'value': '0'}],
#                      'sr': '1',
#                      'type': 'b'}}],
#  'notfound': 1}

# %%
# create empty list
food_items = []

# %%
# creating record for one record per food

# foods = response_json['foods']

# for food in foods:
# #     print(food['food']['nutrients'])
#     food_item = {
#         'name': 'name of the food',
#         'units': '',
#         'values': ''
#     }
#     try:
#         food_item['name'] = food['food']['desc']['name']
#         i = 0
#         for nutrient in food['food']['nutrients']:
#             i = i + 1
#             nutrient_name = nutrient['name']
#             nutrient_value = nutrient['value']
#             food_item[nutrient_name] = nutrient_value
#             if i > 7:
#                 break
#         food_items.append(food_item)
#     except:
#         print("No food:(")
# Out:
# No food:(

# %%
food_items = []

# %%
# creating output for one record per nutrient per food
foods = response_json['foods']

for food in foods:        
    try:

        i = 0
        for nutrient in food['food']['nutrients']:
            food_item = {}
            food_item['name'] = food['food']['desc']['name']

            nutrient_name = nutrient['name']
            nutrient_value = nutrient['value']
            nutrient_unit = nutrient['unit']

            food_item['nutrient'] = nutrient_name
            food_item['value'] = nutrient_value
            food_item['unit'] = nutrient_unit

            food_items.append(food_item)

            i = i + 1
            if i > 6:
                break
    
    except:
        print("No food:(")
# Out:
# No food:(

# %%
food_items
# Out:
# [{'name': 'Asparagus, raw',
#   'nutrient': 'Water',
#   'value': '93.22',
#   'unit': 'g'},
#  {'name': 'Asparagus, raw',
#   'nutrient': 'Energy',
#   'value': '20',
#   'unit': 'kcal'},
#  {'name': 'Asparagus, raw',
#   'nutrient': 'Protein',
#   'value': '2.20',
#   'unit': 'g'},
#  {'name': 'Asparagus, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.12',
#   'unit': 'g'},
#  {'name': 'Asparagus, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '3.88',
#   'unit': 'g'},
#  {'name': 'Asparagus, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.1',
#   'unit': 'g'},
#  {'name': 'Asparagus, raw',
#   'nutrient': 'Sugars, total',
#   'value': '1.88',
#   'unit': 'g'},
#  {'name': 'Beets, raw', 'nutrient': 'Water', 'value': '87.58', 'unit': 'g'},
#  {'name': 'Beets, raw', 'nutrient': 'Energy', 'value': '43', 'unit': 'kcal'},
#  {'name': 'Beets, raw', 'nutrient': 'Protein', 'value': '1.61', 'unit': 'g'},
#  {'name': 'Beets, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.17',
#   'unit': 'g'},
#  {'name': 'Beets, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '9.56',
#   'unit': 'g'},
#  {'name': 'Beets, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.8',
#   'unit': 'g'},
#  {'name': 'Beets, raw',
#   'nutrient': 'Sugars, total',
#   'value': '6.76',
#   'unit': 'g'},
#  {'name': 'Broccoli, raw', 'nutrient': 'Water', 'value': '89.30', 'unit': 'g'},
#  {'name': 'Broccoli, raw',
#   'nutrient': 'Energy',
#   'value': '34',
#   'unit': 'kcal'},
#  {'name': 'Broccoli, raw',
#   'nutrient': 'Protein',
#   'value': '2.82',
#   'unit': 'g'},
#  {'name': 'Broccoli, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.37',
#   'unit': 'g'},
#  {'name': 'Broccoli, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '6.64',
#   'unit': 'g'},
#  {'name': 'Broccoli, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.6',
#   'unit': 'g'},
#  {'name': 'Broccoli, raw',
#   'nutrient': 'Sugars, total',
#   'value': '1.70',
#   'unit': 'g'},
#  {'name': 'Cabbage, raw', 'nutrient': 'Water', 'value': '92.18', 'unit': 'g'},
#  {'name': 'Cabbage, raw', 'nutrient': 'Energy', 'value': '25', 'unit': 'kcal'},
#  {'name': 'Cabbage, raw', 'nutrient': 'Protein', 'value': '1.28', 'unit': 'g'},
#  {'name': 'Cabbage, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.10',
#   'unit': 'g'},
#  {'name': 'Cabbage, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '5.80',
#   'unit': 'g'},
#  {'name': 'Cabbage, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.5',
#   'unit': 'g'},
#  {'name': 'Cabbage, raw',
#   'nutrient': 'Sugars, total',
#   'value': '3.20',
#   'unit': 'g'},
#  {'name': 'Carrots, raw', 'nutrient': 'Water', 'value': '88.29', 'unit': 'g'},
#  {'name': 'Carrots, raw', 'nutrient': 'Energy', 'value': '41', 'unit': 'kcal'},
#  {'name': 'Carrots, raw', 'nutrient': 'Protein', 'value': '0.93', 'unit': 'g'},
#  {'name': 'Carrots, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.24',
#   'unit': 'g'},
#  {'name': 'Carrots, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '9.58',
#   'unit': 'g'},
#  {'name': 'Carrots, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.8',
#   'unit': 'g'},
#  {'name': 'Carrots, raw',
#   'nutrient': 'Sugars, total',
#   'value': '4.74',
#   'unit': 'g'},
#  {'name': 'Cauliflower, raw',
#   'nutrient': 'Water',
#   'value': '92.07',
#   'unit': 'g'},
#  {'name': 'Cauliflower, raw',
#   'nutrient': 'Energy',
#   'value': '25',
#   'unit': 'kcal'},
#  {'name': 'Cauliflower, raw',
#   'nutrient': 'Protein',
#   'value': '1.92',
#   'unit': 'g'},
#  {'name': 'Cauliflower, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.28',
#   'unit': 'g'},
#  {'name': 'Cauliflower, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '4.97',
#   'unit': 'g'},
#  {'name': 'Cauliflower, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.0',
#   'unit': 'g'},
#  {'name': 'Cauliflower, raw',
#   'nutrient': 'Sugars, total',
#   'value': '1.91',
#   'unit': 'g'},
#  {'name': 'Celery, raw', 'nutrient': 'Water', 'value': '95.43', 'unit': 'g'},
#  {'name': 'Celery, raw', 'nutrient': 'Energy', 'value': '14', 'unit': 'kcal'},
#  {'name': 'Celery, raw', 'nutrient': 'Protein', 'value': '0.69', 'unit': 'g'},
#  {'name': 'Celery, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.17',
#   'unit': 'g'},
#  {'name': 'Celery, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '2.97',
#   'unit': 'g'},
#  {'name': 'Celery, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.6',
#   'unit': 'g'},
#  {'name': 'Celery, raw',
#   'nutrient': 'Sugars, total',
#   'value': '1.34',
#   'unit': 'g'},
#  {'name': 'Cucumber, with peel, raw',
#   'nutrient': 'Water',
#   'value': '95.23',
#   'unit': 'g'},
#  {'name': 'Cucumber, with peel, raw',
#   'nutrient': 'Energy',
#   'value': '15',
#   'unit': 'kcal'},
#  {'name': 'Cucumber, with peel, raw',
#   'nutrient': 'Protein',
#   'value': '0.65',
#   'unit': 'g'},
#  {'name': 'Cucumber, with peel, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.11',
#   'unit': 'g'},
#  {'name': 'Cucumber, with peel, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '3.63',
#   'unit': 'g'},
#  {'name': 'Cucumber, with peel, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '0.5',
#   'unit': 'g'},
#  {'name': 'Cucumber, with peel, raw',
#   'nutrient': 'Sugars, total',
#   'value': '1.67',
#   'unit': 'g'},
#  {'name': 'Lentils, sprouted, raw',
#   'nutrient': 'Water',
#   'value': '67.34',
#   'unit': 'g'},
#  {'name': 'Lentils, sprouted, raw',
#   'nutrient': 'Energy',
#   'value': '106',
#   'unit': 'kcal'},
#  {'name': 'Lentils, sprouted, raw',
#   'nutrient': 'Protein',
#   'value': '8.96',
#   'unit': 'g'},
#  {'name': 'Lentils, sprouted, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.55',
#   'unit': 'g'},
#  {'name': 'Lentils, sprouted, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '22.14',
#   'unit': 'g'},
#  {'name': 'Lentils, sprouted, raw',
#   'nutrient': 'Calcium, Ca',
#   'value': '25',
#   'unit': 'mg'},
#  {'name': 'Lentils, sprouted, raw',
#   'nutrient': 'Iron, Fe',
#   'value': '3.21',
#   'unit': 'mg'},
#  {'name': 'Lettuce, green leaf, raw',
#   'nutrient': 'Water',
#   'value': '94.98',
#   'unit': 'g'},
#  {'name': 'Lettuce, green leaf, raw',
#   'nutrient': 'Energy',
#   'value': '15',
#   'unit': 'kcal'},
#  {'name': 'Lettuce, green leaf, raw',
#   'nutrient': 'Protein',
#   'value': '1.36',
#   'unit': 'g'},
#  {'name': 'Lettuce, green leaf, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.15',
#   'unit': 'g'},
#  {'name': 'Lettuce, green leaf, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '2.87',
#   'unit': 'g'},
#  {'name': 'Lettuce, green leaf, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.3',
#   'unit': 'g'},
#  {'name': 'Lettuce, green leaf, raw',
#   'nutrient': 'Sugars, total',
#   'value': '0.78',
#   'unit': 'g'},
#  {'name': 'Onions, sweet, raw',
#   'nutrient': 'Water',
#   'value': '91.24',
#   'unit': 'g'},
#  {'name': 'Onions, sweet, raw',
#   'nutrient': 'Energy',
#   'value': '32',
#   'unit': 'kcal'},
#  {'name': 'Onions, sweet, raw',
#   'nutrient': 'Protein',
#   'value': '0.80',
#   'unit': 'g'},
#  {'name': 'Onions, sweet, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.08',
#   'unit': 'g'},
#  {'name': 'Onions, sweet, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '7.55',
#   'unit': 'g'},
#  {'name': 'Onions, sweet, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '0.9',
#   'unit': 'g'},
#  {'name': 'Onions, sweet, raw',
#   'nutrient': 'Sugars, total',
#   'value': '5.02',
#   'unit': 'g'},
#  {'name': 'Peas, green, raw',
#   'nutrient': 'Water',
#   'value': '78.86',
#   'unit': 'g'},
#  {'name': 'Peas, green, raw',
#   'nutrient': 'Energy',
#   'value': '81',
#   'unit': 'kcal'},
#  {'name': 'Peas, green, raw',
#   'nutrient': 'Protein',
#   'value': '5.42',
#   'unit': 'g'},
#  {'name': 'Peas, green, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.40',
#   'unit': 'g'},
#  {'name': 'Peas, green, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '14.45',
#   'unit': 'g'},
#  {'name': 'Peas, green, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '5.7',
#   'unit': 'g'},
#  {'name': 'Peas, green, raw',
#   'nutrient': 'Sugars, total',
#   'value': '5.67',
#   'unit': 'g'},
#  {'name': 'Peppers, sweet, green, raw',
#   'nutrient': 'Water',
#   'value': '93.89',
#   'unit': 'g'},
#  {'name': 'Peppers, sweet, green, raw',
#   'nutrient': 'Energy',
#   'value': '20',
#   'unit': 'kcal'},
#  {'name': 'Peppers, sweet, green, raw',
#   'nutrient': 'Protein',
#   'value': '0.86',
#   'unit': 'g'},
#  {'name': 'Peppers, sweet, green, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.17',
#   'unit': 'g'},
#  {'name': 'Peppers, sweet, green, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '4.64',
#   'unit': 'g'},
#  {'name': 'Peppers, sweet, green, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.7',
#   'unit': 'g'},
#  {'name': 'Peppers, sweet, green, raw',
#   'nutrient': 'Sugars, total',
#   'value': '2.40',
#   'unit': 'g'},
#  {'name': 'Potatoes, white, flesh and skin, baked',
#   'nutrient': 'Water',
#   'value': '75.43',
#   'unit': 'g'},
#  {'name': 'Potatoes, white, flesh and skin, baked',
#   'nutrient': 'Energy',
#   'value': '92',
#   'unit': 'kcal'},
#  {'name': 'Potatoes, white, flesh and skin, baked',
#   'nutrient': 'Protein',
#   'value': '2.10',
#   'unit': 'g'},
#  {'name': 'Potatoes, white, flesh and skin, baked',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.15',
#   'unit': 'g'},
#  {'name': 'Potatoes, white, flesh and skin, baked',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '21.08',
#   'unit': 'g'},
#  {'name': 'Potatoes, white, flesh and skin, baked',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.1',
#   'unit': 'g'},
#  {'name': 'Potatoes, white, flesh and skin, baked',
#   'nutrient': 'Sugars, total',
#   'value': '1.53',
#   'unit': 'g'},
#  {'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'nutrient': 'Water',
#   'value': '89.70',
#   'unit': 'g'},
#  {'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'nutrient': 'Energy',
#   'value': '34',
#   'unit': 'kcal'},
#  {'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'nutrient': 'Protein',
#   'value': '0.67',
#   'unit': 'g'},
#  {'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.08',
#   'unit': 'g'},
#  {'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '8.79',
#   'unit': 'g'},
#  {'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.6',
#   'unit': 'g'},
#  {'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'nutrient': 'Calcium, Ca',
#   'value': '26',
#   'unit': 'mg'},
#  {'name': 'Tomatoes, orange, raw',
#   'nutrient': 'Water',
#   'value': '94.78',
#   'unit': 'g'},
#  {'name': 'Tomatoes, orange, raw',
#   'nutrient': 'Energy',
#   'value': '16',
#   'unit': 'kcal'},
#  {'name': 'Tomatoes, orange, raw',
#   'nutrient': 'Protein',
#   'value': '1.16',
#   'unit': 'g'},
#  {'name': 'Tomatoes, orange, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.19',
#   'unit': 'g'},
#  {'name': 'Tomatoes, orange, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '3.18',
#   'unit': 'g'},
#  {'name': 'Tomatoes, orange, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '0.9',
#   'unit': 'g'},
#  {'name': 'Tomatoes, orange, raw',
#   'nutrient': 'Calcium, Ca',
#   'value': '5',
#   'unit': 'mg'},
#  {'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'nutrient': 'Water',
#   'value': '93.30',
#   'unit': 'g'},
#  {'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'nutrient': 'Energy',
#   'value': '20',
#   'unit': 'kcal'},
#  {'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'nutrient': 'Protein',
#   'value': '1.15',
#   'unit': 'g'},
#  {'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.10',
#   'unit': 'g'},
#  {'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '4.50',
#   'unit': 'g'},
#  {'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.3',
#   'unit': 'g'},
#  {'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'nutrient': 'Sugars, total',
#   'value': '0.78',
#   'unit': 'g'},
#  {'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'nutrient': 'Water',
#   'value': '92.63',
#   'unit': 'g'},
#  {'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'nutrient': 'Energy',
#   'value': '22',
#   'unit': 'kcal'},
#  {'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'nutrient': 'Protein',
#   'value': '2.40',
#   'unit': 'g'},
#  {'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.22',
#   'unit': 'g'},
#  {'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '4.11',
#   'unit': 'g'},
#  {'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.0',
#   'unit': 'g'},
#  {'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'nutrient': 'Sugars, total',
#   'value': '1.30',
#   'unit': 'g'},
#  {'name': 'Garlic, raw', 'nutrient': 'Water', 'value': '58.58', 'unit': 'g'},
#  {'name': 'Garlic, raw', 'nutrient': 'Energy', 'value': '149', 'unit': 'kcal'},
#  {'name': 'Garlic, raw', 'nutrient': 'Protein', 'value': '6.36', 'unit': 'g'},
#  {'name': 'Garlic, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.50',
#   'unit': 'g'},
#  {'name': 'Garlic, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '33.06',
#   'unit': 'g'},
#  {'name': 'Garlic, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.1',
#   'unit': 'g'},
#  {'name': 'Garlic, raw',
#   'nutrient': 'Sugars, total',
#   'value': '1.00',
#   'unit': 'g'},
#  {'name': 'Kale, raw', 'nutrient': 'Water', 'value': '89.63', 'unit': 'g'},
#  {'name': 'Kale, raw', 'nutrient': 'Energy', 'value': '35', 'unit': 'kcal'},
#  {'name': 'Kale, raw', 'nutrient': 'Protein', 'value': '2.92', 'unit': 'g'},
#  {'name': 'Kale, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '1.49',
#   'unit': 'g'},
#  {'name': 'Kale, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '4.42',
#   'unit': 'g'},
#  {'name': 'Kale, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '4.1',
#   'unit': 'g'},
#  {'name': 'Kale, raw',
#   'nutrient': 'Sugars, total',
#   'value': '0.99',
#   'unit': 'g'},
#  {'name': 'Artichokes, (globe or french), raw',
#   'nutrient': 'Water',
#   'value': '84.94',
#   'unit': 'g'},
#  {'name': 'Artichokes, (globe or french), raw',
#   'nutrient': 'Energy',
#   'value': '47',
#   'unit': 'kcal'},
#  {'name': 'Artichokes, (globe or french), raw',
#   'nutrient': 'Protein',
#   'value': '3.27',
#   'unit': 'g'},
#  {'name': 'Artichokes, (globe or french), raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.15',
#   'unit': 'g'},
#  {'name': 'Artichokes, (globe or french), raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '10.51',
#   'unit': 'g'},
#  {'name': 'Artichokes, (globe or french), raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '5.4',
#   'unit': 'g'},
#  {'name': 'Artichokes, (globe or french), raw',
#   'nutrient': 'Sugars, total',
#   'value': '0.99',
#   'unit': 'g'},
#  {'name': 'Asparagus, raw',
#   'nutrient': 'Water',
#   'value': '93.22',
#   'unit': 'g'},
#  {'name': 'Asparagus, raw',
#   'nutrient': 'Energy',
#   'value': '20',
#   'unit': 'kcal'},
#  {'name': 'Asparagus, raw',
#   'nutrient': 'Protein',
#   'value': '2.20',
#   'unit': 'g'},
#  {'name': 'Asparagus, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.12',
#   'unit': 'g'},
#  {'name': 'Asparagus, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '3.88',
#   'unit': 'g'},
#  {'name': 'Asparagus, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.1',
#   'unit': 'g'},
#  {'name': 'Asparagus, raw',
#   'nutrient': 'Sugars, total',
#   'value': '1.88',
#   'unit': 'g'},
#  {'name': 'Beets, raw', 'nutrient': 'Water', 'value': '87.58', 'unit': 'g'},
#  {'name': 'Beets, raw', 'nutrient': 'Energy', 'value': '43', 'unit': 'kcal'},
#  {'name': 'Beets, raw', 'nutrient': 'Protein', 'value': '1.61', 'unit': 'g'},
#  {'name': 'Beets, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.17',
#   'unit': 'g'},
#  {'name': 'Beets, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '9.56',
#   'unit': 'g'},
#  {'name': 'Beets, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.8',
#   'unit': 'g'},
#  {'name': 'Beets, raw',
#   'nutrient': 'Sugars, total',
#   'value': '6.76',
#   'unit': 'g'},
#  {'name': 'Broccoli, raw', 'nutrient': 'Water', 'value': '89.30', 'unit': 'g'},
#  {'name': 'Broccoli, raw',
#   'nutrient': 'Energy',
#   'value': '34',
#   'unit': 'kcal'},
#  {'name': 'Broccoli, raw',
#   'nutrient': 'Protein',
#   'value': '2.82',
#   'unit': 'g'},
#  {'name': 'Broccoli, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.37',
#   'unit': 'g'},
#  {'name': 'Broccoli, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '6.64',
#   'unit': 'g'},
#  {'name': 'Broccoli, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.6',
#   'unit': 'g'},
#  {'name': 'Broccoli, raw',
#   'nutrient': 'Sugars, total',
#   'value': '1.70',
#   'unit': 'g'},
#  {'name': 'Cabbage, raw', 'nutrient': 'Water', 'value': '92.18', 'unit': 'g'},
#  {'name': 'Cabbage, raw', 'nutrient': 'Energy', 'value': '25', 'unit': 'kcal'},
#  {'name': 'Cabbage, raw', 'nutrient': 'Protein', 'value': '1.28', 'unit': 'g'},
#  {'name': 'Cabbage, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.10',
#   'unit': 'g'},
#  {'name': 'Cabbage, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '5.80',
#   'unit': 'g'},
#  {'name': 'Cabbage, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.5',
#   'unit': 'g'},
#  {'name': 'Cabbage, raw',
#   'nutrient': 'Sugars, total',
#   'value': '3.20',
#   'unit': 'g'},
#  {'name': 'Carrots, raw', 'nutrient': 'Water', 'value': '88.29', 'unit': 'g'},
#  {'name': 'Carrots, raw', 'nutrient': 'Energy', 'value': '41', 'unit': 'kcal'},
#  {'name': 'Carrots, raw', 'nutrient': 'Protein', 'value': '0.93', 'unit': 'g'},
#  {'name': 'Carrots, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.24',
#   'unit': 'g'},
#  {'name': 'Carrots, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '9.58',
#   'unit': 'g'},
#  {'name': 'Carrots, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.8',
#   'unit': 'g'},
#  {'name': 'Carrots, raw',
#   'nutrient': 'Sugars, total',
#   'value': '4.74',
#   'unit': 'g'},
#  {'name': 'Cauliflower, raw',
#   'nutrient': 'Water',
#   'value': '92.07',
#   'unit': 'g'},
#  {'name': 'Cauliflower, raw',
#   'nutrient': 'Energy',
#   'value': '25',
#   'unit': 'kcal'},
#  {'name': 'Cauliflower, raw',
#   'nutrient': 'Protein',
#   'value': '1.92',
#   'unit': 'g'},
#  {'name': 'Cauliflower, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.28',
#   'unit': 'g'},
#  {'name': 'Cauliflower, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '4.97',
#   'unit': 'g'},
#  {'name': 'Cauliflower, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.0',
#   'unit': 'g'},
#  {'name': 'Cauliflower, raw',
#   'nutrient': 'Sugars, total',
#   'value': '1.91',
#   'unit': 'g'},
#  {'name': 'Celery, raw', 'nutrient': 'Water', 'value': '95.43', 'unit': 'g'},
#  {'name': 'Celery, raw', 'nutrient': 'Energy', 'value': '14', 'unit': 'kcal'},
#  {'name': 'Celery, raw', 'nutrient': 'Protein', 'value': '0.69', 'unit': 'g'},
#  {'name': 'Celery, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.17',
#   'unit': 'g'},
#  {'name': 'Celery, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '2.97',
#   'unit': 'g'},
#  {'name': 'Celery, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.6',
#   'unit': 'g'},
#  {'name': 'Celery, raw',
#   'nutrient': 'Sugars, total',
#   'value': '1.34',
#   'unit': 'g'},
#  {'name': 'Cucumber, with peel, raw',
#   'nutrient': 'Water',
#   'value': '95.23',
#   'unit': 'g'},
#  {'name': 'Cucumber, with peel, raw',
#   'nutrient': 'Energy',
#   'value': '15',
#   'unit': 'kcal'},
#  {'name': 'Cucumber, with peel, raw',
#   'nutrient': 'Protein',
#   'value': '0.65',
#   'unit': 'g'},
#  {'name': 'Cucumber, with peel, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.11',
#   'unit': 'g'},
#  {'name': 'Cucumber, with peel, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '3.63',
#   'unit': 'g'},
#  {'name': 'Cucumber, with peel, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '0.5',
#   'unit': 'g'},
#  {'name': 'Cucumber, with peel, raw',
#   'nutrient': 'Sugars, total',
#   'value': '1.67',
#   'unit': 'g'},
#  {'name': 'Lentils, sprouted, raw',
#   'nutrient': 'Water',
#   'value': '67.34',
#   'unit': 'g'},
#  {'name': 'Lentils, sprouted, raw',
#   'nutrient': 'Energy',
#   'value': '106',
#   'unit': 'kcal'},
#  {'name': 'Lentils, sprouted, raw',
#   'nutrient': 'Protein',
#   'value': '8.96',
#   'unit': 'g'},
#  {'name': 'Lentils, sprouted, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.55',
#   'unit': 'g'},
#  {'name': 'Lentils, sprouted, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '22.14',
#   'unit': 'g'},
#  {'name': 'Lentils, sprouted, raw',
#   'nutrient': 'Calcium, Ca',
#   'value': '25',
#   'unit': 'mg'},
#  {'name': 'Lentils, sprouted, raw',
#   'nutrient': 'Iron, Fe',
#   'value': '3.21',
#   'unit': 'mg'},
#  {'name': 'Lettuce, green leaf, raw',
#   'nutrient': 'Water',
#   'value': '94.98',
#   'unit': 'g'},
#  {'name': 'Lettuce, green leaf, raw',
#   'nutrient': 'Energy',
#   'value': '15',
#   'unit': 'kcal'},
#  {'name': 'Lettuce, green leaf, raw',
#   'nutrient': 'Protein',
#   'value': '1.36',
#   'unit': 'g'},
#  {'name': 'Lettuce, green leaf, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.15',
#   'unit': 'g'},
#  {'name': 'Lettuce, green leaf, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '2.87',
#   'unit': 'g'},
#  {'name': 'Lettuce, green leaf, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.3',
#   'unit': 'g'},
#  {'name': 'Lettuce, green leaf, raw',
#   'nutrient': 'Sugars, total',
#   'value': '0.78',
#   'unit': 'g'},
#  {'name': 'Onions, sweet, raw',
#   'nutrient': 'Water',
#   'value': '91.24',
#   'unit': 'g'},
#  {'name': 'Onions, sweet, raw',
#   'nutrient': 'Energy',
#   'value': '32',
#   'unit': 'kcal'},
#  {'name': 'Onions, sweet, raw',
#   'nutrient': 'Protein',
#   'value': '0.80',
#   'unit': 'g'},
#  {'name': 'Onions, sweet, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.08',
#   'unit': 'g'},
#  {'name': 'Onions, sweet, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '7.55',
#   'unit': 'g'},
#  {'name': 'Onions, sweet, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '0.9',
#   'unit': 'g'},
#  {'name': 'Onions, sweet, raw',
#   'nutrient': 'Sugars, total',
#   'value': '5.02',
#   'unit': 'g'},
#  {'name': 'Peas, green, raw',
#   'nutrient': 'Water',
#   'value': '78.86',
#   'unit': 'g'},
#  {'name': 'Peas, green, raw',
#   'nutrient': 'Energy',
#   'value': '81',
#   'unit': 'kcal'},
#  {'name': 'Peas, green, raw',
#   'nutrient': 'Protein',
#   'value': '5.42',
#   'unit': 'g'},
#  {'name': 'Peas, green, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.40',
#   'unit': 'g'},
#  {'name': 'Peas, green, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '14.45',
#   'unit': 'g'},
#  {'name': 'Peas, green, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '5.7',
#   'unit': 'g'},
#  {'name': 'Peas, green, raw',
#   'nutrient': 'Sugars, total',
#   'value': '5.67',
#   'unit': 'g'},
#  {'name': 'Peppers, sweet, green, raw',
#   'nutrient': 'Water',
#   'value': '93.89',
#   'unit': 'g'},
#  {'name': 'Peppers, sweet, green, raw',
#   'nutrient': 'Energy',
#   'value': '20',
#   'unit': 'kcal'},
#  {'name': 'Peppers, sweet, green, raw',
#   'nutrient': 'Protein',
#   'value': '0.86',
#   'unit': 'g'},
#  {'name': 'Peppers, sweet, green, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.17',
#   'unit': 'g'},
#  {'name': 'Peppers, sweet, green, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '4.64',
#   'unit': 'g'},
#  {'name': 'Peppers, sweet, green, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.7',
#   'unit': 'g'},
#  {'name': 'Peppers, sweet, green, raw',
#   'nutrient': 'Sugars, total',
#   'value': '2.40',
#   'unit': 'g'},
#  {'name': 'Potatoes, white, flesh and skin, baked',
#   'nutrient': 'Water',
#   'value': '75.43',
#   'unit': 'g'},
#  {'name': 'Potatoes, white, flesh and skin, baked',
#   'nutrient': 'Energy',
#   'value': '92',
#   'unit': 'kcal'},
#  {'name': 'Potatoes, white, flesh and skin, baked',
#   'nutrient': 'Protein',
#   'value': '2.10',
#   'unit': 'g'},
#  {'name': 'Potatoes, white, flesh and skin, baked',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.15',
#   'unit': 'g'},
#  {'name': 'Potatoes, white, flesh and skin, baked',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '21.08',
#   'unit': 'g'},
#  {'name': 'Potatoes, white, flesh and skin, baked',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.1',
#   'unit': 'g'},
#  {'name': 'Potatoes, white, flesh and skin, baked',
#   'nutrient': 'Sugars, total',
#   'value': '1.53',
#   'unit': 'g'},
#  {'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'nutrient': 'Water',
#   'value': '89.70',
#   'unit': 'g'},
#  {'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'nutrient': 'Energy',
#   'value': '34',
#   'unit': 'kcal'},
#  {'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'nutrient': 'Protein',
#   'value': '0.67',
#   'unit': 'g'},
#  {'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.08',
#   'unit': 'g'},
#  {'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '8.79',
#   'unit': 'g'},
#  {'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.6',
#   'unit': 'g'},
#  {'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'nutrient': 'Calcium, Ca',
#   'value': '26',
#   'unit': 'mg'},
#  {'name': 'Tomatoes, orange, raw',
#   'nutrient': 'Water',
#   'value': '94.78',
#   'unit': 'g'},
#  {'name': 'Tomatoes, orange, raw',
#   'nutrient': 'Energy',
#   'value': '16',
#   'unit': 'kcal'},
#  {'name': 'Tomatoes, orange, raw',
#   'nutrient': 'Protein',
#   'value': '1.16',
#   'unit': 'g'},
#  {'name': 'Tomatoes, orange, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.19',
#   'unit': 'g'},
#  {'name': 'Tomatoes, orange, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '3.18',
#   'unit': 'g'},
#  {'name': 'Tomatoes, orange, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '0.9',
#   'unit': 'g'},
#  {'name': 'Tomatoes, orange, raw',
#   'nutrient': 'Calcium, Ca',
#   'value': '5',
#   'unit': 'mg'},
#  {'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'nutrient': 'Water',
#   'value': '93.30',
#   'unit': 'g'},
#  {'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'nutrient': 'Energy',
#   'value': '20',
#   'unit': 'kcal'},
#  {'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'nutrient': 'Protein',
#   'value': '1.15',
#   'unit': 'g'},
#  {'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.10',
#   'unit': 'g'},
#  {'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '4.50',
#   'unit': 'g'},
#  {'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.3',
#   'unit': 'g'},
#  {'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'nutrient': 'Sugars, total',
#   'value': '0.78',
#   'unit': 'g'},
#  {'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'nutrient': 'Water',
#   'value': '92.63',
#   'unit': 'g'},
#  {'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'nutrient': 'Energy',
#   'value': '22',
#   'unit': 'kcal'},
#  {'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'nutrient': 'Protein',
#   'value': '2.40',
#   'unit': 'g'},
#  {'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.22',
#   'unit': 'g'},
#  {'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '4.11',
#   'unit': 'g'},
#  {'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.0',
#   'unit': 'g'},
#  {'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'nutrient': 'Sugars, total',
#   'value': '1.30',
#   'unit': 'g'},
#  {'name': 'Garlic, raw', 'nutrient': 'Water', 'value': '58.58', 'unit': 'g'},
#  {'name': 'Garlic, raw', 'nutrient': 'Energy', 'value': '149', 'unit': 'kcal'},
#  {'name': 'Garlic, raw', 'nutrient': 'Protein', 'value': '6.36', 'unit': 'g'},
#  {'name': 'Garlic, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.50',
#   'unit': 'g'},
#  {'name': 'Garlic, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '33.06',
#   'unit': 'g'},
#  {'name': 'Garlic, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.1',
#   'unit': 'g'},
#  {'name': 'Garlic, raw',
#   'nutrient': 'Sugars, total',
#   'value': '1.00',
#   'unit': 'g'},
#  {'name': 'Kale, raw', 'nutrient': 'Water', 'value': '89.63', 'unit': 'g'},
#  {'name': 'Kale, raw', 'nutrient': 'Energy', 'value': '35', 'unit': 'kcal'},
#  {'name': 'Kale, raw', 'nutrient': 'Protein', 'value': '2.92', 'unit': 'g'},
#  {'name': 'Kale, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '1.49',
#   'unit': 'g'},
#  {'name': 'Kale, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '4.42',
#   'unit': 'g'},
#  {'name': 'Kale, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '4.1',
#   'unit': 'g'},
#  {'name': 'Kale, raw',
#   'nutrient': 'Sugars, total',
#   'value': '0.99',
#   'unit': 'g'},
#  {'name': 'Artichokes, (globe or french), raw',
#   'nutrient': 'Water',
#   'value': '84.94',
#   'unit': 'g'},
#  {'name': 'Artichokes, (globe or french), raw',
#   'nutrient': 'Energy',
#   'value': '47',
#   'unit': 'kcal'},
#  {'name': 'Artichokes, (globe or french), raw',
#   'nutrient': 'Protein',
#   'value': '3.27',
#   'unit': 'g'},
#  {'name': 'Artichokes, (globe or french), raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.15',
#   'unit': 'g'},
#  {'name': 'Artichokes, (globe or french), raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '10.51',
#   'unit': 'g'},
#  {'name': 'Artichokes, (globe or french), raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '5.4',
#   'unit': 'g'},
#  {'name': 'Artichokes, (globe or french), raw',
#   'nutrient': 'Sugars, total',
#   'value': '0.99',
#   'unit': 'g'},
#  {'name': 'Asparagus, raw',
#   'nutrient': 'Water',
#   'value': '93.22',
#   'unit': 'g'},
#  {'name': 'Asparagus, raw',
#   'nutrient': 'Energy',
#   'value': '20',
#   'unit': 'kcal'},
#  {'name': 'Asparagus, raw',
#   'nutrient': 'Protein',
#   'value': '2.20',
#   'unit': 'g'},
#  {'name': 'Asparagus, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.12',
#   'unit': 'g'},
#  {'name': 'Asparagus, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '3.88',
#   'unit': 'g'},
#  {'name': 'Asparagus, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.1',
#   'unit': 'g'},
#  {'name': 'Asparagus, raw',
#   'nutrient': 'Sugars, total',
#   'value': '1.88',
#   'unit': 'g'},
#  {'name': 'Beets, raw', 'nutrient': 'Water', 'value': '87.58', 'unit': 'g'},
#  {'name': 'Beets, raw', 'nutrient': 'Energy', 'value': '43', 'unit': 'kcal'},
#  {'name': 'Beets, raw', 'nutrient': 'Protein', 'value': '1.61', 'unit': 'g'},
#  {'name': 'Beets, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.17',
#   'unit': 'g'},
#  {'name': 'Beets, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '9.56',
#   'unit': 'g'},
#  {'name': 'Beets, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.8',
#   'unit': 'g'},
#  {'name': 'Beets, raw',
#   'nutrient': 'Sugars, total',
#   'value': '6.76',
#   'unit': 'g'},
#  {'name': 'Broccoli, raw', 'nutrient': 'Water', 'value': '89.30', 'unit': 'g'},
#  {'name': 'Broccoli, raw',
#   'nutrient': 'Energy',
#   'value': '34',
#   'unit': 'kcal'},
#  {'name': 'Broccoli, raw',
#   'nutrient': 'Protein',
#   'value': '2.82',
#   'unit': 'g'},
#  {'name': 'Broccoli, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.37',
#   'unit': 'g'},
#  {'name': 'Broccoli, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '6.64',
#   'unit': 'g'},
#  {'name': 'Broccoli, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.6',
#   'unit': 'g'},
#  {'name': 'Broccoli, raw',
#   'nutrient': 'Sugars, total',
#   'value': '1.70',
#   'unit': 'g'},
#  {'name': 'Cabbage, raw', 'nutrient': 'Water', 'value': '92.18', 'unit': 'g'},
#  {'name': 'Cabbage, raw', 'nutrient': 'Energy', 'value': '25', 'unit': 'kcal'},
#  {'name': 'Cabbage, raw', 'nutrient': 'Protein', 'value': '1.28', 'unit': 'g'},
#  {'name': 'Cabbage, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.10',
#   'unit': 'g'},
#  {'name': 'Cabbage, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '5.80',
#   'unit': 'g'},
#  {'name': 'Cabbage, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.5',
#   'unit': 'g'},
#  {'name': 'Cabbage, raw',
#   'nutrient': 'Sugars, total',
#   'value': '3.20',
#   'unit': 'g'},
#  {'name': 'Carrots, raw', 'nutrient': 'Water', 'value': '88.29', 'unit': 'g'},
#  {'name': 'Carrots, raw', 'nutrient': 'Energy', 'value': '41', 'unit': 'kcal'},
#  {'name': 'Carrots, raw', 'nutrient': 'Protein', 'value': '0.93', 'unit': 'g'},
#  {'name': 'Carrots, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.24',
#   'unit': 'g'},
#  {'name': 'Carrots, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '9.58',
#   'unit': 'g'},
#  {'name': 'Carrots, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.8',
#   'unit': 'g'},
#  {'name': 'Carrots, raw',
#   'nutrient': 'Sugars, total',
#   'value': '4.74',
#   'unit': 'g'},
#  {'name': 'Cauliflower, raw',
#   'nutrient': 'Water',
#   'value': '92.07',
#   'unit': 'g'},
#  {'name': 'Cauliflower, raw',
#   'nutrient': 'Energy',
#   'value': '25',
#   'unit': 'kcal'},
#  {'name': 'Cauliflower, raw',
#   'nutrient': 'Protein',
#   'value': '1.92',
#   'unit': 'g'},
#  {'name': 'Cauliflower, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.28',
#   'unit': 'g'},
#  {'name': 'Cauliflower, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '4.97',
#   'unit': 'g'},
#  {'name': 'Cauliflower, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.0',
#   'unit': 'g'},
#  {'name': 'Cauliflower, raw',
#   'nutrient': 'Sugars, total',
#   'value': '1.91',
#   'unit': 'g'},
#  {'name': 'Celery, raw', 'nutrient': 'Water', 'value': '95.43', 'unit': 'g'},
#  {'name': 'Celery, raw', 'nutrient': 'Energy', 'value': '14', 'unit': 'kcal'},
#  {'name': 'Celery, raw', 'nutrient': 'Protein', 'value': '0.69', 'unit': 'g'},
#  {'name': 'Celery, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.17',
#   'unit': 'g'},
#  {'name': 'Celery, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '2.97',
#   'unit': 'g'},
#  {'name': 'Celery, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.6',
#   'unit': 'g'},
#  {'name': 'Celery, raw',
#   'nutrient': 'Sugars, total',
#   'value': '1.34',
#   'unit': 'g'},
#  {'name': 'Cucumber, with peel, raw',
#   'nutrient': 'Water',
#   'value': '95.23',
#   'unit': 'g'},
#  {'name': 'Cucumber, with peel, raw',
#   'nutrient': 'Energy',
#   'value': '15',
#   'unit': 'kcal'},
#  {'name': 'Cucumber, with peel, raw',
#   'nutrient': 'Protein',
#   'value': '0.65',
#   'unit': 'g'},
#  {'name': 'Cucumber, with peel, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.11',
#   'unit': 'g'},
#  {'name': 'Cucumber, with peel, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '3.63',
#   'unit': 'g'},
#  {'name': 'Cucumber, with peel, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '0.5',
#   'unit': 'g'},
#  {'name': 'Cucumber, with peel, raw',
#   'nutrient': 'Sugars, total',
#   'value': '1.67',
#   'unit': 'g'},
#  {'name': 'Lentils, sprouted, raw',
#   'nutrient': 'Water',
#   'value': '67.34',
#   'unit': 'g'},
#  {'name': 'Lentils, sprouted, raw',
#   'nutrient': 'Energy',
#   'value': '106',
#   'unit': 'kcal'},
#  {'name': 'Lentils, sprouted, raw',
#   'nutrient': 'Protein',
#   'value': '8.96',
#   'unit': 'g'},
#  {'name': 'Lentils, sprouted, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.55',
#   'unit': 'g'},
#  {'name': 'Lentils, sprouted, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '22.14',
#   'unit': 'g'},
#  {'name': 'Lentils, sprouted, raw',
#   'nutrient': 'Calcium, Ca',
#   'value': '25',
#   'unit': 'mg'},
#  {'name': 'Lentils, sprouted, raw',
#   'nutrient': 'Iron, Fe',
#   'value': '3.21',
#   'unit': 'mg'},
#  {'name': 'Lettuce, green leaf, raw',
#   'nutrient': 'Water',
#   'value': '94.98',
#   'unit': 'g'},
#  {'name': 'Lettuce, green leaf, raw',
#   'nutrient': 'Energy',
#   'value': '15',
#   'unit': 'kcal'},
#  {'name': 'Lettuce, green leaf, raw',
#   'nutrient': 'Protein',
#   'value': '1.36',
#   'unit': 'g'},
#  {'name': 'Lettuce, green leaf, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.15',
#   'unit': 'g'},
#  {'name': 'Lettuce, green leaf, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '2.87',
#   'unit': 'g'},
#  {'name': 'Lettuce, green leaf, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.3',
#   'unit': 'g'},
#  {'name': 'Lettuce, green leaf, raw',
#   'nutrient': 'Sugars, total',
#   'value': '0.78',
#   'unit': 'g'},
#  {'name': 'Onions, sweet, raw',
#   'nutrient': 'Water',
#   'value': '91.24',
#   'unit': 'g'},
#  {'name': 'Onions, sweet, raw',
#   'nutrient': 'Energy',
#   'value': '32',
#   'unit': 'kcal'},
#  {'name': 'Onions, sweet, raw',
#   'nutrient': 'Protein',
#   'value': '0.80',
#   'unit': 'g'},
#  {'name': 'Onions, sweet, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.08',
#   'unit': 'g'},
#  {'name': 'Onions, sweet, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '7.55',
#   'unit': 'g'},
#  {'name': 'Onions, sweet, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '0.9',
#   'unit': 'g'},
#  {'name': 'Onions, sweet, raw',
#   'nutrient': 'Sugars, total',
#   'value': '5.02',
#   'unit': 'g'},
#  {'name': 'Peas, green, raw',
#   'nutrient': 'Water',
#   'value': '78.86',
#   'unit': 'g'},
#  {'name': 'Peas, green, raw',
#   'nutrient': 'Energy',
#   'value': '81',
#   'unit': 'kcal'},
#  {'name': 'Peas, green, raw',
#   'nutrient': 'Protein',
#   'value': '5.42',
#   'unit': 'g'},
#  {'name': 'Peas, green, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.40',
#   'unit': 'g'},
#  {'name': 'Peas, green, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '14.45',
#   'unit': 'g'},
#  {'name': 'Peas, green, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '5.7',
#   'unit': 'g'},
#  {'name': 'Peas, green, raw',
#   'nutrient': 'Sugars, total',
#   'value': '5.67',
#   'unit': 'g'},
#  {'name': 'Peppers, sweet, green, raw',
#   'nutrient': 'Water',
#   'value': '93.89',
#   'unit': 'g'},
#  {'name': 'Peppers, sweet, green, raw',
#   'nutrient': 'Energy',
#   'value': '20',
#   'unit': 'kcal'},
#  {'name': 'Peppers, sweet, green, raw',
#   'nutrient': 'Protein',
#   'value': '0.86',
#   'unit': 'g'},
#  {'name': 'Peppers, sweet, green, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.17',
#   'unit': 'g'},
#  {'name': 'Peppers, sweet, green, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '4.64',
#   'unit': 'g'},
#  {'name': 'Peppers, sweet, green, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.7',
#   'unit': 'g'},
#  {'name': 'Peppers, sweet, green, raw',
#   'nutrient': 'Sugars, total',
#   'value': '2.40',
#   'unit': 'g'},
#  {'name': 'Potatoes, white, flesh and skin, baked',
#   'nutrient': 'Water',
#   'value': '75.43',
#   'unit': 'g'},
#  {'name': 'Potatoes, white, flesh and skin, baked',
#   'nutrient': 'Energy',
#   'value': '92',
#   'unit': 'kcal'},
#  {'name': 'Potatoes, white, flesh and skin, baked',
#   'nutrient': 'Protein',
#   'value': '2.10',
#   'unit': 'g'},
#  {'name': 'Potatoes, white, flesh and skin, baked',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.15',
#   'unit': 'g'},
#  {'name': 'Potatoes, white, flesh and skin, baked',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '21.08',
#   'unit': 'g'},
#  {'name': 'Potatoes, white, flesh and skin, baked',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.1',
#   'unit': 'g'},
#  {'name': 'Potatoes, white, flesh and skin, baked',
#   'nutrient': 'Sugars, total',
#   'value': '1.53',
#   'unit': 'g'},
#  {'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'nutrient': 'Water',
#   'value': '89.70',
#   'unit': 'g'},
#  {'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'nutrient': 'Energy',
#   'value': '34',
#   'unit': 'kcal'},
#  {'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'nutrient': 'Protein',
#   'value': '0.67',
#   'unit': 'g'},
#  {'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.08',
#   'unit': 'g'},
#  {'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '8.79',
#   'unit': 'g'},
#  {'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.6',
#   'unit': 'g'},
#  {'name': 'Squash, winter, acorn, cooked, boiled, mashed, without salt',
#   'nutrient': 'Calcium, Ca',
#   'value': '26',
#   'unit': 'mg'},
#  {'name': 'Tomatoes, orange, raw',
#   'nutrient': 'Water',
#   'value': '94.78',
#   'unit': 'g'},
#  {'name': 'Tomatoes, orange, raw',
#   'nutrient': 'Energy',
#   'value': '16',
#   'unit': 'kcal'},
#  {'name': 'Tomatoes, orange, raw',
#   'nutrient': 'Protein',
#   'value': '1.16',
#   'unit': 'g'},
#  {'name': 'Tomatoes, orange, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.19',
#   'unit': 'g'},
#  {'name': 'Tomatoes, orange, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '3.18',
#   'unit': 'g'},
#  {'name': 'Tomatoes, orange, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '0.9',
#   'unit': 'g'},
#  {'name': 'Tomatoes, orange, raw',
#   'nutrient': 'Calcium, Ca',
#   'value': '5',
#   'unit': 'mg'},
#  {'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'nutrient': 'Water',
#   'value': '93.30',
#   'unit': 'g'},
#  {'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'nutrient': 'Energy',
#   'value': '20',
#   'unit': 'kcal'},
#  {'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'nutrient': 'Protein',
#   'value': '1.15',
#   'unit': 'g'},
#  {'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.10',
#   'unit': 'g'},
#  {'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '4.50',
#   'unit': 'g'},
#  {'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'nutrient': 'Fiber, total dietary',
#   'value': '1.3',
#   'unit': 'g'},
#  {'name': 'Beans, snap, yellow, canned, regular pack, drained solids',
#   'nutrient': 'Sugars, total',
#   'value': '0.78',
#   'unit': 'g'},
#  {'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'nutrient': 'Water',
#   'value': '92.63',
#   'unit': 'g'},
#  {'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'nutrient': 'Energy',
#   'value': '22',
#   'unit': 'kcal'},
#  {'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'nutrient': 'Protein',
#   'value': '2.40',
#   'unit': 'g'},
#  {'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.22',
#   'unit': 'g'},
#  {'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '4.11',
#   'unit': 'g'},
#  {'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.0',
#   'unit': 'g'},
#  {'name': 'Asparagus, cooked, boiled, drained, with salt',
#   'nutrient': 'Sugars, total',
#   'value': '1.30',
#   'unit': 'g'},
#  {'name': 'Garlic, raw', 'nutrient': 'Water', 'value': '58.58', 'unit': 'g'},
#  {'name': 'Garlic, raw', 'nutrient': 'Energy', 'value': '149', 'unit': 'kcal'},
#  {'name': 'Garlic, raw', 'nutrient': 'Protein', 'value': '6.36', 'unit': 'g'},
#  {'name': 'Garlic, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.50',
#   'unit': 'g'},
#  {'name': 'Garlic, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '33.06',
#   'unit': 'g'},
#  {'name': 'Garlic, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '2.1',
#   'unit': 'g'},
#  {'name': 'Garlic, raw',
#   'nutrient': 'Sugars, total',
#   'value': '1.00',
#   'unit': 'g'},
#  {'name': 'Kale, raw', 'nutrient': 'Water', 'value': '89.63', 'unit': 'g'},
#  {'name': 'Kale, raw', 'nutrient': 'Energy', 'value': '35', 'unit': 'kcal'},
#  {'name': 'Kale, raw', 'nutrient': 'Protein', 'value': '2.92', 'unit': 'g'},
#  {'name': 'Kale, raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '1.49',
#   'unit': 'g'},
#  {'name': 'Kale, raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '4.42',
#   'unit': 'g'},
#  {'name': 'Kale, raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '4.1',
#   'unit': 'g'},
#  {'name': 'Kale, raw',
#   'nutrient': 'Sugars, total',
#   'value': '0.99',
#   'unit': 'g'},
#  {'name': 'Artichokes, (globe or french), raw',
#   'nutrient': 'Water',
#   'value': '84.94',
#   'unit': 'g'},
#  {'name': 'Artichokes, (globe or french), raw',
#   'nutrient': 'Energy',
#   'value': '47',
#   'unit': 'kcal'},
#  {'name': 'Artichokes, (globe or french), raw',
#   'nutrient': 'Protein',
#   'value': '3.27',
#   'unit': 'g'},
#  {'name': 'Artichokes, (globe or french), raw',
#   'nutrient': 'Total lipid (fat)',
#   'value': '0.15',
#   'unit': 'g'},
#  {'name': 'Artichokes, (globe or french), raw',
#   'nutrient': 'Carbohydrate, by difference',
#   'value': '10.51',
#   'unit': 'g'},
#  {'name': 'Artichokes, (globe or french), raw',
#   'nutrient': 'Fiber, total dietary',
#   'value': '5.4',
#   'unit': 'g'},
#  {'name': 'Artichokes, (globe or french), raw',
#   'nutrient': 'Sugars, total',
#   'value': '0.99',
#   'unit': 'g'}]

# %%
response_json["foods"][1]["food"]["desc"]["name"]
# response_json["foods"][0]["food"]["nutrients"][2]["name"]
# response_json["foods"][0]["food"]["nutrients"][3]["unit"]
# response_json["foods"][0]["food"]["nutrients"][0]["value"]
# Out:
# 'Beets, raw'
